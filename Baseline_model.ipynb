# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Rock-segmentation/blob/main/Baseline_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model

from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (256, 256)
BATCH_SIZE = 4
EPOCHS = 50
SEED = 42

IMAGE_DIR = "/content/drive/MyDrive/dataset_rock/images"
MASK_DIR  = "/content/drive/MyDrive/dataset_rock/masks"

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

print("Images :", len(os.listdir(IMAGE_DIR)))
print("Masks  :", len(os.listdir(MASK_DIR)))

print(os.listdir(IMAGE_DIR)[:5])
print(os.listdir(MASK_DIR)[:5])
# Out:
# Images : 16
# Masks  : 16
# ['image5.jpg', 'image10.jpg', 'image16.png', 'image1.jpg', 'image4.jpg']
# ['image2.png', 'image7.png', 'image9.png', 'image11.png', 'image3.png']

# %%
def get_pairs(image_dir, mask_dir):
    image_paths = []
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        image_paths.extend(glob.glob(os.path.join(image_dir, f"*.{ext}")))

    image_paths = sorted(image_paths)

    mask_map = {}
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        for p in glob.glob(os.path.join(mask_dir, f"*.{ext}")):
            stem = os.path.splitext(os.path.basename(p))[0]
            mask_map[stem] = p

    pairs = []
    for img_path in image_paths:
        stem = os.path.splitext(os.path.basename(img_path))[0]
        if stem in mask_map:
            pairs.append((img_path, mask_map[stem]))
        else:
            print(f"Warning: no mask found for {img_path}")

    return pairs

pairs = get_pairs(IMAGE_DIR, MASK_DIR)
print("Total paired samples:", len(pairs))

# =========================
# LOAD ONE IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    # Image
    img = cv2.imread(img_path.decode(), cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    # Mask
    mask = cv2.imread(mask_path.decode(), cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")
    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)

    # Binary mask: 0/1
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask

# =========================
# AUGMENTATION
# =========================
def augment(image, mask):
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    k = tf.random.uniform((), minval=0, maxval=4, dtype=tf.int32)
    image = tf.image.rot90(image, k)
    mask = tf.image.rot90(mask, k)

    return image, mask

# =========================
# CREATE DATASET
# =========================

pairs = get_pairs(IMAGE_DIR, MASK_DIR)

print("Total paired samples:", len(pairs))

for img, mask in pairs[:3]:
    print(img)
    print(mask)
    print()
# Out:
# Total paired samples: 16
# Total paired samples: 16
# /content/drive/MyDrive/dataset_rock/images/image1.jpg
# /content/drive/MyDrive/dataset_rock/masks/image1.png
#
# /content/drive/MyDrive/dataset_rock/images/image10.jpg
# /content/drive/MyDrive/dataset_rock/masks/image10.png
#
# /content/drive/MyDrive/dataset_rock/images/image11.png
# /content/drive/MyDrive/dataset_rock/masks/image11.png

# %%
def make_dataset(pairs, training=True):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)

    if training:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

train_pairs, val_pairs = train_test_split(pairs, test_size=0.2, random_state=SEED)

train_ds = make_dataset(train_pairs, training=True)
val_ds = make_dataset(val_pairs, training=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))

# =========================
# METRICS / LOSS
# =========================
def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# =========================
# U-NET BUILDING BLOCKS
# =========================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x

def down_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPool2D((2, 2))(c)
    p = layers.Dropout(0.2)(p)
    return c, p

def up_block(x, skip, filters):
    x = layers.Conv2DTranspose(filters, 2, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip])
    x = layers.Dropout(0.2)(x)
    x = conv_block(x, filters)
    return x

# =========================
# BUILD U-NET
# =========================
def build_unet(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)

    s1, p1 = down_block(inputs, 32)
    s2, p2 = down_block(p1, 64)
    s3, p3 = down_block(p2, 128)
    s4, p4 = down_block(p3, 256)

    bottleneck = conv_block(p4, 512)

    u1 = up_block(bottleneck, s4, 256)
    u2 = up_block(u1, s3, 128)
    u3 = up_block(u2, s2, 64)
    u4 = up_block(u3, s1, 32)

    outputs = layers.Conv2D(1, 1, activation="sigmoid")(u4)

    model = Model(inputs, outputs, name="UNet_Binary")
    return model

model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=dice_loss,
    metrics=["accuracy", dice_coef, iou_coef]
)

model.summary()

# =========================
# CALLBACKS
# =========================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "best_unet.keras",
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# =========================
# TRAIN
# =========================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS: ACCURACY, DICE, IOU
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(18, 5))

    # Accuracy
    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, hist["accuracy"], label="Train Accuracy")
    plt.plot(epochs_range, hist["val_accuracy"], label="Val Accuracy")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    # Dice Score
    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, hist["dice_coef"], label="Train Dice")
    plt.plot(epochs_range, hist["val_dice_coef"], label="Val Dice")
    plt.title("Dice Score Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Dice Coefficient")
    plt.legend()
    plt.grid(True)

    # IoU
    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, hist["iou_coef"], label="Train IoU")
    plt.plot(epochs_range, hist["val_iou_coef"], label="Val IoU")
    plt.title("IoU Curve")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_curves(history)

# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

# Show one validation sample
show_prediction(model, val_pairs[0])
# Out:
# Train samples: 12
# Val samples: 4
# Model: "UNet_Binary"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,248 │ re_lu[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,496 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,928 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ re_lu_3[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,856 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,584 │ re_lu_4[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ re_lu_5[0][0]     │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    295,168 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    590,080 │ re_lu_6[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ re_lu_7[0][0]     │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ dropout_3[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ re_lu_8[0][0]     │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    524,544 │ re_lu_9[0][0]     │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 32,    │          0 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_10[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    131,200 │ re_lu_11[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 64,    │          0 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    295,040 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_12[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     32,832 │ re_lu_13[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128, 128,  │          0 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     73,792 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_14[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      8,224 │ re_lu_15[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256, 256,  │          0 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     18,464 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_16[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         33 │ re_lu_17[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,771,873 (29.65 MB)
#  Trainable params: 7,765,985 (29.62 MB)
#  Non-trainable params: 5,888 (23.00 KB)
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.3593 - dice_coef: 0.4471 - iou_coef: 0.2880 - loss: 0.5529
# Epoch 1: val_dice_coef improved from None to 0.50369, saving model to best_unet.keras
#
# Epoch 1: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 65s 4s/step - accuracy: 0.3656 - dice_coef: 0.4488 - iou_coef: 0.2894 - loss: 0.5512 - val_accuracy: 0.4411 - val_dice_coef: 0.5037 - val_iou_coef: 0.3366 - val_loss: 0.4963 - learning_rate: 1.0000e-04
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.3959 - dice_coef: 0.4660 - iou_coef: 0.3038 - loss: 0.5340
# Epoch 2: val_dice_coef did not improve from 0.50369
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 710ms/step - accuracy: 0.3980 - dice_coef: 0.4684 - iou_coef: 0.3059 - loss: 0.5316 - val_accuracy: 0.4445 - val_dice_coef: 0.5009 - val_iou_coef: 0.3341 - val_loss: 0.4991 - learning_rate: 1.0000e-04
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step - accuracy: 0.4369 - dice_coef: 0.4818 - iou_coef: 0.3175 - loss: 0.5182
# Epoch 3: val_dice_coef did not improve from 0.50369
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 753ms/step - accuracy: 0.4378 - dice_coef: 0.4921 - iou_coef: 0.3265 - loss: 0.5079 - val_accuracy: 0.4403 - val_dice_coef: 0.4960 - val_iou_coef: 0.3298 - val_loss: 0.5040 - learning_rate: 1.0000e-04
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.4667 - dice_coef: 0.5136 - iou_coef: 0.3457 - loss: 0.4864
# Epoch 4: val_dice_coef did not improve from 0.50369
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 853ms/step - accuracy: 0.4747 - dice_coef: 0.5131 - iou_coef: 0.3453 - loss: 0.4869 - val_accuracy: 0.4358 - val_dice_coef: 0.4902 - val_iou_coef: 0.3247 - val_loss: 0.5098 - learning_rate: 1.0000e-04
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 893ms/step - accuracy: 0.5141 - dice_coef: 0.5278 - iou_coef: 0.3586 - loss: 0.4722
# Epoch 5: val_dice_coef did not improve from 0.50369
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.5193 - dice_coef: 0.5366 - iou_coef: 0.3670 - loss: 0.4634 - val_accuracy: 0.4317 - val_dice_coef: 0.4848 - val_iou_coef: 0.3199 - val_loss: 0.5152 - learning_rate: 1.0000e-04
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.5580 - dice_coef: 0.5493 - iou_coef: 0.3787 - loss: 0.4507
# Epoch 6: val_dice_coef did not improve from 0.50369
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 859ms/step - accuracy: 0.5440 - dice_coef: 0.5538 - iou_coef: 0.3830 - loss: 0.4462 - val_accuracy: 0.4274 - val_dice_coef: 0.4901 - val_iou_coef: 0.3246 - val_loss: 0.5099 - learning_rate: 5.0000e-05
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.5502 - dice_coef: 0.5498 - iou_coef: 0.3793 - loss: 0.4502
# Epoch 7: val_dice_coef did not improve from 0.50369
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 753ms/step - accuracy: 0.5588 - dice_coef: 0.5612 - iou_coef: 0.3903 - loss: 0.4388 - val_accuracy: 0.4232 - val_dice_coef: 0.4965 - val_iou_coef: 0.3302 - val_loss: 0.5035 - learning_rate: 5.0000e-05
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.5802 - dice_coef: 0.5684 - iou_coef: 0.3972 - loss: 0.4316
# Epoch 8: val_dice_coef improved from 0.50369 to 0.50453, saving model to best_unet.keras
#
# Epoch 8: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.5760 - dice_coef: 0.5698 - iou_coef: 0.3986 - loss: 0.4302 - val_accuracy: 0.4221 - val_dice_coef: 0.5045 - val_iou_coef: 0.3374 - val_loss: 0.4955 - learning_rate: 5.0000e-05
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.5927 - dice_coef: 0.5702 - iou_coef: 0.3989 - loss: 0.4298
# Epoch 9: val_dice_coef improved from 0.50453 to 0.51215, saving model to best_unet.keras
#
# Epoch 9: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.5853 - dice_coef: 0.5751 - iou_coef: 0.4037 - loss: 0.4249 - val_accuracy: 0.4281 - val_dice_coef: 0.5122 - val_iou_coef: 0.3442 - val_loss: 0.4878 - learning_rate: 5.0000e-05
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.6071 - dice_coef: 0.5863 - iou_coef: 0.4147 - loss: 0.4137
# Epoch 10: val_dice_coef improved from 0.51215 to 0.51946, saving model to best_unet.keras
#
# Epoch 10: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6040 - dice_coef: 0.5862 - iou_coef: 0.4147 - loss: 0.4138 - val_accuracy: 0.4373 - val_dice_coef: 0.5195 - val_iou_coef: 0.3509 - val_loss: 0.4805 - learning_rate: 5.0000e-05
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.6037 - dice_coef: 0.5951 - iou_coef: 0.4236 - loss: 0.4049
# Epoch 11: val_dice_coef improved from 0.51946 to 0.52625, saving model to best_unet.keras
#
# Epoch 11: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6151 - dice_coef: 0.5960 - iou_coef: 0.4245 - loss: 0.4040 - val_accuracy: 0.4554 - val_dice_coef: 0.5262 - val_iou_coef: 0.3571 - val_loss: 0.4738 - learning_rate: 5.0000e-05
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 631ms/step - accuracy: 0.6426 - dice_coef: 0.6097 - iou_coef: 0.4387 - loss: 0.3903
# Epoch 12: val_dice_coef improved from 0.52625 to 0.53306, saving model to best_unet.keras
#
# Epoch 12: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6225 - dice_coef: 0.5999 - iou_coef: 0.4289 - loss: 0.4001 - val_accuracy: 0.4940 - val_dice_coef: 0.5331 - val_iou_coef: 0.3634 - val_loss: 0.4669 - learning_rate: 5.0000e-05
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.6358 - dice_coef: 0.6171 - iou_coef: 0.4467 - loss: 0.3829
# Epoch 13: val_dice_coef improved from 0.53306 to 0.53958, saving model to best_unet.keras
#
# Epoch 13: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6273 - dice_coef: 0.6024 - iou_coef: 0.4314 - loss: 0.3976 - val_accuracy: 0.5373 - val_dice_coef: 0.5396 - val_iou_coef: 0.3695 - val_loss: 0.4604 - learning_rate: 5.0000e-05
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 657ms/step - accuracy: 0.6416 - dice_coef: 0.6148 - iou_coef: 0.4439 - loss: 0.3852
# Epoch 14: val_dice_coef improved from 0.53958 to 0.54619, saving model to best_unet.keras
#
# Epoch 14: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.6368 - dice_coef: 0.6087 - iou_coef: 0.4377 - loss: 0.3913 - val_accuracy: 0.5617 - val_dice_coef: 0.5462 - val_iou_coef: 0.3757 - val_loss: 0.4538 - learning_rate: 5.0000e-05
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step - accuracy: 0.6271 - dice_coef: 0.6080 - iou_coef: 0.4373 - loss: 0.3920
# Epoch 15: val_dice_coef improved from 0.54619 to 0.55285, saving model to best_unet.keras
#
# Epoch 15: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6429 - dice_coef: 0.6137 - iou_coef: 0.4431 - loss: 0.3863 - val_accuracy: 0.5730 - val_dice_coef: 0.5528 - val_iou_coef: 0.3820 - val_loss: 0.4472 - learning_rate: 5.0000e-05
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 632ms/step - accuracy: 0.6351 - dice_coef: 0.6136 - iou_coef: 0.4429 - loss: 0.3864
# Epoch 16: val_dice_coef improved from 0.55285 to 0.55962, saving model to best_unet.keras
#
# Epoch 16: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6624 - dice_coef: 0.6277 - iou_coef: 0.4579 - loss: 0.3723 - val_accuracy: 0.5787 - val_dice_coef: 0.5596 - val_iou_coef: 0.3885 - val_loss: 0.4404 - learning_rate: 5.0000e-05
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6743 - dice_coef: 0.6205 - iou_coef: 0.4500 - loss: 0.3795
# Epoch 17: val_dice_coef improved from 0.55962 to 0.56716, saving model to best_unet.keras
#
# Epoch 17: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6716 - dice_coef: 0.6321 - iou_coef: 0.4623 - loss: 0.3679 - val_accuracy: 0.5820 - val_dice_coef: 0.5672 - val_iou_coef: 0.3958 - val_loss: 0.4328 - learning_rate: 5.0000e-05
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 802ms/step - accuracy: 0.6737 - dice_coef: 0.6372 - iou_coef: 0.4676 - loss: 0.3628
# Epoch 18: val_dice_coef improved from 0.56716 to 0.57475, saving model to best_unet.keras
#
# Epoch 18: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.6795 - dice_coef: 0.6415 - iou_coef: 0.4724 - loss: 0.3585 - val_accuracy: 0.5843 - val_dice_coef: 0.5748 - val_iou_coef: 0.4033 - val_loss: 0.4252 - learning_rate: 5.0000e-05
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.6560 - dice_coef: 0.6284 - iou_coef: 0.4586 - loss: 0.3716
# Epoch 19: val_dice_coef improved from 0.57475 to 0.58219, saving model to best_unet.keras
#
# Epoch 19: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6825 - dice_coef: 0.6449 - iou_coef: 0.4768 - loss: 0.3551 - val_accuracy: 0.5863 - val_dice_coef: 0.5822 - val_iou_coef: 0.4106 - val_loss: 0.4178 - learning_rate: 5.0000e-05
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step - accuracy: 0.7022 - dice_coef: 0.6531 - iou_coef: 0.4852 - loss: 0.3469
# Epoch 20: val_dice_coef improved from 0.58219 to 0.58989, saving model to best_unet.keras
#
# Epoch 20: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6959 - dice_coef: 0.6548 - iou_coef: 0.4872 - loss: 0.3452 - val_accuracy: 0.5878 - val_dice_coef: 0.5899 - val_iou_coef: 0.4183 - val_loss: 0.4101 - learning_rate: 5.0000e-05
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.6825 - dice_coef: 0.6606 - iou_coef: 0.4932 - loss: 0.3394
# Epoch 21: val_dice_coef improved from 0.58989 to 0.59735, saving model to best_unet.keras
#
# Epoch 21: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6883 - dice_coef: 0.6562 - iou_coef: 0.4884 - loss: 0.3438 - val_accuracy: 0.5890 - val_dice_coef: 0.5974 - val_iou_coef: 0.4259 - val_loss: 0.4026 - learning_rate: 5.0000e-05
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7089 - dice_coef: 0.6614 - iou_coef: 0.4944 - loss: 0.3386
# Epoch 22: val_dice_coef improved from 0.59735 to 0.60474, saving model to best_unet.keras
#
# Epoch 22: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.6921 - dice_coef: 0.6582 - iou_coef: 0.4909 - loss: 0.3418 - val_accuracy: 0.5903 - val_dice_coef: 0.6047 - val_iou_coef: 0.4334 - val_loss: 0.3953 - learning_rate: 5.0000e-05
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - accuracy: 0.6888 - dice_coef: 0.6598 - iou_coef: 0.4923 - loss: 0.3402
# Epoch 23: val_dice_coef improved from 0.60474 to 0.61183, saving model to best_unet.keras
#
# Epoch 23: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 7s 909ms/step - accuracy: 0.6935 - dice_coef: 0.6579 - iou_coef: 0.4902 - loss: 0.3421 - val_accuracy: 0.5915 - val_dice_coef: 0.6118 - val_iou_coef: 0.4407 - val_loss: 0.3882 - learning_rate: 5.0000e-05
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.6990 - dice_coef: 0.6633 - iou_coef: 0.4963 - loss: 0.3367
# Epoch 24: val_dice_coef improved from 0.61183 to 0.61871, saving model to best_unet.keras
#
# Epoch 24: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6984 - dice_coef: 0.6685 - iou_coef: 0.5022 - loss: 0.3315 - val_accuracy: 0.5921 - val_dice_coef: 0.6187 - val_iou_coef: 0.4479 - val_loss: 0.3813 - learning_rate: 5.0000e-05
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.6626 - dice_coef: 0.6543 - iou_coef: 0.4866 - loss: 0.3457
# Epoch 25: val_dice_coef improved from 0.61871 to 0.62533, saving model to best_unet.keras
#
# Epoch 25: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6955 - dice_coef: 0.6684 - iou_coef: 0.5025 - loss: 0.3316 - val_accuracy: 0.5931 - val_dice_coef: 0.6253 - val_iou_coef: 0.4549 - val_loss: 0.3747 - learning_rate: 5.0000e-05
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.6854 - dice_coef: 0.6630 - iou_coef: 0.4962 - loss: 0.3370
# Epoch 26: val_dice_coef improved from 0.62533 to 0.63175, saving model to best_unet.keras
#
# Epoch 26: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7035 - dice_coef: 0.6752 - iou_coef: 0.5103 - loss: 0.3248 - val_accuracy: 0.5939 - val_dice_coef: 0.6318 - val_iou_coef: 0.4617 - val_loss: 0.3682 - learning_rate: 5.0000e-05
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.6954 - dice_coef: 0.6837 - iou_coef: 0.5196 - loss: 0.3163
# Epoch 27: val_dice_coef improved from 0.63175 to 0.63774, saving model to best_unet.keras
#
# Epoch 27: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7010 - dice_coef: 0.6733 - iou_coef: 0.5078 - loss: 0.3267 - val_accuracy: 0.5949 - val_dice_coef: 0.6377 - val_iou_coef: 0.4682 - val_loss: 0.3623 - learning_rate: 5.0000e-05
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 851ms/step - accuracy: 0.7042 - dice_coef: 0.6790 - iou_coef: 0.5143 - loss: 0.3210
# Epoch 28: val_dice_coef improved from 0.63774 to 0.64305, saving model to best_unet.keras
#
# Epoch 28: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.7115 - dice_coef: 0.6815 - iou_coef: 0.5174 - loss: 0.3185 - val_accuracy: 0.5961 - val_dice_coef: 0.6430 - val_iou_coef: 0.4739 - val_loss: 0.3570 - learning_rate: 5.0000e-05
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.6916 - dice_coef: 0.6803 - iou_coef: 0.5156 - loss: 0.3197
# Epoch 29: val_dice_coef improved from 0.64305 to 0.64752, saving model to best_unet.keras
#
# Epoch 29: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6949 - dice_coef: 0.6749 - iou_coef: 0.5095 - loss: 0.3251 - val_accuracy: 0.5976 - val_dice_coef: 0.6475 - val_iou_coef: 0.4788 - val_loss: 0.3525 - learning_rate: 5.0000e-05
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.7091 - dice_coef: 0.6701 - iou_coef: 0.5038 - loss: 0.3299
# Epoch 30: val_dice_coef improved from 0.64752 to 0.65169, saving model to best_unet.keras
#
# Epoch 30: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6952 - dice_coef: 0.6744 - iou_coef: 0.5088 - loss: 0.3256 - val_accuracy: 0.5992 - val_dice_coef: 0.6517 - val_iou_coef: 0.4833 - val_loss: 0.3483 - learning_rate: 5.0000e-05
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.6976 - dice_coef: 0.6821 - iou_coef: 0.5177 - loss: 0.3179
# Epoch 31: val_dice_coef improved from 0.65169 to 0.65507, saving model to best_unet.keras
#
# Epoch 31: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 992ms/step - accuracy: 0.7148 - dice_coef: 0.6898 - iou_coef: 0.5266 - loss: 0.3102 - val_accuracy: 0.6012 - val_dice_coef: 0.6551 - val_iou_coef: 0.4871 - val_loss: 0.3449 - learning_rate: 5.0000e-05
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.7367 - dice_coef: 0.7017 - iou_coef: 0.5407 - loss: 0.2983
# Epoch 32: val_dice_coef improved from 0.65507 to 0.65823, saving model to best_unet.keras
#
# Epoch 32: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.7210 - dice_coef: 0.6937 - iou_coef: 0.5312 - loss: 0.3063 - val_accuracy: 0.6032 - val_dice_coef: 0.6582 - val_iou_coef: 0.4906 - val_loss: 0.3418 - learning_rate: 5.0000e-05
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - accuracy: 0.7090 - dice_coef: 0.6884 - iou_coef: 0.5249 - loss: 0.3116
# Epoch 33: val_dice_coef improved from 0.65823 to 0.66075, saving model to best_unet.keras
#
# Epoch 33: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7177 - dice_coef: 0.6941 - iou_coef: 0.5316 - loss: 0.3059 - val_accuracy: 0.6056 - val_dice_coef: 0.6608 - val_iou_coef: 0.4934 - val_loss: 0.3392 - learning_rate: 5.0000e-05
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 628ms/step - accuracy: 0.7289 - dice_coef: 0.6926 - iou_coef: 0.5298 - loss: 0.3074
# Epoch 34: val_dice_coef improved from 0.66075 to 0.66332, saving model to best_unet.keras
#
# Epoch 34: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7232 - dice_coef: 0.6981 - iou_coef: 0.5362 - loss: 0.3019 - val_accuracy: 0.6082 - val_dice_coef: 0.6633 - val_iou_coef: 0.4962 - val_loss: 0.3367 - learning_rate: 5.0000e-05
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.7528 - dice_coef: 0.7139 - iou_coef: 0.5566 - loss: 0.2861
# Epoch 35: val_dice_coef improved from 0.66332 to 0.66568, saving model to best_unet.keras
#
# Epoch 35: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7271 - dice_coef: 0.6987 - iou_coef: 0.5383 - loss: 0.3013 - val_accuracy: 0.6108 - val_dice_coef: 0.6657 - val_iou_coef: 0.4989 - val_loss: 0.3343 - learning_rate: 5.0000e-05
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 900ms/step - accuracy: 0.7140 - dice_coef: 0.6881 - iou_coef: 0.5246 - loss: 0.3119
# Epoch 36: val_dice_coef improved from 0.66568 to 0.66777, saving model to best_unet.keras
#
# Epoch 36: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7114 - dice_coef: 0.6935 - iou_coef: 0.5311 - loss: 0.3065 - val_accuracy: 0.6135 - val_dice_coef: 0.6678 - val_iou_coef: 0.5012 - val_loss: 0.3322 - learning_rate: 5.0000e-05
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.7228 - dice_coef: 0.7012 - iou_coef: 0.5399 - loss: 0.2988
# Epoch 37: val_dice_coef improved from 0.66777 to 0.66972, saving model to best_unet.keras
#
# Epoch 37: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 995ms/step - accuracy: 0.7314 - dice_coef: 0.7029 - iou_coef: 0.5420 - loss: 0.2971 - val_accuracy: 0.6165 - val_dice_coef: 0.6697 - val_iou_coef: 0.5034 - val_loss: 0.3303 - learning_rate: 5.0000e-05
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - accuracy: 0.7544 - dice_coef: 0.7246 - iou_coef: 0.5689 - loss: 0.2754
# Epoch 38: val_dice_coef improved from 0.66972 to 0.67164, saving model to best_unet.keras
#
# Epoch 38: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7275 - dice_coef: 0.7043 - iou_coef: 0.5446 - loss: 0.2957 - val_accuracy: 0.6195 - val_dice_coef: 0.6716 - val_iou_coef: 0.5056 - val_loss: 0.3284 - learning_rate: 5.0000e-05
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.7426 - dice_coef: 0.7152 - iou_coef: 0.5567 - loss: 0.2848
# Epoch 39: val_dice_coef improved from 0.67164 to 0.67346, saving model to best_unet.keras
#
# Epoch 39: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 964ms/step - accuracy: 0.7363 - dice_coef: 0.7121 - iou_coef: 0.5530 - loss: 0.2879 - val_accuracy: 0.6228 - val_dice_coef: 0.6735 - val_iou_coef: 0.5077 - val_loss: 0.3265 - learning_rate: 5.0000e-05
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.7128 - dice_coef: 0.6966 - iou_coef: 0.5348 - loss: 0.3034
# Epoch 40: val_dice_coef improved from 0.67346 to 0.67492, saving model to best_unet.keras
#
# Epoch 40: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7265 - dice_coef: 0.7071 - iou_coef: 0.5476 - loss: 0.2929 - val_accuracy: 0.6263 - val_dice_coef: 0.6749 - val_iou_coef: 0.5093 - val_loss: 0.3251 - learning_rate: 5.0000e-05
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.7347 - dice_coef: 0.7103 - iou_coef: 0.5508 - loss: 0.2897
# Epoch 41: val_dice_coef improved from 0.67492 to 0.67671, saving model to best_unet.keras
#
# Epoch 41: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7452 - dice_coef: 0.7170 - iou_coef: 0.5591 - loss: 0.2830 - val_accuracy: 0.6294 - val_dice_coef: 0.6767 - val_iou_coef: 0.5114 - val_loss: 0.3233 - learning_rate: 5.0000e-05
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step - accuracy: 0.7363 - dice_coef: 0.7065 - iou_coef: 0.5462 - loss: 0.2935
# Epoch 42: val_dice_coef improved from 0.67671 to 0.67923, saving model to best_unet.keras
#
# Epoch 42: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7262 - dice_coef: 0.7076 - iou_coef: 0.5476 - loss: 0.2924 - val_accuracy: 0.6322 - val_dice_coef: 0.6792 - val_iou_coef: 0.5143 - val_loss: 0.3208 - learning_rate: 5.0000e-05
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.7430 - dice_coef: 0.7207 - iou_coef: 0.5634 - loss: 0.2793
# Epoch 43: val_dice_coef improved from 0.67923 to 0.68148, saving model to best_unet.keras
#
# Epoch 43: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 955ms/step - accuracy: 0.7439 - dice_coef: 0.7178 - iou_coef: 0.5600 - loss: 0.2822 - val_accuracy: 0.6351 - val_dice_coef: 0.6815 - val_iou_coef: 0.5168 - val_loss: 0.3185 - learning_rate: 5.0000e-05
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.7543 - dice_coef: 0.7250 - iou_coef: 0.5691 - loss: 0.2750
# Epoch 44: val_dice_coef improved from 0.68148 to 0.68381, saving model to best_unet.keras
#
# Epoch 44: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7397 - dice_coef: 0.7158 - iou_coef: 0.5578 - loss: 0.2842 - val_accuracy: 0.6379 - val_dice_coef: 0.6838 - val_iou_coef: 0.5195 - val_loss: 0.3162 - learning_rate: 5.0000e-05
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 611ms/step - accuracy: 0.7202 - dice_coef: 0.7091 - iou_coef: 0.5497 - loss: 0.2909
# Epoch 45: val_dice_coef improved from 0.68381 to 0.68619, saving model to best_unet.keras
#
# Epoch 45: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7436 - dice_coef: 0.7220 - iou_coef: 0.5654 - loss: 0.2780 - val_accuracy: 0.6405 - val_dice_coef: 0.6862 - val_iou_coef: 0.5223 - val_loss: 0.3138 - learning_rate: 5.0000e-05
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - accuracy: 0.7258 - dice_coef: 0.7117 - iou_coef: 0.5528 - loss: 0.2883
# Epoch 46: val_dice_coef improved from 0.68619 to 0.68863, saving model to best_unet.keras
#
# Epoch 46: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7460 - dice_coef: 0.7235 - iou_coef: 0.5671 - loss: 0.2765 - val_accuracy: 0.6429 - val_dice_coef: 0.6886 - val_iou_coef: 0.5251 - val_loss: 0.3114 - learning_rate: 5.0000e-05
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.7613 - dice_coef: 0.7345 - iou_coef: 0.5806 - loss: 0.2655
# Epoch 47: val_dice_coef improved from 0.68863 to 0.69175, saving model to best_unet.keras
#
# Epoch 47: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7452 - dice_coef: 0.7260 - iou_coef: 0.5700 - loss: 0.2740 - val_accuracy: 0.6446 - val_dice_coef: 0.6917 - val_iou_coef: 0.5288 - val_loss: 0.3083 - learning_rate: 5.0000e-05
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.7365 - dice_coef: 0.7271 - iou_coef: 0.5713 - loss: 0.2729
# Epoch 48: val_dice_coef improved from 0.69175 to 0.69332, saving model to best_unet.keras
#
# Epoch 48: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7344 - dice_coef: 0.7200 - iou_coef: 0.5626 - loss: 0.2800 - val_accuracy: 0.6485 - val_dice_coef: 0.6933 - val_iou_coef: 0.5306 - val_loss: 0.3067 - learning_rate: 5.0000e-05
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.7514 - dice_coef: 0.7343 - iou_coef: 0.5802 - loss: 0.2657
# Epoch 49: val_dice_coef improved from 0.69332 to 0.69464, saving model to best_unet.keras
#
# Epoch 49: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.7500 - dice_coef: 0.7289 - iou_coef: 0.5735 - loss: 0.2711 - val_accuracy: 0.6529 - val_dice_coef: 0.6946 - val_iou_coef: 0.5321 - val_loss: 0.3054 - learning_rate: 5.0000e-05
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.7712 - dice_coef: 0.7391 - iou_coef: 0.5864 - loss: 0.2609
# Epoch 50: val_dice_coef improved from 0.69464 to 0.69635, saving model to best_unet.keras
#
# Epoch 50: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 923ms/step - accuracy: 0.7524 - dice_coef: 0.7278 - iou_coef: 0.5728 - loss: 0.2722 - val_accuracy: 0.6574 - val_dice_coef: 0.6964 - val_iou_coef: 0.5342 - val_loss: 0.3036 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 50.
