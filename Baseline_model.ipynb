# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Rock-segmentation/blob/main/Baseline_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model

from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (256, 256)
BATCH_SIZE = 4
EPOCHS = 50
SEED = 42

IMAGE_DIR = "/content/drive/MyDrive/dataset_rock/images"
MASK_DIR  = "/content/drive/MyDrive/dataset_rock/masks"

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

print("Images :", len(os.listdir(IMAGE_DIR)))
print("Masks  :", len(os.listdir(MASK_DIR)))

print(os.listdir(IMAGE_DIR)[:5])
print(os.listdir(MASK_DIR)[:5])
# Out:
# Images : 16
# Masks  : 16
# ['image5.jpg', 'image10.jpg', 'image16.png', 'image1.jpg', 'image4.jpg']
# ['image2.png', 'image7.png', 'image9.png', 'image11.png', 'image3.png']

# %%
def get_pairs(image_dir, mask_dir):
    image_paths = []
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        image_paths.extend(glob.glob(os.path.join(image_dir, f"*.{ext}")))

    image_paths = sorted(image_paths)

    mask_map = {}
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        for p in glob.glob(os.path.join(mask_dir, f"*.{ext}")):
            stem = os.path.splitext(os.path.basename(p))[0]
            mask_map[stem] = p

    pairs = []
    for img_path in image_paths:
        stem = os.path.splitext(os.path.basename(img_path))[0]
        if stem in mask_map:
            pairs.append((img_path, mask_map[stem]))
        else:
            print(f"Warning: no mask found for {img_path}")

    return pairs

pairs = get_pairs(IMAGE_DIR, MASK_DIR)
print("Total paired samples:", len(pairs))

# =========================
# LOAD ONE IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    # Image
    img = cv2.imread(img_path.decode(), cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    # Mask
    mask = cv2.imread(mask_path.decode(), cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")
    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)

    # Binary mask: 0/1
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask

# =========================
# AUGMENTATION
# =========================
def augment(image, mask):
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    k = tf.random.uniform((), minval=0, maxval=4, dtype=tf.int32)
    image = tf.image.rot90(image, k)
    mask = tf.image.rot90(mask, k)

    return image, mask

# =========================
# CREATE DATASET
# =========================

pairs = get_pairs(IMAGE_DIR, MASK_DIR)

print("Total paired samples:", len(pairs))

for img, mask in pairs[:3]:
    print(img)
    print(mask)
    print()
# Out:
# Total paired samples: 16
# Total paired samples: 16
# /content/drive/MyDrive/dataset_rock/images/image1.jpg
# /content/drive/MyDrive/dataset_rock/masks/image1.png
#
# /content/drive/MyDrive/dataset_rock/images/image10.jpg
# /content/drive/MyDrive/dataset_rock/masks/image10.png
#
# /content/drive/MyDrive/dataset_rock/images/image11.png
# /content/drive/MyDrive/dataset_rock/masks/image11.png

# %%
def make_dataset(pairs, training=True):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)

    if training:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

train_pairs, val_pairs = train_test_split(pairs, test_size=0.2, random_state=SEED)

train_ds = make_dataset(train_pairs, training=True)
val_ds = make_dataset(val_pairs, training=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))

# =========================
# METRICS / LOSS
# =========================
def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# =========================
# U-NET BUILDING BLOCKS
# =========================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x

def down_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPool2D((2, 2))(c)
    p = layers.Dropout(0.2)(p)
    return c, p

def up_block(x, skip, filters):
    x = layers.Conv2DTranspose(filters, 2, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip])
    x = layers.Dropout(0.2)(x)
    x = conv_block(x, filters)
    return x

# =========================
# BUILD U-NET
# =========================
def build_unet(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)

    s1, p1 = down_block(inputs, 32)
    s2, p2 = down_block(p1, 64)
    s3, p3 = down_block(p2, 128)
    s4, p4 = down_block(p3, 256)

    bottleneck = conv_block(p4, 512)

    u1 = up_block(bottleneck, s4, 256)
    u2 = up_block(u1, s3, 128)
    u3 = up_block(u2, s2, 64)
    u4 = up_block(u3, s1, 32)

    outputs = layers.Conv2D(1, 1, activation="sigmoid")(u4)

    model = Model(inputs, outputs, name="UNet_Binary")
    return model

model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=dice_loss,
    metrics=["accuracy", dice_coef, iou_coef]
)

model.summary()

# =========================
# CALLBACKS
# =========================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "best_unet.keras",
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# =========================
# TRAIN
# =========================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS: ACCURACY, DICE, IOU
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(18, 5))

    # Accuracy
    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, hist["accuracy"], label="Train Accuracy")
    plt.plot(epochs_range, hist["val_accuracy"], label="Val Accuracy")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    # Dice Score
    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, hist["dice_coef"], label="Train Dice")
    plt.plot(epochs_range, hist["val_dice_coef"], label="Val Dice")
    plt.title("Dice Score Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Dice Coefficient")
    plt.legend()
    plt.grid(True)

    # IoU
    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, hist["iou_coef"], label="Train IoU")
    plt.plot(epochs_range, hist["val_iou_coef"], label="Val IoU")
    plt.title("IoU Curve")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_curves(history)

# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

# Show one validation sample
show_prediction(model, val_pairs[0])
# Out:
# Train samples: 12
# Val samples: 4
# Model: "UNet_Binary"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,248 │ re_lu[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,496 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,928 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ re_lu_3[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,856 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,584 │ re_lu_4[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ re_lu_5[0][0]     │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    295,168 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    590,080 │ re_lu_6[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ re_lu_7[0][0]     │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ dropout_3[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ re_lu_8[0][0]     │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    524,544 │ re_lu_9[0][0]     │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 32,    │          0 │ concatenate[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_10[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    131,200 │ re_lu_11[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 64,    │          0 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    295,040 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_12[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     32,832 │ re_lu_13[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128, 128,  │          0 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     73,792 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_14[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      8,224 │ re_lu_15[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256, 256,  │          0 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     18,464 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_16[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         33 │ re_lu_17[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,771,873 (29.65 MB)
#  Trainable params: 7,765,985 (29.62 MB)
#  Non-trainable params: 5,888 (23.00 KB)
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.3593 - dice_coef: 0.4471 - iou_coef: 0.2880 - loss: 0.5529
# Epoch 1: val_dice_coef improved from None to 0.50368, saving model to best_unet.keras
#
# Epoch 1: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 65s 3s/step - accuracy: 0.3656 - dice_coef: 0.4488 - iou_coef: 0.2894 - loss: 0.5512 - val_accuracy: 0.4410 - val_dice_coef: 0.5037 - val_iou_coef: 0.3366 - val_loss: 0.4963 - learning_rate: 1.0000e-04
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.3959 - dice_coef: 0.4660 - iou_coef: 0.3038 - loss: 0.5340
# Epoch 2: val_dice_coef did not improve from 0.50368
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.3980 - dice_coef: 0.4684 - iou_coef: 0.3059 - loss: 0.5316 - val_accuracy: 0.4446 - val_dice_coef: 0.5009 - val_iou_coef: 0.3341 - val_loss: 0.4991 - learning_rate: 1.0000e-04
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 852ms/step - accuracy: 0.4369 - dice_coef: 0.4818 - iou_coef: 0.3175 - loss: 0.5182
# Epoch 3: val_dice_coef did not improve from 0.50368
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.4378 - dice_coef: 0.4921 - iou_coef: 0.3265 - loss: 0.5079 - val_accuracy: 0.4404 - val_dice_coef: 0.4960 - val_iou_coef: 0.3298 - val_loss: 0.5040 - learning_rate: 1.0000e-04
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.4675 - dice_coef: 0.5141 - iou_coef: 0.3461 - loss: 0.4859
# Epoch 4: val_dice_coef did not improve from 0.50368
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 697ms/step - accuracy: 0.4752 - dice_coef: 0.5134 - iou_coef: 0.3455 - loss: 0.4866 - val_accuracy: 0.4356 - val_dice_coef: 0.4902 - val_iou_coef: 0.3247 - val_loss: 0.5098 - learning_rate: 1.0000e-04
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.5141 - dice_coef: 0.5278 - iou_coef: 0.3586 - loss: 0.4722
# Epoch 5: val_dice_coef did not improve from 0.50368
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 660ms/step - accuracy: 0.5192 - dice_coef: 0.5366 - iou_coef: 0.3670 - loss: 0.4634 - val_accuracy: 0.4315 - val_dice_coef: 0.4846 - val_iou_coef: 0.3198 - val_loss: 0.5154 - learning_rate: 1.0000e-04
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - accuracy: 0.5582 - dice_coef: 0.5494 - iou_coef: 0.3788 - loss: 0.4506
# Epoch 6: val_dice_coef did not improve from 0.50368
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 772ms/step - accuracy: 0.5443 - dice_coef: 0.5540 - iou_coef: 0.3832 - loss: 0.4460 - val_accuracy: 0.4273 - val_dice_coef: 0.4898 - val_iou_coef: 0.3244 - val_loss: 0.5102 - learning_rate: 5.0000e-05
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.5501 - dice_coef: 0.5498 - iou_coef: 0.3793 - loss: 0.4502
# Epoch 7: val_dice_coef did not improve from 0.50368
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 775ms/step - accuracy: 0.5587 - dice_coef: 0.5612 - iou_coef: 0.3903 - loss: 0.4388 - val_accuracy: 0.4233 - val_dice_coef: 0.4962 - val_iou_coef: 0.3299 - val_loss: 0.5038 - learning_rate: 5.0000e-05
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - accuracy: 0.5802 - dice_coef: 0.5684 - iou_coef: 0.3972 - loss: 0.4316
# Epoch 8: val_dice_coef improved from 0.50368 to 0.50427, saving model to best_unet.keras
#
# Epoch 8: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.5760 - dice_coef: 0.5698 - iou_coef: 0.3986 - loss: 0.4302 - val_accuracy: 0.4221 - val_dice_coef: 0.5043 - val_iou_coef: 0.3371 - val_loss: 0.4957 - learning_rate: 5.0000e-05
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.5927 - dice_coef: 0.5702 - iou_coef: 0.3989 - loss: 0.4298
# Epoch 9: val_dice_coef improved from 0.50427 to 0.51195, saving model to best_unet.keras
#
# Epoch 9: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.5852 - dice_coef: 0.5751 - iou_coef: 0.4037 - loss: 0.4249 - val_accuracy: 0.4282 - val_dice_coef: 0.5120 - val_iou_coef: 0.3440 - val_loss: 0.4880 - learning_rate: 5.0000e-05
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.6073 - dice_coef: 0.5862 - iou_coef: 0.4146 - loss: 0.4138
# Epoch 10: val_dice_coef improved from 0.51195 to 0.51930, saving model to best_unet.keras
#
# Epoch 10: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6043 - dice_coef: 0.5861 - iou_coef: 0.4146 - loss: 0.4139 - val_accuracy: 0.4370 - val_dice_coef: 0.5193 - val_iou_coef: 0.3507 - val_loss: 0.4807 - learning_rate: 5.0000e-05
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.6039 - dice_coef: 0.5953 - iou_coef: 0.4238 - loss: 0.4047
# Epoch 11: val_dice_coef improved from 0.51930 to 0.52612, saving model to best_unet.keras
#
# Epoch 11: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.6153 - dice_coef: 0.5962 - iou_coef: 0.4247 - loss: 0.4038 - val_accuracy: 0.4551 - val_dice_coef: 0.5261 - val_iou_coef: 0.3570 - val_loss: 0.4739 - learning_rate: 5.0000e-05
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 781ms/step - accuracy: 0.6424 - dice_coef: 0.6095 - iou_coef: 0.4385 - loss: 0.3905
# Epoch 12: val_dice_coef improved from 0.52612 to 0.53293, saving model to best_unet.keras
#
# Epoch 12: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6226 - dice_coef: 0.6000 - iou_coef: 0.4289 - loss: 0.4000 - val_accuracy: 0.4930 - val_dice_coef: 0.5329 - val_iou_coef: 0.3633 - val_loss: 0.4671 - learning_rate: 5.0000e-05
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.6361 - dice_coef: 0.6173 - iou_coef: 0.4469 - loss: 0.3827
# Epoch 13: val_dice_coef improved from 0.53293 to 0.53943, saving model to best_unet.keras
#
# Epoch 13: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6283 - dice_coef: 0.6028 - iou_coef: 0.4319 - loss: 0.3972 - val_accuracy: 0.5364 - val_dice_coef: 0.5394 - val_iou_coef: 0.3693 - val_loss: 0.4606 - learning_rate: 5.0000e-05
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - accuracy: 0.6415 - dice_coef: 0.6148 - iou_coef: 0.4439 - loss: 0.3852
# Epoch 14: val_dice_coef improved from 0.53943 to 0.54604, saving model to best_unet.keras
#
# Epoch 14: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6368 - dice_coef: 0.6086 - iou_coef: 0.4376 - loss: 0.3914 - val_accuracy: 0.5612 - val_dice_coef: 0.5460 - val_iou_coef: 0.3756 - val_loss: 0.4540 - learning_rate: 5.0000e-05
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 520ms/step - accuracy: 0.6281 - dice_coef: 0.6088 - iou_coef: 0.4381 - loss: 0.3912
# Epoch 15: val_dice_coef improved from 0.54604 to 0.55269, saving model to best_unet.keras
#
# Epoch 15: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.6429 - dice_coef: 0.6139 - iou_coef: 0.4434 - loss: 0.3861 - val_accuracy: 0.5728 - val_dice_coef: 0.5527 - val_iou_coef: 0.3819 - val_loss: 0.4473 - learning_rate: 5.0000e-05
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.6350 - dice_coef: 0.6135 - iou_coef: 0.4427 - loss: 0.3865
# Epoch 16: val_dice_coef improved from 0.55269 to 0.55946, saving model to best_unet.keras
#
# Epoch 16: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6623 - dice_coef: 0.6275 - iou_coef: 0.4577 - loss: 0.3725 - val_accuracy: 0.5787 - val_dice_coef: 0.5595 - val_iou_coef: 0.3884 - val_loss: 0.4405 - learning_rate: 5.0000e-05
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.6743 - dice_coef: 0.6206 - iou_coef: 0.4502 - loss: 0.3794
# Epoch 17: val_dice_coef improved from 0.55946 to 0.56700, saving model to best_unet.keras
#
# Epoch 17: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6717 - dice_coef: 0.6322 - iou_coef: 0.4625 - loss: 0.3678 - val_accuracy: 0.5820 - val_dice_coef: 0.5670 - val_iou_coef: 0.3957 - val_loss: 0.4330 - learning_rate: 5.0000e-05
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - accuracy: 0.6735 - dice_coef: 0.6372 - iou_coef: 0.4676 - loss: 0.3628
# Epoch 18: val_dice_coef improved from 0.56700 to 0.57458, saving model to best_unet.keras
#
# Epoch 18: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6793 - dice_coef: 0.6415 - iou_coef: 0.4724 - loss: 0.3585 - val_accuracy: 0.5843 - val_dice_coef: 0.5746 - val_iou_coef: 0.4031 - val_loss: 0.4254 - learning_rate: 5.0000e-05
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.6559 - dice_coef: 0.6284 - iou_coef: 0.4586 - loss: 0.3716
# Epoch 19: val_dice_coef improved from 0.57458 to 0.58201, saving model to best_unet.keras
#
# Epoch 19: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.6824 - dice_coef: 0.6449 - iou_coef: 0.4768 - loss: 0.3551 - val_accuracy: 0.5863 - val_dice_coef: 0.5820 - val_iou_coef: 0.4104 - val_loss: 0.4180 - learning_rate: 5.0000e-05
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.7022 - dice_coef: 0.6531 - iou_coef: 0.4852 - loss: 0.3469
# Epoch 20: val_dice_coef improved from 0.58201 to 0.58971, saving model to best_unet.keras
#
# Epoch 20: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6960 - dice_coef: 0.6548 - iou_coef: 0.4872 - loss: 0.3452 - val_accuracy: 0.5878 - val_dice_coef: 0.5897 - val_iou_coef: 0.4181 - val_loss: 0.4103 - learning_rate: 5.0000e-05
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.6830 - dice_coef: 0.6608 - iou_coef: 0.4934 - loss: 0.3392
# Epoch 21: val_dice_coef improved from 0.58971 to 0.59717, saving model to best_unet.keras
#
# Epoch 21: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6888 - dice_coef: 0.6564 - iou_coef: 0.4886 - loss: 0.3436 - val_accuracy: 0.5890 - val_dice_coef: 0.5972 - val_iou_coef: 0.4257 - val_loss: 0.4028 - learning_rate: 5.0000e-05
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.7089 - dice_coef: 0.6613 - iou_coef: 0.4943 - loss: 0.3387
# Epoch 22: val_dice_coef improved from 0.59717 to 0.60458, saving model to best_unet.keras
#
# Epoch 22: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6921 - dice_coef: 0.6582 - iou_coef: 0.4908 - loss: 0.3418 - val_accuracy: 0.5904 - val_dice_coef: 0.6046 - val_iou_coef: 0.4333 - val_loss: 0.3954 - learning_rate: 5.0000e-05
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 622ms/step - accuracy: 0.6888 - dice_coef: 0.6597 - iou_coef: 0.4923 - loss: 0.3403
# Epoch 23: val_dice_coef improved from 0.60458 to 0.61169, saving model to best_unet.keras
#
# Epoch 23: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.6935 - dice_coef: 0.6578 - iou_coef: 0.4902 - loss: 0.3422 - val_accuracy: 0.5915 - val_dice_coef: 0.6117 - val_iou_coef: 0.4406 - val_loss: 0.3883 - learning_rate: 5.0000e-05
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - accuracy: 0.6990 - dice_coef: 0.6632 - iou_coef: 0.4963 - loss: 0.3368
# Epoch 24: val_dice_coef improved from 0.61169 to 0.61859, saving model to best_unet.keras
#
# Epoch 24: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6983 - dice_coef: 0.6684 - iou_coef: 0.5021 - loss: 0.3316 - val_accuracy: 0.5921 - val_dice_coef: 0.6186 - val_iou_coef: 0.4478 - val_loss: 0.3814 - learning_rate: 5.0000e-05
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.6624 - dice_coef: 0.6542 - iou_coef: 0.4864 - loss: 0.3458
# Epoch 25: val_dice_coef improved from 0.61859 to 0.62523, saving model to best_unet.keras
#
# Epoch 25: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6953 - dice_coef: 0.6684 - iou_coef: 0.5026 - loss: 0.3316 - val_accuracy: 0.5930 - val_dice_coef: 0.6252 - val_iou_coef: 0.4548 - val_loss: 0.3748 - learning_rate: 5.0000e-05
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.6853 - dice_coef: 0.6630 - iou_coef: 0.4962 - loss: 0.3370
# Epoch 26: val_dice_coef improved from 0.62523 to 0.63169, saving model to best_unet.keras
#
# Epoch 26: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7035 - dice_coef: 0.6751 - iou_coef: 0.5103 - loss: 0.3249 - val_accuracy: 0.5938 - val_dice_coef: 0.6317 - val_iou_coef: 0.4617 - val_loss: 0.3683 - learning_rate: 5.0000e-05
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - accuracy: 0.6966 - dice_coef: 0.6842 - iou_coef: 0.5202 - loss: 0.3158
# Epoch 27: val_dice_coef improved from 0.63169 to 0.63769, saving model to best_unet.keras
#
# Epoch 27: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.7016 - dice_coef: 0.6736 - iou_coef: 0.5081 - loss: 0.3264 - val_accuracy: 0.5949 - val_dice_coef: 0.6377 - val_iou_coef: 0.4681 - val_loss: 0.3623 - learning_rate: 5.0000e-05
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.7044 - dice_coef: 0.6792 - iou_coef: 0.5146 - loss: 0.3208
# Epoch 28: val_dice_coef improved from 0.63769 to 0.64301, saving model to best_unet.keras
#
# Epoch 28: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7118 - dice_coef: 0.6820 - iou_coef: 0.5179 - loss: 0.3180 - val_accuracy: 0.5961 - val_dice_coef: 0.6430 - val_iou_coef: 0.4739 - val_loss: 0.3570 - learning_rate: 5.0000e-05
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - accuracy: 0.6917 - dice_coef: 0.6802 - iou_coef: 0.5155 - loss: 0.3198
# Epoch 29: val_dice_coef improved from 0.64301 to 0.64750, saving model to best_unet.keras
#
# Epoch 29: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6949 - dice_coef: 0.6749 - iou_coef: 0.5094 - loss: 0.3251 - val_accuracy: 0.5976 - val_dice_coef: 0.6475 - val_iou_coef: 0.4787 - val_loss: 0.3525 - learning_rate: 5.0000e-05
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.7091 - dice_coef: 0.6700 - iou_coef: 0.5037 - loss: 0.3300
# Epoch 30: val_dice_coef improved from 0.64750 to 0.65169, saving model to best_unet.keras
#
# Epoch 30: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6952 - dice_coef: 0.6743 - iou_coef: 0.5087 - loss: 0.3257 - val_accuracy: 0.5992 - val_dice_coef: 0.6517 - val_iou_coef: 0.4833 - val_loss: 0.3483 - learning_rate: 5.0000e-05
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - accuracy: 0.6993 - dice_coef: 0.6835 - iou_coef: 0.5193 - loss: 0.3165
# Epoch 31: val_dice_coef improved from 0.65169 to 0.65505, saving model to best_unet.keras
#
# Epoch 31: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.7159 - dice_coef: 0.6909 - iou_coef: 0.5278 - loss: 0.3091 - val_accuracy: 0.6012 - val_dice_coef: 0.6550 - val_iou_coef: 0.4870 - val_loss: 0.3450 - learning_rate: 5.0000e-05
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.7366 - dice_coef: 0.7017 - iou_coef: 0.5406 - loss: 0.2983
# Epoch 32: val_dice_coef improved from 0.65505 to 0.65821, saving model to best_unet.keras
#
# Epoch 32: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7209 - dice_coef: 0.6936 - iou_coef: 0.5311 - loss: 0.3064 - val_accuracy: 0.6033 - val_dice_coef: 0.6582 - val_iou_coef: 0.4905 - val_loss: 0.3418 - learning_rate: 5.0000e-05
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.7088 - dice_coef: 0.6884 - iou_coef: 0.5249 - loss: 0.3116
# Epoch 33: val_dice_coef improved from 0.65821 to 0.66071, saving model to best_unet.keras
#
# Epoch 33: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7175 - dice_coef: 0.6941 - iou_coef: 0.5316 - loss: 0.3059 - val_accuracy: 0.6057 - val_dice_coef: 0.6607 - val_iou_coef: 0.4933 - val_loss: 0.3393 - learning_rate: 5.0000e-05
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.7288 - dice_coef: 0.6925 - iou_coef: 0.5297 - loss: 0.3075
# Epoch 34: val_dice_coef improved from 0.66071 to 0.66326, saving model to best_unet.keras
#
# Epoch 34: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7231 - dice_coef: 0.6980 - iou_coef: 0.5362 - loss: 0.3020 - val_accuracy: 0.6082 - val_dice_coef: 0.6633 - val_iou_coef: 0.4962 - val_loss: 0.3367 - learning_rate: 5.0000e-05
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.7524 - dice_coef: 0.7139 - iou_coef: 0.5566 - loss: 0.2861
# Epoch 35: val_dice_coef improved from 0.66326 to 0.66561, saving model to best_unet.keras
#
# Epoch 35: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7268 - dice_coef: 0.6987 - iou_coef: 0.5383 - loss: 0.3013 - val_accuracy: 0.6108 - val_dice_coef: 0.6656 - val_iou_coef: 0.4988 - val_loss: 0.3344 - learning_rate: 5.0000e-05
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 771ms/step - accuracy: 0.7139 - dice_coef: 0.6880 - iou_coef: 0.5245 - loss: 0.3120
# Epoch 36: val_dice_coef improved from 0.66561 to 0.66769, saving model to best_unet.keras
#
# Epoch 36: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7114 - dice_coef: 0.6935 - iou_coef: 0.5311 - loss: 0.3065 - val_accuracy: 0.6136 - val_dice_coef: 0.6677 - val_iou_coef: 0.5011 - val_loss: 0.3323 - learning_rate: 5.0000e-05
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step - accuracy: 0.7225 - dice_coef: 0.7013 - iou_coef: 0.5400 - loss: 0.2987
# Epoch 37: val_dice_coef improved from 0.66769 to 0.66961, saving model to best_unet.keras
#
# Epoch 37: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7307 - dice_coef: 0.7027 - iou_coef: 0.5418 - loss: 0.2973 - val_accuracy: 0.6166 - val_dice_coef: 0.6696 - val_iou_coef: 0.5033 - val_loss: 0.3304 - learning_rate: 5.0000e-05
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7540 - dice_coef: 0.7247 - iou_coef: 0.5691 - loss: 0.2753
# Epoch 38: val_dice_coef improved from 0.66961 to 0.67151, saving model to best_unet.keras
#
# Epoch 38: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7271 - dice_coef: 0.7044 - iou_coef: 0.5446 - loss: 0.2956 - val_accuracy: 0.6195 - val_dice_coef: 0.6715 - val_iou_coef: 0.5055 - val_loss: 0.3285 - learning_rate: 5.0000e-05
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 767ms/step - accuracy: 0.7424 - dice_coef: 0.7151 - iou_coef: 0.5566 - loss: 0.2849
# Epoch 39: val_dice_coef improved from 0.67151 to 0.67330, saving model to best_unet.keras
#
# Epoch 39: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7360 - dice_coef: 0.7120 - iou_coef: 0.5528 - loss: 0.2880 - val_accuracy: 0.6228 - val_dice_coef: 0.6733 - val_iou_coef: 0.5075 - val_loss: 0.3267 - learning_rate: 5.0000e-05
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 687ms/step - accuracy: 0.7127 - dice_coef: 0.6965 - iou_coef: 0.5347 - loss: 0.3035
# Epoch 40: val_dice_coef improved from 0.67330 to 0.67471, saving model to best_unet.keras
#
# Epoch 40: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7264 - dice_coef: 0.7071 - iou_coef: 0.5475 - loss: 0.2929 - val_accuracy: 0.6263 - val_dice_coef: 0.6747 - val_iou_coef: 0.5091 - val_loss: 0.3253 - learning_rate: 5.0000e-05
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.7346 - dice_coef: 0.7102 - iou_coef: 0.5507 - loss: 0.2898
# Epoch 41: val_dice_coef improved from 0.67471 to 0.67644, saving model to best_unet.keras
#
# Epoch 41: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 993ms/step - accuracy: 0.7451 - dice_coef: 0.7169 - iou_coef: 0.5590 - loss: 0.2831 - val_accuracy: 0.6294 - val_dice_coef: 0.6764 - val_iou_coef: 0.5111 - val_loss: 0.3236 - learning_rate: 5.0000e-05
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 526ms/step - accuracy: 0.7360 - dice_coef: 0.7064 - iou_coef: 0.5461 - loss: 0.2936
# Epoch 42: val_dice_coef improved from 0.67644 to 0.67892, saving model to best_unet.keras
#
# Epoch 42: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7260 - dice_coef: 0.7075 - iou_coef: 0.5475 - loss: 0.2925 - val_accuracy: 0.6322 - val_dice_coef: 0.6789 - val_iou_coef: 0.5139 - val_loss: 0.3211 - learning_rate: 5.0000e-05
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.7430 - dice_coef: 0.7206 - iou_coef: 0.5634 - loss: 0.2794
# Epoch 43: val_dice_coef improved from 0.67892 to 0.68113, saving model to best_unet.keras
#
# Epoch 43: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7439 - dice_coef: 0.7178 - iou_coef: 0.5599 - loss: 0.2822 - val_accuracy: 0.6351 - val_dice_coef: 0.6811 - val_iou_coef: 0.5165 - val_loss: 0.3189 - learning_rate: 5.0000e-05
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 501ms/step - accuracy: 0.7544 - dice_coef: 0.7251 - iou_coef: 0.5692 - loss: 0.2749
# Epoch 44: val_dice_coef improved from 0.68113 to 0.68348, saving model to best_unet.keras
#
# Epoch 44: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7398 - dice_coef: 0.7158 - iou_coef: 0.5578 - loss: 0.2842 - val_accuracy: 0.6380 - val_dice_coef: 0.6835 - val_iou_coef: 0.5192 - val_loss: 0.3165 - learning_rate: 5.0000e-05
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.7188 - dice_coef: 0.7083 - iou_coef: 0.5487 - loss: 0.2917
# Epoch 45: val_dice_coef improved from 0.68348 to 0.68590, saving model to best_unet.keras
#
# Epoch 45: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7428 - dice_coef: 0.7214 - iou_coef: 0.5646 - loss: 0.2786 - val_accuracy: 0.6404 - val_dice_coef: 0.6859 - val_iou_coef: 0.5220 - val_loss: 0.3141 - learning_rate: 5.0000e-05
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.7257 - dice_coef: 0.7117 - iou_coef: 0.5527 - loss: 0.2883
# Epoch 46: val_dice_coef improved from 0.68590 to 0.68840, saving model to best_unet.keras
#
# Epoch 46: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7461 - dice_coef: 0.7235 - iou_coef: 0.5671 - loss: 0.2765 - val_accuracy: 0.6428 - val_dice_coef: 0.6884 - val_iou_coef: 0.5249 - val_loss: 0.3116 - learning_rate: 5.0000e-05
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 781ms/step - accuracy: 0.7613 - dice_coef: 0.7345 - iou_coef: 0.5806 - loss: 0.2655
# Epoch 47: val_dice_coef improved from 0.68840 to 0.69153, saving model to best_unet.keras
#
# Epoch 47: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7451 - dice_coef: 0.7259 - iou_coef: 0.5700 - loss: 0.2741 - val_accuracy: 0.6445 - val_dice_coef: 0.6915 - val_iou_coef: 0.5285 - val_loss: 0.3085 - learning_rate: 5.0000e-05
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.7362 - dice_coef: 0.7270 - iou_coef: 0.5711 - loss: 0.2730
# Epoch 48: val_dice_coef improved from 0.69153 to 0.69314, saving model to best_unet.keras
#
# Epoch 48: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7343 - dice_coef: 0.7199 - iou_coef: 0.5625 - loss: 0.2801 - val_accuracy: 0.6484 - val_dice_coef: 0.6931 - val_iou_coef: 0.5304 - val_loss: 0.3069 - learning_rate: 5.0000e-05
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.7511 - dice_coef: 0.7341 - iou_coef: 0.5800 - loss: 0.2659
# Epoch 49: val_dice_coef improved from 0.69314 to 0.69445, saving model to best_unet.keras
#
# Epoch 49: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7495 - dice_coef: 0.7286 - iou_coef: 0.5732 - loss: 0.2714 - val_accuracy: 0.6529 - val_dice_coef: 0.6945 - val_iou_coef: 0.5319 - val_loss: 0.3055 - learning_rate: 5.0000e-05
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - accuracy: 0.7714 - dice_coef: 0.7392 - iou_coef: 0.5866 - loss: 0.2608
# Epoch 50: val_dice_coef improved from 0.69445 to 0.69613, saving model to best_unet.keras
#
# Epoch 50: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7526 - dice_coef: 0.7279 - iou_coef: 0.5728 - loss: 0.2721 - val_accuracy: 0.6576 - val_dice_coef: 0.6961 - val_iou_coef: 0.5339 - val_loss: 0.3039 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 50.
