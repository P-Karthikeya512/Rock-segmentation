# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Rock-segmentation/blob/main/Skip_connections_modified_unet_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model

from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (256, 256)
BATCH_SIZE = 4
EPOCHS = 50
SEED = 42

IMAGE_DIR = "/content/drive/MyDrive/dataset_rock/images"
MASK_DIR  = "/content/drive/MyDrive/dataset_rock/masks"

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

print("Images :", len(os.listdir(IMAGE_DIR)))
print("Masks  :", len(os.listdir(MASK_DIR)))

print(os.listdir(IMAGE_DIR)[:5])
print(os.listdir(MASK_DIR)[:5])
# Out:
# Images : 16
# Masks  : 16
# ['image5.jpg', 'image10.jpg', 'image16.png', 'image1.jpg', 'image4.jpg']
# ['image2.png', 'image7.png', 'image9.png', 'image11.png', 'image3.png']

# %%
def get_pairs(image_dir, mask_dir):
    image_paths = []
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        image_paths.extend(glob.glob(os.path.join(image_dir, f"*.{ext}")))

    image_paths = sorted(image_paths)

    mask_map = {}
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        for p in glob.glob(os.path.join(mask_dir, f"*.{ext}")):
            stem = os.path.splitext(os.path.basename(p))[0]
            mask_map[stem] = p

    pairs = []
    for img_path in image_paths:
        stem = os.path.splitext(os.path.basename(img_path))[0]
        if stem in mask_map:
            pairs.append((img_path, mask_map[stem]))
        else:
            print(f"Warning: no mask found for {img_path}")

    return pairs

pairs = get_pairs(IMAGE_DIR, MASK_DIR)
print("Total paired samples:", len(pairs))

# =========================
# LOAD ONE IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    # Image
    img = cv2.imread(img_path.decode(), cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    # Mask
    mask = cv2.imread(mask_path.decode(), cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")
    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)

    # Binary mask: 0/1
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask

# =========================
# AUGMENTATION
# =========================
def augment(image, mask):
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    k = tf.random.uniform((), minval=0, maxval=4, dtype=tf.int32)
    image = tf.image.rot90(image, k)
    mask = tf.image.rot90(mask, k)

    return image, mask

# =========================
# CREATE DATASET
# =========================

pairs = get_pairs(IMAGE_DIR, MASK_DIR)

print("Total paired samples:", len(pairs))

for img, mask in pairs[:3]:
    print(img)
    print(mask)
    print()
# Out:
# Total paired samples: 16
# Total paired samples: 16
# /content/drive/MyDrive/dataset_rock/images/image1.jpg
# /content/drive/MyDrive/dataset_rock/masks/image1.png
#
# /content/drive/MyDrive/dataset_rock/images/image10.jpg
# /content/drive/MyDrive/dataset_rock/masks/image10.png
#
# /content/drive/MyDrive/dataset_rock/images/image11.png
# /content/drive/MyDrive/dataset_rock/masks/image11.png

# %%
def make_dataset(pairs, training=True):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)

    if training:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

train_pairs, val_pairs = train_test_split(pairs, test_size=0.2, random_state=SEED)

train_ds = make_dataset(train_pairs, training=True)
val_ds = make_dataset(val_pairs, training=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))

# =========================
# METRICS / LOSS
# =========================
def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

import tensorflow as tf
from tensorflow.keras import layers, Model
import numpy as np

# =========================================================
# LEARNABLE / FIXED-KERNEL STYLE EDGE LAYER
# =========================================================
@tf.keras.utils.register_keras_serializable()
class FixedKernelLayer(layers.Layer):
    """
    Fixed non-trainable kernel bank:
    - Sobel X
    - Sobel Y
    - Laplacian

    Input:  [B, H, W, C]
    Output: [B, H, W, 3C]
    """
    def __init__(self, **kwargs):
        super().__init__(trainable=False, **kwargs)

    def build(self, input_shape):
        c = int(input_shape[-1])

        sobel_x = np.array([
            [-1, 0, 1],
            [-2, 0, 2],
            [-1, 0, 1]
        ], dtype=np.float32)

        sobel_y = np.array([
            [-1, -2, -1],
            [ 0,  0,  0],
            [ 1,  2,  1]
        ], dtype=np.float32)

        laplacian = np.array([
            [ 0,  1,  0],
            [ 1, -4,  1],
            [ 0,  1,  0]
        ], dtype=np.float32)

        def make_depthwise_kernel(base_kernel):
            k = np.zeros((3, 3, c, 1), dtype=np.float32)
            for ch in range(c):
                k[:, :, ch, 0] = base_kernel
            return tf.constant(k)

        self.k_sobel_x = make_depthwise_kernel(sobel_x)
        self.k_sobel_y = make_depthwise_kernel(sobel_y)
        self.k_lap = make_depthwise_kernel(laplacian)

        super().build(input_shape)

    def call(self, x):
        sx = tf.nn.depthwise_conv2d(
            x, self.k_sobel_x, strides=[1, 1, 1, 1], padding="SAME"
        )
        sy = tf.nn.depthwise_conv2d(
            x, self.k_sobel_y, strides=[1, 1, 1, 1], padding="SAME"
        )
        lp = tf.nn.depthwise_conv2d(
            x, self.k_lap, strides=[1, 1, 1, 1], padding="SAME"
        )
        return tf.concat([sx, sy, lp], axis=-1)

    def get_config(self):
        config = super().get_config()
        return config


# =========================================================
# FIXED KERNEL BRANCH
# =========================================================
def fixed_kernel_block(x):
    x = FixedKernelLayer()(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x


def merge_with_fixed_kernels(feat, filters, prefix):
    """
    For a single skip tensor:
      original feature
      + fixed-kernel response of that feature
    Then concatenate and compress with 1x1 conv.
    """
    fk = FixedKernelLayer(name=f"{prefix}_fixed")(feat)
    x = layers.Concatenate(name=f"{prefix}_concat")([feat, fk])

    x = layers.Conv2D(
        filters,
        1,
        padding="same",
        kernel_initializer="he_normal",
        name=f"{prefix}_compress"
    )(x)
    x = layers.ReLU(name=f"{prefix}_compress_relu")(x)
    return x


# =========================================================
# U-NET BLOCKS
# =========================================================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x


def down_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPool2D((2, 2))(c)
    p = layers.Dropout(0.2)(p)
    return c, p


def up_block(x, skip, skip_fixed, filters):
    x = layers.Conv2DTranspose(filters, 2, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip, skip_fixed])
    x = layers.Dropout(0.2)(x)
    x = conv_block(x, filters)
    return x


# =========================================================
# BUILD MODEL
# =========================================================
def build_unet(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1, p1 = down_block(inputs, 32)
    c2, p2 = down_block(p1, 64)
    c3, p3 = down_block(p2, 128)
    c4, p4 = down_block(p3, 256)

    # Fixed-kernel transformed skips
    c1_star = merge_with_fixed_kernels(c1, 32, "c1")
    c2_star = merge_with_fixed_kernels(c2, 64, "c2")
    c3_star = merge_with_fixed_kernels(c3, 128, "c3")
    c4_star = merge_with_fixed_kernels(c4, 256, "c4")

    # Bottleneck
    bottleneck = conv_block(p4, 512)

    # Decoder
    u1 = up_block(bottleneck, c4, c4_star, 256)
    u2 = up_block(u1, c3, c3_star, 128)
    u3 = up_block(u2, c2, c2_star, 64)
    u4 = up_block(u3, c1, c1_star, 32)

    outputs = layers.Conv2D(1, 1, activation="sigmoid")(u4)

    model = Model(inputs, outputs, name="UNet_Binary_FixedKernel")
    return model


model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=dice_loss,
    metrics=["accuracy", dice_coef, iou_coef]
)

model.summary()

# =========================
# CALLBACKS
# =========================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "best_unet.keras",
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# =========================
# TRAIN
# =========================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS: ACCURACY, DICE, IOU
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(18, 5))

    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, hist["accuracy"], label="Train Accuracy")
    plt.plot(epochs_range, hist["val_accuracy"], label="Val Accuracy")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, hist["dice_coef"], label="Train Dice")
    plt.plot(epochs_range, hist["val_dice_coef"], label="Val Dice")
    plt.title("Dice Score Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Dice Coefficient")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, hist["iou_coef"], label="Train IoU")
    plt.plot(epochs_range, hist["val_iou_coef"], label="Val IoU")
    plt.title("IoU Curve")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_curves(history)

# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

# Show one validation sample
show_prediction(model, val_pairs[0])
# Out:
# Train samples: 12
# Val samples: 4
# Model: "UNet_Binary_FixedKernel"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,248 │ re_lu[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,496 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,928 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ re_lu_3[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,856 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,584 │ re_lu_4[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ re_lu_5[0][0]     │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    295,168 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    590,080 │ re_lu_6[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ re_lu_7[0][0]     │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ dropout_3[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ re_lu_8[0][0]     │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_fixed            │ (None, 32, 32,    │          0 │ re_lu_7[0][0]     │
# │ (FixedKernelLayer)  │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_concat           │ (None, 32, 32,    │          0 │ re_lu_7[0][0],    │
# │ (Concatenate)       │ 1024)             │            │ c4_fixed[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_compress         │ (None, 32, 32,    │    262,400 │ c4_concat[0][0]   │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 32, 32,    │    524,544 │ re_lu_9[0][0]     │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c4_compress_relu    │ (None, 32, 32,    │          0 │ c4_compress[0][0] │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 768)              │            │ re_lu_7[0][0],    │
# │                     │                   │            │ c4_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 32,    │          0 │ concatenate[0][0] │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │  1,769,728 │ dropout_4[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_10[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_fixed            │ (None, 64, 64,    │          0 │ re_lu_5[0][0]     │
# │ (FixedKernelLayer)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_concat           │ (None, 64, 64,    │          0 │ re_lu_5[0][0],    │
# │ (Concatenate)       │ 512)              │            │ c3_fixed[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_compress         │ (None, 64, 64,    │     65,664 │ c3_concat[0][0]   │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 64, 64,    │    131,200 │ re_lu_11[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c3_compress_relu    │ (None, 64, 64,    │          0 │ c3_compress[0][0] │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 384)              │            │ re_lu_5[0][0],    │
# │                     │                   │            │ c3_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 64,    │          0 │ concatenate_1[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 64, 64,    │    442,496 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_12[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_fixed            │ (None, 128, 128,  │          0 │ re_lu_3[0][0]     │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_concat           │ (None, 128, 128,  │          0 │ re_lu_3[0][0],    │
# │ (Concatenate)       │ 256)              │            │ c2_fixed[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_compress         │ (None, 128, 128,  │     16,448 │ c2_concat[0][0]   │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 128, 128,  │     32,832 │ re_lu_13[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c2_compress_relu    │ (None, 128, 128,  │          0 │ c2_compress[0][0] │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 192)              │            │ re_lu_3[0][0],    │
# │                     │                   │            │ c2_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128, 128,  │          0 │ concatenate_2[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │    110,656 │ dropout_6[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_14[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_fixed            │ (None, 256, 256,  │          0 │ re_lu_1[0][0]     │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_concat           │ (None, 256, 256,  │          0 │ re_lu_1[0][0],    │
# │ (Concatenate)       │ 128)              │            │ c1_fixed[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_compress         │ (None, 256, 256,  │      4,128 │ c1_concat[0][0]   │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 256, 256,  │      8,224 │ re_lu_15[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ c1_compress_relu    │ (None, 256, 256,  │          0 │ c1_compress[0][0] │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 96)               │            │ re_lu_1[0][0],    │
# │                     │                   │            │ c1_compress_relu… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256, 256,  │          0 │ concatenate_3[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 256, 256,  │     27,680 │ dropout_7[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_16[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │         33 │ re_lu_17[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,903,873 (33.97 MB)
#  Trainable params: 8,897,985 (33.94 MB)
#  Non-trainable params: 5,888 (23.00 KB)
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.4555 - dice_coef: 0.5083 - iou_coef: 0.3408 - loss: 0.4917
# Epoch 1: val_dice_coef improved from None to 0.52435, saving model to best_unet.keras
#
# Epoch 1: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 83s 6s/step - accuracy: 0.4663 - dice_coef: 0.5103 - iou_coef: 0.3426 - loss: 0.4897 - val_accuracy: 0.5364 - val_dice_coef: 0.5244 - val_iou_coef: 0.3553 - val_loss: 0.4756 - learning_rate: 1.0000e-04
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.5139 - dice_coef: 0.5289 - iou_coef: 0.3595 - loss: 0.4711
# Epoch 2: val_dice_coef did not improve from 0.52435
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 866ms/step - accuracy: 0.5185 - dice_coef: 0.5311 - iou_coef: 0.3616 - loss: 0.4689 - val_accuracy: 0.5158 - val_dice_coef: 0.5177 - val_iou_coef: 0.3492 - val_loss: 0.4823 - learning_rate: 1.0000e-04
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.5439 - dice_coef: 0.5369 - iou_coef: 0.3672 - loss: 0.4631
# Epoch 3: val_dice_coef did not improve from 0.52435
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 734ms/step - accuracy: 0.5549 - dice_coef: 0.5475 - iou_coef: 0.3772 - loss: 0.4525 - val_accuracy: 0.4948 - val_dice_coef: 0.5113 - val_iou_coef: 0.3435 - val_loss: 0.4887 - learning_rate: 1.0000e-04
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 519ms/step - accuracy: 0.5757 - dice_coef: 0.5617 - iou_coef: 0.3908 - loss: 0.4383
# Epoch 4: val_dice_coef did not improve from 0.52435
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 808ms/step - accuracy: 0.5781 - dice_coef: 0.5609 - iou_coef: 0.3901 - loss: 0.4391 - val_accuracy: 0.4810 - val_dice_coef: 0.5065 - val_iou_coef: 0.3391 - val_loss: 0.4935 - learning_rate: 1.0000e-04
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.5973 - dice_coef: 0.5700 - iou_coef: 0.3987 - loss: 0.4300
# Epoch 5: val_dice_coef did not improve from 0.52435
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 850ms/step - accuracy: 0.5972 - dice_coef: 0.5753 - iou_coef: 0.4040 - loss: 0.4247 - val_accuracy: 0.4760 - val_dice_coef: 0.5041 - val_iou_coef: 0.3370 - val_loss: 0.4959 - learning_rate: 1.0000e-04
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 880ms/step - accuracy: 0.6308 - dice_coef: 0.5867 - iou_coef: 0.4152 - loss: 0.4133
# Epoch 6: val_dice_coef did not improve from 0.52435
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.6132 - dice_coef: 0.5896 - iou_coef: 0.4181 - loss: 0.4104 - val_accuracy: 0.4958 - val_dice_coef: 0.5100 - val_iou_coef: 0.3423 - val_loss: 0.4900 - learning_rate: 5.0000e-05
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.6137 - dice_coef: 0.5853 - iou_coef: 0.4138 - loss: 0.4147
# Epoch 7: val_dice_coef did not improve from 0.52435
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 746ms/step - accuracy: 0.6157 - dice_coef: 0.5938 - iou_coef: 0.4224 - loss: 0.4062 - val_accuracy: 0.5176 - val_dice_coef: 0.5175 - val_iou_coef: 0.3491 - val_loss: 0.4825 - learning_rate: 5.0000e-05
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.6499 - dice_coef: 0.6029 - iou_coef: 0.4318 - loss: 0.3971
# Epoch 8: val_dice_coef improved from 0.52435 to 0.52635, saving model to best_unet.keras
#
# Epoch 8: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6347 - dice_coef: 0.6004 - iou_coef: 0.4292 - loss: 0.3996 - val_accuracy: 0.5374 - val_dice_coef: 0.5263 - val_iou_coef: 0.3572 - val_loss: 0.4737 - learning_rate: 5.0000e-05
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.6243 - dice_coef: 0.5958 - iou_coef: 0.4243 - loss: 0.4042
# Epoch 9: val_dice_coef improved from 0.52635 to 0.53568, saving model to best_unet.keras
#
# Epoch 9: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6224 - dice_coef: 0.6020 - iou_coef: 0.4307 - loss: 0.3980 - val_accuracy: 0.5505 - val_dice_coef: 0.5357 - val_iou_coef: 0.3658 - val_loss: 0.4643 - learning_rate: 5.0000e-05
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 966ms/step - accuracy: 0.6491 - dice_coef: 0.6146 - iou_coef: 0.4436 - loss: 0.3854
# Epoch 10: val_dice_coef improved from 0.53568 to 0.54534, saving model to best_unet.keras
#
# Epoch 10: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.6349 - dice_coef: 0.6110 - iou_coef: 0.4399 - loss: 0.3890 - val_accuracy: 0.5616 - val_dice_coef: 0.5453 - val_iou_coef: 0.3749 - val_loss: 0.4547 - learning_rate: 5.0000e-05
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step - accuracy: 0.6457 - dice_coef: 0.6187 - iou_coef: 0.4480 - loss: 0.3813
# Epoch 11: val_dice_coef improved from 0.54534 to 0.55454, saving model to best_unet.keras
#
# Epoch 11: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6428 - dice_coef: 0.6156 - iou_coef: 0.4447 - loss: 0.3844 - val_accuracy: 0.5713 - val_dice_coef: 0.5545 - val_iou_coef: 0.3836 - val_loss: 0.4455 - learning_rate: 5.0000e-05
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.6634 - dice_coef: 0.6307 - iou_coef: 0.4608 - loss: 0.3693
# Epoch 12: val_dice_coef improved from 0.55454 to 0.56354, saving model to best_unet.keras
#
# Epoch 12: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6411 - dice_coef: 0.6201 - iou_coef: 0.4499 - loss: 0.3799 - val_accuracy: 0.5789 - val_dice_coef: 0.5635 - val_iou_coef: 0.3923 - val_loss: 0.4365 - learning_rate: 5.0000e-05
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.6571 - dice_coef: 0.6336 - iou_coef: 0.4643 - loss: 0.3664
# Epoch 13: val_dice_coef improved from 0.56354 to 0.57179, saving model to best_unet.keras
#
# Epoch 13: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6431 - dice_coef: 0.6191 - iou_coef: 0.4489 - loss: 0.3809 - val_accuracy: 0.5842 - val_dice_coef: 0.5718 - val_iou_coef: 0.4004 - val_loss: 0.4282 - learning_rate: 5.0000e-05
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.6477 - dice_coef: 0.6289 - iou_coef: 0.4587 - loss: 0.3711
# Epoch 14: val_dice_coef improved from 0.57179 to 0.57993, saving model to best_unet.keras
#
# Epoch 14: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.6460 - dice_coef: 0.6236 - iou_coef: 0.4532 - loss: 0.3764 - val_accuracy: 0.5884 - val_dice_coef: 0.5799 - val_iou_coef: 0.4084 - val_loss: 0.4201 - learning_rate: 5.0000e-05
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.6357 - dice_coef: 0.6250 - iou_coef: 0.4550 - loss: 0.3750
# Epoch 15: val_dice_coef improved from 0.57993 to 0.58743, saving model to best_unet.keras
#
# Epoch 15: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6444 - dice_coef: 0.6278 - iou_coef: 0.4580 - loss: 0.3722 - val_accuracy: 0.5911 - val_dice_coef: 0.5874 - val_iou_coef: 0.4159 - val_loss: 0.4126 - learning_rate: 5.0000e-05
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - accuracy: 0.6439 - dice_coef: 0.6280 - iou_coef: 0.4579 - loss: 0.3720
# Epoch 16: val_dice_coef improved from 0.58743 to 0.59445, saving model to best_unet.keras
#
# Epoch 16: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6651 - dice_coef: 0.6407 - iou_coef: 0.4718 - loss: 0.3593 - val_accuracy: 0.5935 - val_dice_coef: 0.5944 - val_iou_coef: 0.4229 - val_loss: 0.4056 - learning_rate: 5.0000e-05
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - accuracy: 0.6731 - dice_coef: 0.6340 - iou_coef: 0.4642 - loss: 0.3660
# Epoch 17: val_dice_coef improved from 0.59445 to 0.60185, saving model to best_unet.keras
#
# Epoch 17: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6659 - dice_coef: 0.6425 - iou_coef: 0.4735 - loss: 0.3575 - val_accuracy: 0.5952 - val_dice_coef: 0.6019 - val_iou_coef: 0.4305 - val_loss: 0.3981 - learning_rate: 5.0000e-05
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.6798 - dice_coef: 0.6506 - iou_coef: 0.4823 - loss: 0.3494
# Epoch 18: val_dice_coef improved from 0.60185 to 0.60865, saving model to best_unet.keras
#
# Epoch 18: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.6782 - dice_coef: 0.6507 - iou_coef: 0.4825 - loss: 0.3493 - val_accuracy: 0.5965 - val_dice_coef: 0.6086 - val_iou_coef: 0.4374 - val_loss: 0.3914 - learning_rate: 5.0000e-05
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 0.6592 - dice_coef: 0.6387 - iou_coef: 0.4696 - loss: 0.3613
# Epoch 19: val_dice_coef improved from 0.60865 to 0.61473, saving model to best_unet.keras
#
# Epoch 19: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6797 - dice_coef: 0.6534 - iou_coef: 0.4861 - loss: 0.3466 - val_accuracy: 0.5974 - val_dice_coef: 0.6147 - val_iou_coef: 0.4438 - val_loss: 0.3853 - learning_rate: 5.0000e-05
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 621ms/step - accuracy: 0.6997 - dice_coef: 0.6615 - iou_coef: 0.4947 - loss: 0.3385
# Epoch 20: val_dice_coef improved from 0.61473 to 0.62080, saving model to best_unet.keras
#
# Epoch 20: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6904 - dice_coef: 0.6620 - iou_coef: 0.4955 - loss: 0.3380 - val_accuracy: 0.5982 - val_dice_coef: 0.6208 - val_iou_coef: 0.4501 - val_loss: 0.3792 - learning_rate: 5.0000e-05
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.6749 - dice_coef: 0.6704 - iou_coef: 0.5043 - loss: 0.3296
# Epoch 21: val_dice_coef improved from 0.62080 to 0.62646, saving model to best_unet.keras
#
# Epoch 21: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6792 - dice_coef: 0.6636 - iou_coef: 0.4966 - loss: 0.3364 - val_accuracy: 0.5991 - val_dice_coef: 0.6265 - val_iou_coef: 0.4561 - val_loss: 0.3735 - learning_rate: 5.0000e-05
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - accuracy: 0.7008 - dice_coef: 0.6698 - iou_coef: 0.5040 - loss: 0.3302
# Epoch 22: val_dice_coef improved from 0.62646 to 0.63182, saving model to best_unet.keras
#
# Epoch 22: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6822 - dice_coef: 0.6643 - iou_coef: 0.4979 - loss: 0.3357 - val_accuracy: 0.6003 - val_dice_coef: 0.6318 - val_iou_coef: 0.4618 - val_loss: 0.3682 - learning_rate: 5.0000e-05
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.6864 - dice_coef: 0.6693 - iou_coef: 0.5031 - loss: 0.3307
# Epoch 23: val_dice_coef improved from 0.63182 to 0.63676, saving model to best_unet.keras
#
# Epoch 23: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6853 - dice_coef: 0.6637 - iou_coef: 0.4968 - loss: 0.3363 - val_accuracy: 0.6017 - val_dice_coef: 0.6368 - val_iou_coef: 0.4671 - val_loss: 0.3632 - learning_rate: 5.0000e-05
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step - accuracy: 0.6854 - dice_coef: 0.6674 - iou_coef: 0.5010 - loss: 0.3326
# Epoch 24: val_dice_coef improved from 0.63676 to 0.64156, saving model to best_unet.keras
#
# Epoch 24: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6896 - dice_coef: 0.6741 - iou_coef: 0.5086 - loss: 0.3259 - val_accuracy: 0.6027 - val_dice_coef: 0.6416 - val_iou_coef: 0.4723 - val_loss: 0.3584 - learning_rate: 5.0000e-05
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.6574 - dice_coef: 0.6618 - iou_coef: 0.4948 - loss: 0.3382
# Epoch 25: val_dice_coef improved from 0.64156 to 0.64615, saving model to best_unet.keras
#
# Epoch 25: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6862 - dice_coef: 0.6741 - iou_coef: 0.5090 - loss: 0.3259 - val_accuracy: 0.6041 - val_dice_coef: 0.6461 - val_iou_coef: 0.4773 - val_loss: 0.3539 - learning_rate: 5.0000e-05
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 970ms/step - accuracy: 0.6786 - dice_coef: 0.6693 - iou_coef: 0.5032 - loss: 0.3307
# Epoch 26: val_dice_coef improved from 0.64615 to 0.65074, saving model to best_unet.keras
#
# Epoch 26: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.6954 - dice_coef: 0.6806 - iou_coef: 0.5165 - loss: 0.3194 - val_accuracy: 0.6060 - val_dice_coef: 0.6507 - val_iou_coef: 0.4823 - val_loss: 0.3493 - learning_rate: 5.0000e-05
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.6836 - dice_coef: 0.6881 - iou_coef: 0.5247 - loss: 0.3119
# Epoch 27: val_dice_coef improved from 0.65074 to 0.65520, saving model to best_unet.keras
#
# Epoch 27: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6891 - dice_coef: 0.6787 - iou_coef: 0.5138 - loss: 0.3213 - val_accuracy: 0.6074 - val_dice_coef: 0.6552 - val_iou_coef: 0.4872 - val_loss: 0.3448 - learning_rate: 5.0000e-05
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.6974 - dice_coef: 0.6833 - iou_coef: 0.5192 - loss: 0.3167
# Epoch 28: val_dice_coef improved from 0.65520 to 0.65928, saving model to best_unet.keras
#
# Epoch 28: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7050 - dice_coef: 0.6874 - iou_coef: 0.5241 - loss: 0.3126 - val_accuracy: 0.6084 - val_dice_coef: 0.6593 - val_iou_coef: 0.4917 - val_loss: 0.3407 - learning_rate: 5.0000e-05
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.6917 - dice_coef: 0.6905 - iou_coef: 0.5274 - loss: 0.3095
# Epoch 29: val_dice_coef improved from 0.65928 to 0.66295, saving model to best_unet.keras
#
# Epoch 29: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6897 - dice_coef: 0.6812 - iou_coef: 0.5169 - loss: 0.3188 - val_accuracy: 0.6096 - val_dice_coef: 0.6630 - val_iou_coef: 0.4958 - val_loss: 0.3370 - learning_rate: 5.0000e-05
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 848ms/step - accuracy: 0.6997 - dice_coef: 0.6747 - iou_coef: 0.5091 - loss: 0.3253
# Epoch 30: val_dice_coef improved from 0.66295 to 0.66664, saving model to best_unet.keras
#
# Epoch 30: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.6870 - dice_coef: 0.6791 - iou_coef: 0.5143 - loss: 0.3209 - val_accuracy: 0.6105 - val_dice_coef: 0.6666 - val_iou_coef: 0.5000 - val_loss: 0.3334 - learning_rate: 5.0000e-05
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - accuracy: 0.6984 - dice_coef: 0.6905 - iou_coef: 0.5275 - loss: 0.3095
# Epoch 31: val_dice_coef improved from 0.66664 to 0.66974, saving model to best_unet.keras
#
# Epoch 31: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7138 - dice_coef: 0.6972 - iou_coef: 0.5353 - loss: 0.3028 - val_accuracy: 0.6119 - val_dice_coef: 0.6697 - val_iou_coef: 0.5035 - val_loss: 0.3303 - learning_rate: 5.0000e-05
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.7267 - dice_coef: 0.7073 - iou_coef: 0.5472 - loss: 0.2927
# Epoch 32: val_dice_coef improved from 0.66974 to 0.67275, saving model to best_unet.keras
#
# Epoch 32: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7138 - dice_coef: 0.6986 - iou_coef: 0.5370 - loss: 0.3014 - val_accuracy: 0.6128 - val_dice_coef: 0.6727 - val_iou_coef: 0.5069 - val_loss: 0.3273 - learning_rate: 5.0000e-05
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.7128 - dice_coef: 0.6955 - iou_coef: 0.5333 - loss: 0.3045
# Epoch 33: val_dice_coef improved from 0.67275 to 0.67541, saving model to best_unet.keras
#
# Epoch 33: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7162 - dice_coef: 0.7001 - iou_coef: 0.5387 - loss: 0.2999 - val_accuracy: 0.6139 - val_dice_coef: 0.6754 - val_iou_coef: 0.5099 - val_loss: 0.3246 - learning_rate: 5.0000e-05
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 868ms/step - accuracy: 0.7259 - dice_coef: 0.6992 - iou_coef: 0.5376 - loss: 0.3008
# Epoch 34: val_dice_coef improved from 0.67541 to 0.67814, saving model to best_unet.keras
#
# Epoch 34: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7195 - dice_coef: 0.7039 - iou_coef: 0.5431 - loss: 0.2961 - val_accuracy: 0.6154 - val_dice_coef: 0.6781 - val_iou_coef: 0.5130 - val_loss: 0.3219 - learning_rate: 5.0000e-05
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.7490 - dice_coef: 0.7203 - iou_coef: 0.5644 - loss: 0.2797
# Epoch 35: val_dice_coef improved from 0.67814 to 0.68066, saving model to best_unet.keras
#
# Epoch 35: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7264 - dice_coef: 0.7054 - iou_coef: 0.5462 - loss: 0.2946 - val_accuracy: 0.6169 - val_dice_coef: 0.6807 - val_iou_coef: 0.5159 - val_loss: 0.3193 - learning_rate: 5.0000e-05
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 589ms/step - accuracy: 0.7048 - dice_coef: 0.6929 - iou_coef: 0.5302 - loss: 0.3071
# Epoch 36: val_dice_coef improved from 0.68066 to 0.68305, saving model to best_unet.keras
#
# Epoch 36: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7055 - dice_coef: 0.6991 - iou_coef: 0.5376 - loss: 0.3009 - val_accuracy: 0.6186 - val_dice_coef: 0.6830 - val_iou_coef: 0.5187 - val_loss: 0.3170 - learning_rate: 5.0000e-05
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 0.7184 - dice_coef: 0.7084 - iou_coef: 0.5485 - loss: 0.2916
# Epoch 37: val_dice_coef improved from 0.68305 to 0.68510, saving model to best_unet.keras
#
# Epoch 37: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.7255 - dice_coef: 0.7074 - iou_coef: 0.5474 - loss: 0.2926 - val_accuracy: 0.6205 - val_dice_coef: 0.6851 - val_iou_coef: 0.5210 - val_loss: 0.3149 - learning_rate: 5.0000e-05
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 607ms/step - accuracy: 0.7499 - dice_coef: 0.7326 - iou_coef: 0.5791 - loss: 0.2674
# Epoch 38: val_dice_coef improved from 0.68510 to 0.68711, saving model to best_unet.keras
#
# Epoch 38: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7236 - dice_coef: 0.7105 - iou_coef: 0.5521 - loss: 0.2895 - val_accuracy: 0.6227 - val_dice_coef: 0.6871 - val_iou_coef: 0.5234 - val_loss: 0.3129 - learning_rate: 5.0000e-05
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.7386 - dice_coef: 0.7204 - iou_coef: 0.5631 - loss: 0.2796
# Epoch 39: val_dice_coef improved from 0.68711 to 0.68908, saving model to best_unet.keras
#
# Epoch 39: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7298 - dice_coef: 0.7164 - iou_coef: 0.5582 - loss: 0.2836 - val_accuracy: 0.6248 - val_dice_coef: 0.6891 - val_iou_coef: 0.5257 - val_loss: 0.3109 - learning_rate: 5.0000e-05
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 668ms/step - accuracy: 0.7053 - dice_coef: 0.6980 - iou_coef: 0.5365 - loss: 0.3020
# Epoch 40: val_dice_coef improved from 0.68908 to 0.69073, saving model to best_unet.keras
#
# Epoch 40: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7212 - dice_coef: 0.7118 - iou_coef: 0.5534 - loss: 0.2882 - val_accuracy: 0.6270 - val_dice_coef: 0.6907 - val_iou_coef: 0.5276 - val_loss: 0.3093 - learning_rate: 5.0000e-05
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - accuracy: 0.7278 - dice_coef: 0.7151 - iou_coef: 0.5566 - loss: 0.2849
# Epoch 41: val_dice_coef improved from 0.69073 to 0.69220, saving model to best_unet.keras
#
# Epoch 41: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.7366 - dice_coef: 0.7196 - iou_coef: 0.5622 - loss: 0.2804 - val_accuracy: 0.6292 - val_dice_coef: 0.6922 - val_iou_coef: 0.5293 - val_loss: 0.3078 - learning_rate: 5.0000e-05
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.7247 - dice_coef: 0.7088 - iou_coef: 0.5490 - loss: 0.2912
# Epoch 42: val_dice_coef improved from 0.69220 to 0.69395, saving model to best_unet.keras
#
# Epoch 42: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7182 - dice_coef: 0.7111 - iou_coef: 0.5518 - loss: 0.2889 - val_accuracy: 0.6314 - val_dice_coef: 0.6939 - val_iou_coef: 0.5313 - val_loss: 0.3061 - learning_rate: 5.0000e-05
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.7370 - dice_coef: 0.7280 - iou_coef: 0.5726 - loss: 0.2720
# Epoch 43: val_dice_coef improved from 0.69395 to 0.69528, saving model to best_unet.keras
#
# Epoch 43: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7352 - dice_coef: 0.7209 - iou_coef: 0.5638 - loss: 0.2791 - val_accuracy: 0.6340 - val_dice_coef: 0.6953 - val_iou_coef: 0.5329 - val_loss: 0.3047 - learning_rate: 5.0000e-05
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.7411 - dice_coef: 0.7231 - iou_coef: 0.5666 - loss: 0.2769
# Epoch 44: val_dice_coef improved from 0.69528 to 0.69657, saving model to best_unet.keras
#
# Epoch 44: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7308 - dice_coef: 0.7179 - iou_coef: 0.5602 - loss: 0.2821 - val_accuracy: 0.6368 - val_dice_coef: 0.6966 - val_iou_coef: 0.5344 - val_loss: 0.3034 - learning_rate: 5.0000e-05
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.7128 - dice_coef: 0.7098 - iou_coef: 0.5506 - loss: 0.2902
# Epoch 45: val_dice_coef improved from 0.69657 to 0.69777, saving model to best_unet.keras
#
# Epoch 45: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7349 - dice_coef: 0.7228 - iou_coef: 0.5664 - loss: 0.2772 - val_accuracy: 0.6396 - val_dice_coef: 0.6978 - val_iou_coef: 0.5358 - val_loss: 0.3022 - learning_rate: 5.0000e-05
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.7239 - dice_coef: 0.7161 - iou_coef: 0.5582 - loss: 0.2839
# Epoch 46: val_dice_coef improved from 0.69777 to 0.69897, saving model to best_unet.keras
#
# Epoch 46: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7437 - dice_coef: 0.7288 - iou_coef: 0.5737 - loss: 0.2712 - val_accuracy: 0.6426 - val_dice_coef: 0.6990 - val_iou_coef: 0.5372 - val_loss: 0.3010 - learning_rate: 5.0000e-05
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 615ms/step - accuracy: 0.7542 - dice_coef: 0.7356 - iou_coef: 0.5819 - loss: 0.2644
# Epoch 47: val_dice_coef improved from 0.69897 to 0.70045, saving model to best_unet.keras
#
# Epoch 47: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7398 - dice_coef: 0.7272 - iou_coef: 0.5715 - loss: 0.2728 - val_accuracy: 0.6454 - val_dice_coef: 0.7004 - val_iou_coef: 0.5390 - val_loss: 0.2996 - learning_rate: 5.0000e-05
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.7362 - dice_coef: 0.7312 - iou_coef: 0.5764 - loss: 0.2688
# Epoch 48: val_dice_coef improved from 0.70045 to 0.70189, saving model to best_unet.keras
#
# Epoch 48: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7343 - dice_coef: 0.7251 - iou_coef: 0.5688 - loss: 0.2749 - val_accuracy: 0.6486 - val_dice_coef: 0.7019 - val_iou_coef: 0.5407 - val_loss: 0.2981 - learning_rate: 5.0000e-05
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 669ms/step - accuracy: 0.7471 - dice_coef: 0.7360 - iou_coef: 0.5823 - loss: 0.2640
# Epoch 49: val_dice_coef improved from 0.70189 to 0.70324, saving model to best_unet.keras
#
# Epoch 49: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7442 - dice_coef: 0.7303 - iou_coef: 0.5753 - loss: 0.2697 - val_accuracy: 0.6525 - val_dice_coef: 0.7032 - val_iou_coef: 0.5423 - val_loss: 0.2968 - learning_rate: 5.0000e-05
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step - accuracy: 0.7658 - dice_coef: 0.7414 - iou_coef: 0.5893 - loss: 0.2586
# Epoch 50: val_dice_coef improved from 0.70324 to 0.70464, saving model to best_unet.keras
#
# Epoch 50: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7491 - dice_coef: 0.7318 - iou_coef: 0.5777 - loss: 0.2682 - val_accuracy: 0.6569 - val_dice_coef: 0.7046 - val_iou_coef: 0.5440 - val_loss: 0.2954 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 50.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
