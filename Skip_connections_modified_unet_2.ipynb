# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Rock-segmentation/blob/main/Skip_connections_modified_unet_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Model

from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (256, 256)
BATCH_SIZE = 4
EPOCHS = 50
SEED = 42

IMAGE_DIR = "/content/drive/MyDrive/dataset_rock/images"
MASK_DIR  = "/content/drive/MyDrive/dataset_rock/masks"

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

print("Images :", len(os.listdir(IMAGE_DIR)))
print("Masks  :", len(os.listdir(MASK_DIR)))

print(os.listdir(IMAGE_DIR)[:5])
print(os.listdir(MASK_DIR)[:5])
# Out:
# Images : 16
# Masks  : 16
# ['image5.jpg', 'image10.jpg', 'image16.png', 'image1.jpg', 'image4.jpg']
# ['image2.png', 'image7.png', 'image9.png', 'image11.png', 'image3.png']

# %%
def get_pairs(image_dir, mask_dir):
    image_paths = []
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        image_paths.extend(glob.glob(os.path.join(image_dir, f"*.{ext}")))

    image_paths = sorted(image_paths)

    mask_map = {}
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        for p in glob.glob(os.path.join(mask_dir, f"*.{ext}")):
            stem = os.path.splitext(os.path.basename(p))[0]
            mask_map[stem] = p

    pairs = []
    for img_path in image_paths:
        stem = os.path.splitext(os.path.basename(img_path))[0]
        if stem in mask_map:
            pairs.append((img_path, mask_map[stem]))
        else:
            print(f"Warning: no mask found for {img_path}")

    return pairs

pairs = get_pairs(IMAGE_DIR, MASK_DIR)
print("Total paired samples:", len(pairs))

# =========================
# LOAD ONE IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    # Image
    img = cv2.imread(img_path.decode(), cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    # Mask
    mask = cv2.imread(mask_path.decode(), cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")
    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)

    # Binary mask: 0/1
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask

# =========================
# AUGMENTATION
# =========================
def augment(image, mask):
    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_left_right(image)
        mask = tf.image.flip_left_right(mask)

    if tf.random.uniform(()) > 0.5:
        image = tf.image.flip_up_down(image)
        mask = tf.image.flip_up_down(mask)

    k = tf.random.uniform((), minval=0, maxval=4, dtype=tf.int32)
    image = tf.image.rot90(image, k)
    mask = tf.image.rot90(mask, k)

    return image, mask

# =========================
# CREATE DATASET
# =========================

pairs = get_pairs(IMAGE_DIR, MASK_DIR)

print("Total paired samples:", len(pairs))

for img, mask in pairs[:3]:
    print(img)
    print(mask)
    print()
# Out:
# Total paired samples: 16
# Total paired samples: 16
# /content/drive/MyDrive/dataset_rock/images/image1.jpg
# /content/drive/MyDrive/dataset_rock/masks/image1.png
#
# /content/drive/MyDrive/dataset_rock/images/image10.jpg
# /content/drive/MyDrive/dataset_rock/masks/image10.png
#
# /content/drive/MyDrive/dataset_rock/images/image11.png
# /content/drive/MyDrive/dataset_rock/masks/image11.png

# %%
def make_dataset(pairs, training=True):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)

    if training:
        ds = ds.map(augment, num_parallel_calls=tf.data.AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
    return ds

train_pairs, val_pairs = train_test_split(pairs, test_size=0.2, random_state=SEED)

train_ds = make_dataset(train_pairs, training=True)
val_ds = make_dataset(val_pairs, training=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))

# =========================
# METRICS / LOSS
# =========================
def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

import tensorflow as tf
from tensorflow.keras import layers, Model
import numpy as np

# =========================================================
# FIXED KERNEL LAYER
# =========================================================
@tf.keras.utils.register_keras_serializable()
class FixedDepthwiseConv2D(layers.Layer):
    def __init__(self, kernel_2d, **kwargs):
        super().__init__(**kwargs)
        self.kernel_2d = np.array(kernel_2d, dtype=np.float32)
        self.depthwise_conv = None

    def build(self, input_shape):
        in_channels = int(input_shape[-1])

        kh, kw = self.kernel_2d.shape
        kernel = self.kernel_2d[:, :, None, None]          # (kh, kw, 1, 1)
        kernel = np.repeat(kernel, in_channels, axis=2)    # (kh, kw, in_channels, 1)

        self.depthwise_conv = layers.DepthwiseConv2D(
            kernel_size=(kh, kw),
            padding="same",
            use_bias=False,
            depth_multiplier=1,
            trainable=False,
        )
        self.depthwise_conv.build(input_shape)
        self.depthwise_conv.set_weights([kernel])

        super().build(input_shape)

    def call(self, inputs):
        return self.depthwise_conv(inputs)

    def get_config(self):
        config = super().get_config()
        config.update({
            "kernel_2d": self.kernel_2d.tolist(),
        })
        return config


# =========================================================
# FIXED KERNEL BRANCH
# =========================================================
def fixed_kernel_block(x, kernel):
    x = FixedDepthwiseConv2D(kernel)(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x


# =========================================================
# U-NET BLOCKS
# =========================================================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x


def down_block(x, filters):
    c = conv_block(x, filters)
    p = layers.MaxPool2D((2, 2))(c)
    p = layers.Dropout(0.2)(p)
    return c, p


def up_block(x, skip, skip_fixed, filters):
    x = layers.Conv2DTranspose(filters, 2, strides=2, padding="same")(x)
    x = layers.Concatenate()([x, skip, skip_fixed])
    x = layers.Dropout(0.2)(x)
    x = conv_block(x, filters)
    return x


# =========================================================
# BUILD MODEL
# =========================================================
def build_unet(input_shape=(256, 256, 3)):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1, p1 = down_block(inputs, 32)
    c2, p2 = down_block(p1, 64)
    c3, p3 = down_block(p2, 128)
    c4, p4 = down_block(p3, 256)

    fixed_kernel = np.array([
        [0,  1, 0],
        [1, -4, 1],
        [0,  1, 0]
    ], dtype=np.float32)

    # Fixed-kernel transformed skips
    c1_star = fixed_kernel_block(c1, fixed_kernel)
    c2_star = fixed_kernel_block(c2, fixed_kernel)
    c3_star = fixed_kernel_block(c3, fixed_kernel)
    c4_star = fixed_kernel_block(c4, fixed_kernel)

    # Bottleneck
    bottleneck = conv_block(p4, 512)

    # Decoder
    u1 = up_block(bottleneck, c4, c4_star, 256)
    u2 = up_block(u1, c3, c3_star, 128)
    u3 = up_block(u2, c2, c2_star, 64)
    u4 = up_block(u3, c1, c1_star, 32)

    outputs = layers.Conv2D(1, 1, activation="sigmoid")(u4)

    model = Model(inputs, outputs, name="UNet_Binary_FixedSkip")
    return model


model = build_unet()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=dice_loss,
    metrics=["accuracy", dice_coef, iou_coef]
)

model.summary()

# =========================
# CALLBACKS
# =========================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "best_unet.keras",
        monitor="val_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# =========================
# TRAIN
# =========================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS: ACCURACY, DICE, IOU
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)

    plt.figure(figsize=(18, 5))

    # Accuracy
    plt.subplot(1, 3, 1)
    plt.plot(epochs_range, hist["accuracy"], label="Train Accuracy")
    plt.plot(epochs_range, hist["val_accuracy"], label="Val Accuracy")
    plt.title("Accuracy Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    # Dice Score
    plt.subplot(1, 3, 2)
    plt.plot(epochs_range, hist["dice_coef"], label="Train Dice")
    plt.plot(epochs_range, hist["val_dice_coef"], label="Val Dice")
    plt.title("Dice Score Curve")
    plt.xlabel("Epoch")
    plt.ylabel("Dice Coefficient")
    plt.legend()
    plt.grid(True)

    # IoU
    plt.subplot(1, 3, 3)
    plt.plot(epochs_range, hist["iou_coef"], label="Train IoU")
    plt.plot(epochs_range, hist["val_iou_coef"], label="Val IoU")
    plt.title("IoU Curve")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_curves(history)

# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

# Show one validation sample
show_prediction(model, val_pairs[0])
# Out:
# Train samples: 12
# Val samples: 4
# Model: "UNet_Binary_FixedSkip"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 256, 256,  │        896 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_44 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_44[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_39[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_45 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 128, 128,  │          0 │ re_lu_45[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 128, 128,  │          0 │ max_pooling2d_8[… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 128, 128,  │     18,496 │ dropout_16[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_40[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_46 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_46[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_41[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_47 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_9     │ (None, 64, 64,    │          0 │ re_lu_47[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_17          │ (None, 64, 64,    │          0 │ max_pooling2d_9[… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 64, 64,    │     73,856 │ dropout_17[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_42[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_48 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_48[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_43[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_49 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_10    │ (None, 32, 32,    │          0 │ re_lu_49[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 32, 32,    │          0 │ max_pooling2d_10… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 32, 32,    │    295,168 │ dropout_18[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_44[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_50 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_50[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_45[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_51 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_11    │ (None, 16, 16,    │          0 │ re_lu_51[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 16, 16,    │          0 │ max_pooling2d_11… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 16, 16,    │  1,180,160 │ dropout_19[0][0]  │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_46[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_56 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ re_lu_56[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ conv2d_47[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fixed_depthwise_co… │ (None, 32, 32,    │      2,304 │ re_lu_51[0][0]    │
# │ (FixedDepthwiseCon… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_57 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ fixed_depthwise_… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_8  │ (None, 32, 32,    │    524,544 │ re_lu_57[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_55 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 768)              │            │ re_lu_51[0][0],   │
# │                     │                   │            │ re_lu_55[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 32, 32,    │          0 │ concatenate_8[0]… │
# │ (Dropout)           │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 32, 32,    │  1,769,728 │ dropout_20[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_48[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_58 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_58[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_49[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fixed_depthwise_co… │ (None, 64, 64,    │      1,152 │ re_lu_49[0][0]    │
# │ (FixedDepthwiseCon… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_59 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ fixed_depthwise_… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_9  │ (None, 64, 64,    │    131,200 │ re_lu_59[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_54 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 384)              │            │ re_lu_49[0][0],   │
# │                     │                   │            │ re_lu_54[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 64, 64,    │          0 │ concatenate_9[0]… │
# │ (Dropout)           │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 64, 64,    │    442,496 │ dropout_21[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_50[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_60 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_60[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_51[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fixed_depthwise_co… │ (None, 128, 128,  │        576 │ re_lu_47[0][0]    │
# │ (FixedDepthwiseCon… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_61 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ fixed_depthwise_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_10 │ (None, 128, 128,  │     32,832 │ re_lu_61[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_53 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 192)              │            │ re_lu_47[0][0],   │
# │                     │                   │            │ re_lu_53[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 128, 128,  │          0 │ concatenate_10[0… │
# │ (Dropout)           │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 128, 128,  │    110,656 │ dropout_22[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_52[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_62 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_62[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_53[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fixed_depthwise_co… │ (None, 256, 256,  │        288 │ re_lu_45[0][0]    │
# │ (FixedDepthwiseCon… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_63 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ fixed_depthwise_… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_11 │ (None, 256, 256,  │      8,224 │ re_lu_63[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_52 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 96)               │            │ re_lu_45[0][0],   │
# │                     │                   │            │ re_lu_52[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 256, 256,  │          0 │ concatenate_11[0… │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 256, 256,  │     27,680 │ dropout_23[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_54[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_64 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_64[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_55[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_65 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 256, 256,  │         33 │ re_lu_65[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,561,473 (32.66 MB)
#  Trainable params: 8,550,305 (32.62 MB)
#  Non-trainable params: 11,168 (43.62 KB)
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.5950 - dice_coef: 0.6115 - iou_coef: 0.4407 - loss: 0.3885
# Epoch 1: val_dice_coef improved from None to 0.30970, saving model to best_unet.keras
#
# Epoch 1: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.6085 - dice_coef: 0.6152 - iou_coef: 0.4446 - loss: 0.3848 - val_accuracy: 0.4360 - val_dice_coef: 0.3097 - val_iou_coef: 0.1832 - val_loss: 0.6903 - learning_rate: 1.0000e-04
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.6404 - dice_coef: 0.6302 - iou_coef: 0.4602 - loss: 0.3698
# Epoch 2: val_dice_coef improved from 0.30970 to 0.32680, saving model to best_unet.keras
#
# Epoch 2: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6398 - dice_coef: 0.6315 - iou_coef: 0.4616 - loss: 0.3685 - val_accuracy: 0.4353 - val_dice_coef: 0.3268 - val_iou_coef: 0.1953 - val_loss: 0.6732 - learning_rate: 1.0000e-04
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.6356 - dice_coef: 0.6285 - iou_coef: 0.4585 - loss: 0.3715
# Epoch 3: val_dice_coef improved from 0.32680 to 0.33822, saving model to best_unet.keras
#
# Epoch 3: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.6502 - dice_coef: 0.6394 - iou_coef: 0.4702 - loss: 0.3606 - val_accuracy: 0.4340 - val_dice_coef: 0.3382 - val_iou_coef: 0.2035 - val_loss: 0.6618 - learning_rate: 1.0000e-04
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.6579 - dice_coef: 0.6515 - iou_coef: 0.4835 - loss: 0.3485
# Epoch 4: val_dice_coef improved from 0.33822 to 0.34694, saving model to best_unet.keras
#
# Epoch 4: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.6628 - dice_coef: 0.6510 - iou_coef: 0.4830 - loss: 0.3490 - val_accuracy: 0.4325 - val_dice_coef: 0.3469 - val_iou_coef: 0.2099 - val_loss: 0.6531 - learning_rate: 1.0000e-04
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - accuracy: 0.6631 - dice_coef: 0.6579 - iou_coef: 0.4903 - loss: 0.3421
# Epoch 5: val_dice_coef improved from 0.34694 to 0.35215, saving model to best_unet.keras
#
# Epoch 5: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6725 - dice_coef: 0.6672 - iou_coef: 0.5010 - loss: 0.3328 - val_accuracy: 0.4312 - val_dice_coef: 0.3521 - val_iou_coef: 0.2137 - val_loss: 0.6479 - learning_rate: 1.0000e-04
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.6858 - dice_coef: 0.6684 - iou_coef: 0.5021 - loss: 0.3316
# Epoch 6: val_dice_coef improved from 0.35215 to 0.35607, saving model to best_unet.keras
#
# Epoch 6: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6878 - dice_coef: 0.6783 - iou_coef: 0.5136 - loss: 0.3217 - val_accuracy: 0.4293 - val_dice_coef: 0.3561 - val_iou_coef: 0.2166 - val_loss: 0.6439 - learning_rate: 1.0000e-04
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 848ms/step - accuracy: 0.6763 - dice_coef: 0.6711 - iou_coef: 0.5054 - loss: 0.3289
# Epoch 7: val_dice_coef improved from 0.35607 to 0.35942, saving model to best_unet.keras
#
# Epoch 7: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.6907 - dice_coef: 0.6839 - iou_coef: 0.5200 - loss: 0.3161 - val_accuracy: 0.4267 - val_dice_coef: 0.3594 - val_iou_coef: 0.2191 - val_loss: 0.6406 - learning_rate: 1.0000e-04
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 0.7159 - dice_coef: 0.6918 - iou_coef: 0.5290 - loss: 0.3082
# Epoch 8: val_dice_coef improved from 0.35942 to 0.37071, saving model to best_unet.keras
#
# Epoch 8: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7112 - dice_coef: 0.6928 - iou_coef: 0.5302 - loss: 0.3072 - val_accuracy: 0.4206 - val_dice_coef: 0.3707 - val_iou_coef: 0.2275 - val_loss: 0.6293 - learning_rate: 1.0000e-04
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 596ms/step - accuracy: 0.6852 - dice_coef: 0.6840 - iou_coef: 0.5199 - loss: 0.3160
# Epoch 9: val_dice_coef improved from 0.37071 to 0.38448, saving model to best_unet.keras
#
# Epoch 9: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6896 - dice_coef: 0.6918 - iou_coef: 0.5290 - loss: 0.3082 - val_accuracy: 0.4101 - val_dice_coef: 0.3845 - val_iou_coef: 0.2380 - val_loss: 0.6155 - learning_rate: 1.0000e-04
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.7185 - dice_coef: 0.7064 - iou_coef: 0.5462 - loss: 0.2936
# Epoch 10: val_dice_coef improved from 0.38448 to 0.40364, saving model to best_unet.keras
#
# Epoch 10: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7173 - dice_coef: 0.7062 - iou_coef: 0.5460 - loss: 0.2938 - val_accuracy: 0.3918 - val_dice_coef: 0.4036 - val_iou_coef: 0.2528 - val_loss: 0.5964 - learning_rate: 1.0000e-04
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 750ms/step - accuracy: 0.7170 - dice_coef: 0.7082 - iou_coef: 0.5483 - loss: 0.2918
# Epoch 11: val_dice_coef improved from 0.40364 to 0.42557, saving model to best_unet.keras
#
# Epoch 11: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7141 - dice_coef: 0.7066 - iou_coef: 0.5464 - loss: 0.2934 - val_accuracy: 0.3629 - val_dice_coef: 0.4256 - val_iou_coef: 0.2703 - val_loss: 0.5744 - learning_rate: 1.0000e-04
# Epoch 12/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 659ms/step - accuracy: 0.7237 - dice_coef: 0.7183 - iou_coef: 0.5606 - loss: 0.2817
# Epoch 12: val_dice_coef improved from 0.42557 to 0.45055, saving model to best_unet.keras
#
# Epoch 12: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7088 - dice_coef: 0.7098 - iou_coef: 0.5504 - loss: 0.2902 - val_accuracy: 0.3377 - val_dice_coef: 0.4505 - val_iou_coef: 0.2908 - val_loss: 0.5495 - learning_rate: 1.0000e-04
# Epoch 13/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.7300 - dice_coef: 0.7252 - iou_coef: 0.5697 - loss: 0.2748
# Epoch 13: val_dice_coef improved from 0.45055 to 0.47003, saving model to best_unet.keras
#
# Epoch 13: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7158 - dice_coef: 0.7107 - iou_coef: 0.5518 - loss: 0.2893 - val_accuracy: 0.3409 - val_dice_coef: 0.4700 - val_iou_coef: 0.3072 - val_loss: 0.5300 - learning_rate: 1.0000e-04
# Epoch 14/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 835ms/step - accuracy: 0.7180 - dice_coef: 0.7213 - iou_coef: 0.5642 - loss: 0.2787
# Epoch 14: val_dice_coef improved from 0.47003 to 0.48885, saving model to best_unet.keras
#
# Epoch 14: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.7111 - dice_coef: 0.7153 - iou_coef: 0.5570 - loss: 0.2847 - val_accuracy: 0.3672 - val_dice_coef: 0.4888 - val_iou_coef: 0.3235 - val_loss: 0.5112 - learning_rate: 1.0000e-04
# Epoch 15/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.7042 - dice_coef: 0.7140 - iou_coef: 0.5560 - loss: 0.2860
# Epoch 15: val_dice_coef improved from 0.48885 to 0.50256, saving model to best_unet.keras
#
# Epoch 15: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7065 - dice_coef: 0.7157 - iou_coef: 0.5583 - loss: 0.2843 - val_accuracy: 0.3965 - val_dice_coef: 0.5026 - val_iou_coef: 0.3356 - val_loss: 0.4974 - learning_rate: 1.0000e-04
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 524ms/step - accuracy: 0.7186 - dice_coef: 0.7204 - iou_coef: 0.5632 - loss: 0.2796
# Epoch 16: val_dice_coef improved from 0.50256 to 0.51575, saving model to best_unet.keras
#
# Epoch 16: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7314 - dice_coef: 0.7319 - iou_coef: 0.5778 - loss: 0.2681 - val_accuracy: 0.4204 - val_dice_coef: 0.5158 - val_iou_coef: 0.3475 - val_loss: 0.4842 - learning_rate: 1.0000e-04
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 675ms/step - accuracy: 0.7108 - dice_coef: 0.7133 - iou_coef: 0.5549 - loss: 0.2867
# Epoch 17: val_dice_coef improved from 0.51575 to 0.53603, saving model to best_unet.keras
#
# Epoch 17: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7290 - dice_coef: 0.7301 - iou_coef: 0.5756 - loss: 0.2699 - val_accuracy: 0.4488 - val_dice_coef: 0.5360 - val_iou_coef: 0.3661 - val_loss: 0.4640 - learning_rate: 1.0000e-04
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 837ms/step - accuracy: 0.7420 - dice_coef: 0.7414 - iou_coef: 0.5892 - loss: 0.2586
# Epoch 18: val_dice_coef improved from 0.53603 to 0.55487, saving model to best_unet.keras
#
# Epoch 18: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7437 - dice_coef: 0.7421 - iou_coef: 0.5901 - loss: 0.2579 - val_accuracy: 0.4917 - val_dice_coef: 0.5549 - val_iou_coef: 0.3840 - val_loss: 0.4451 - learning_rate: 1.0000e-04
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.7285 - dice_coef: 0.7326 - iou_coef: 0.5785 - loss: 0.2674
# Epoch 19: val_dice_coef improved from 0.55487 to 0.57007, saving model to best_unet.keras
#
# Epoch 19: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7479 - dice_coef: 0.7462 - iou_coef: 0.5960 - loss: 0.2538 - val_accuracy: 0.5314 - val_dice_coef: 0.5701 - val_iou_coef: 0.3987 - val_loss: 0.4299 - learning_rate: 1.0000e-04
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - accuracy: 0.7494 - dice_coef: 0.7482 - iou_coef: 0.5982 - loss: 0.2518
# Epoch 20: val_dice_coef improved from 0.57007 to 0.58890, saving model to best_unet.keras
#
# Epoch 20: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7562 - dice_coef: 0.7532 - iou_coef: 0.6050 - loss: 0.2468 - val_accuracy: 0.5633 - val_dice_coef: 0.5889 - val_iou_coef: 0.4173 - val_loss: 0.4111 - learning_rate: 1.0000e-04
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 625ms/step - accuracy: 0.7623 - dice_coef: 0.7652 - iou_coef: 0.6199 - loss: 0.2348
# Epoch 21: val_dice_coef improved from 0.58890 to 0.60353, saving model to best_unet.keras
#
# Epoch 21: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7528 - dice_coef: 0.7552 - iou_coef: 0.6069 - loss: 0.2448 - val_accuracy: 0.5741 - val_dice_coef: 0.6035 - val_iou_coef: 0.4322 - val_loss: 0.3965 - learning_rate: 1.0000e-04
# Epoch 22/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 978ms/step - accuracy: 0.7550 - dice_coef: 0.7567 - iou_coef: 0.6089 - loss: 0.2433
# Epoch 22: val_dice_coef improved from 0.60353 to 0.61918, saving model to best_unet.keras
#
# Epoch 22: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7512 - dice_coef: 0.7561 - iou_coef: 0.6081 - loss: 0.2439 - val_accuracy: 0.5757 - val_dice_coef: 0.6192 - val_iou_coef: 0.4484 - val_loss: 0.3808 - learning_rate: 1.0000e-04
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.7486 - dice_coef: 0.7582 - iou_coef: 0.6107 - loss: 0.2418
# Epoch 23: val_dice_coef improved from 0.61918 to 0.63121, saving model to best_unet.keras
#
# Epoch 23: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7494 - dice_coef: 0.7550 - iou_coef: 0.6066 - loss: 0.2450 - val_accuracy: 0.5775 - val_dice_coef: 0.6312 - val_iou_coef: 0.4611 - val_loss: 0.3688 - learning_rate: 1.0000e-04
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.7516 - dice_coef: 0.7564 - iou_coef: 0.6087 - loss: 0.2436
# Epoch 24: val_dice_coef improved from 0.63121 to 0.64614, saving model to best_unet.keras
#
# Epoch 24: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7621 - dice_coef: 0.7650 - iou_coef: 0.6198 - loss: 0.2350 - val_accuracy: 0.5757 - val_dice_coef: 0.6461 - val_iou_coef: 0.4773 - val_loss: 0.3539 - learning_rate: 1.0000e-04
# Epoch 25/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - accuracy: 0.7272 - dice_coef: 0.7465 - iou_coef: 0.5958 - loss: 0.2535
# Epoch 25: val_dice_coef improved from 0.64614 to 0.65903, saving model to best_unet.keras
#
# Epoch 25: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7481 - dice_coef: 0.7570 - iou_coef: 0.6095 - loss: 0.2430 - val_accuracy: 0.5675 - val_dice_coef: 0.6590 - val_iou_coef: 0.4915 - val_loss: 0.3410 - learning_rate: 1.0000e-04
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 717ms/step - accuracy: 0.7576 - dice_coef: 0.7645 - iou_coef: 0.6192 - loss: 0.2355
# Epoch 26: val_dice_coef improved from 0.65903 to 0.66613, saving model to best_unet.keras
#
# Epoch 26: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7683 - dice_coef: 0.7721 - iou_coef: 0.6296 - loss: 0.2279 - val_accuracy: 0.5654 - val_dice_coef: 0.6661 - val_iou_coef: 0.4994 - val_loss: 0.3339 - learning_rate: 1.0000e-04
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - accuracy: 0.7715 - dice_coef: 0.7785 - iou_coef: 0.6377 - loss: 0.2215
# Epoch 27: val_dice_coef improved from 0.66613 to 0.67003, saving model to best_unet.keras
#
# Epoch 27: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7620 - dice_coef: 0.7646 - iou_coef: 0.6195 - loss: 0.2354 - val_accuracy: 0.5745 - val_dice_coef: 0.6700 - val_iou_coef: 0.5038 - val_loss: 0.3300 - learning_rate: 1.0000e-04
# Epoch 28/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.7611 - dice_coef: 0.7727 - iou_coef: 0.6299 - loss: 0.2273
# Epoch 28: val_dice_coef improved from 0.67003 to 0.67280, saving model to best_unet.keras
#
# Epoch 28: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7683 - dice_coef: 0.7763 - iou_coef: 0.6350 - loss: 0.2237 - val_accuracy: 0.5894 - val_dice_coef: 0.6728 - val_iou_coef: 0.5069 - val_loss: 0.3272 - learning_rate: 1.0000e-04
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.7678 - dice_coef: 0.7791 - iou_coef: 0.6383 - loss: 0.2209
# Epoch 29: val_dice_coef improved from 0.67280 to 0.67391, saving model to best_unet.keras
#
# Epoch 29: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7599 - dice_coef: 0.7703 - iou_coef: 0.6267 - loss: 0.2297 - val_accuracy: 0.5987 - val_dice_coef: 0.6739 - val_iou_coef: 0.5082 - val_loss: 0.3261 - learning_rate: 1.0000e-04
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.7474 - dice_coef: 0.7542 - iou_coef: 0.6057 - loss: 0.2458
# Epoch 30: val_dice_coef improved from 0.67391 to 0.67740, saving model to best_unet.keras
#
# Epoch 30: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7554 - dice_coef: 0.7670 - iou_coef: 0.6226 - loss: 0.2330 - val_accuracy: 0.5973 - val_dice_coef: 0.6774 - val_iou_coef: 0.5122 - val_loss: 0.3226 - learning_rate: 1.0000e-04
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 659ms/step - accuracy: 0.7684 - dice_coef: 0.7802 - iou_coef: 0.6398 - loss: 0.2198
# Epoch 31: val_dice_coef improved from 0.67740 to 0.67858, saving model to best_unet.keras
#
# Epoch 31: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7734 - dice_coef: 0.7826 - iou_coef: 0.6429 - loss: 0.2174 - val_accuracy: 0.5985 - val_dice_coef: 0.6786 - val_iou_coef: 0.5135 - val_loss: 0.3214 - learning_rate: 1.0000e-04
# Epoch 32/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 653ms/step - accuracy: 0.7729 - dice_coef: 0.7806 - iou_coef: 0.6402 - loss: 0.2194
# Epoch 32: val_dice_coef improved from 0.67858 to 0.68135, saving model to best_unet.keras
#
# Epoch 32: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7752 - dice_coef: 0.7820 - iou_coef: 0.6422 - loss: 0.2180 - val_accuracy: 0.5972 - val_dice_coef: 0.6814 - val_iou_coef: 0.5167 - val_loss: 0.3186 - learning_rate: 1.0000e-04
# Epoch 33/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.7776 - dice_coef: 0.7822 - iou_coef: 0.6424 - loss: 0.2178
# Epoch 33: val_dice_coef improved from 0.68135 to 0.68338, saving model to best_unet.keras
#
# Epoch 33: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7749 - dice_coef: 0.7829 - iou_coef: 0.6433 - loss: 0.2171 - val_accuracy: 0.5976 - val_dice_coef: 0.6834 - val_iou_coef: 0.5190 - val_loss: 0.3166 - learning_rate: 1.0000e-04
# Epoch 34/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.7713 - dice_coef: 0.7748 - iou_coef: 0.6327 - loss: 0.2252
# Epoch 34: val_dice_coef improved from 0.68338 to 0.68693, saving model to best_unet.keras
#
# Epoch 34: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7756 - dice_coef: 0.7841 - iou_coef: 0.6451 - loss: 0.2159 - val_accuracy: 0.5937 - val_dice_coef: 0.6869 - val_iou_coef: 0.5231 - val_loss: 0.3131 - learning_rate: 1.0000e-04
# Epoch 35/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.7940 - dice_coef: 0.7998 - iou_coef: 0.6681 - loss: 0.2002
# Epoch 35: val_dice_coef improved from 0.68693 to 0.68872, saving model to best_unet.keras
#
# Epoch 35: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7745 - dice_coef: 0.7861 - iou_coef: 0.6490 - loss: 0.2139 - val_accuracy: 0.5896 - val_dice_coef: 0.6887 - val_iou_coef: 0.5252 - val_loss: 0.3113 - learning_rate: 1.0000e-04
# Epoch 36/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.7634 - dice_coef: 0.7718 - iou_coef: 0.6286 - loss: 0.2282
# Epoch 36: val_dice_coef improved from 0.68872 to 0.69005, saving model to best_unet.keras
#
# Epoch 36: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.7697 - dice_coef: 0.7814 - iou_coef: 0.6415 - loss: 0.2186 - val_accuracy: 0.5876 - val_dice_coef: 0.6900 - val_iou_coef: 0.5268 - val_loss: 0.3100 - learning_rate: 1.0000e-04
# Epoch 37/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.7750 - dice_coef: 0.7895 - iou_coef: 0.6523 - loss: 0.2105
# Epoch 37: val_dice_coef improved from 0.69005 to 0.69090, saving model to best_unet.keras
#
# Epoch 37: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7813 - dice_coef: 0.7907 - iou_coef: 0.6539 - loss: 0.2093 - val_accuracy: 0.5879 - val_dice_coef: 0.6909 - val_iou_coef: 0.5278 - val_loss: 0.3091 - learning_rate: 1.0000e-04
# Epoch 38/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.7928 - dice_coef: 0.8026 - iou_coef: 0.6707 - loss: 0.1974
# Epoch 38: val_dice_coef improved from 0.69090 to 0.69252, saving model to best_unet.keras
#
# Epoch 38: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7802 - dice_coef: 0.7900 - iou_coef: 0.6534 - loss: 0.2100 - val_accuracy: 0.5920 - val_dice_coef: 0.6925 - val_iou_coef: 0.5297 - val_loss: 0.3075 - learning_rate: 1.0000e-04
# Epoch 39/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.7819 - dice_coef: 0.7914 - iou_coef: 0.6549 - loss: 0.2086
# Epoch 39: val_dice_coef improved from 0.69252 to 0.69430, saving model to best_unet.keras
#
# Epoch 39: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7875 - dice_coef: 0.7961 - iou_coef: 0.6614 - loss: 0.2039 - val_accuracy: 0.5963 - val_dice_coef: 0.6943 - val_iou_coef: 0.5317 - val_loss: 0.3057 - learning_rate: 1.0000e-04
# Epoch 40/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 983ms/step - accuracy: 0.7767 - dice_coef: 0.7896 - iou_coef: 0.6524 - loss: 0.2104
# Epoch 40: val_dice_coef improved from 0.69430 to 0.69580, saving model to best_unet.keras
#
# Epoch 40: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.7865 - dice_coef: 0.7964 - iou_coef: 0.6619 - loss: 0.2036 - val_accuracy: 0.5955 - val_dice_coef: 0.6958 - val_iou_coef: 0.5335 - val_loss: 0.3042 - learning_rate: 1.0000e-04
# Epoch 41/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.7842 - dice_coef: 0.7953 - iou_coef: 0.6602 - loss: 0.2047
# Epoch 41: val_dice_coef improved from 0.69580 to 0.69682, saving model to best_unet.keras
#
# Epoch 41: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7903 - dice_coef: 0.7988 - iou_coef: 0.6651 - loss: 0.2012 - val_accuracy: 0.5933 - val_dice_coef: 0.6968 - val_iou_coef: 0.5347 - val_loss: 0.3032 - learning_rate: 1.0000e-04
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - accuracy: 0.7663 - dice_coef: 0.7772 - iou_coef: 0.6358 - loss: 0.2228
# Epoch 42: val_dice_coef improved from 0.69682 to 0.69773, saving model to best_unet.keras
#
# Epoch 42: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7588 - dice_coef: 0.7795 - iou_coef: 0.6388 - loss: 0.2205 - val_accuracy: 0.5958 - val_dice_coef: 0.6977 - val_iou_coef: 0.5358 - val_loss: 0.3023 - learning_rate: 1.0000e-04
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.7940 - dice_coef: 0.8037 - iou_coef: 0.6720 - loss: 0.1963
# Epoch 43: val_dice_coef improved from 0.69773 to 0.69840, saving model to best_unet.keras
#
# Epoch 43: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.7934 - dice_coef: 0.8015 - iou_coef: 0.6689 - loss: 0.1985 - val_accuracy: 0.6015 - val_dice_coef: 0.6984 - val_iou_coef: 0.5366 - val_loss: 0.3016 - learning_rate: 1.0000e-04
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 679ms/step - accuracy: 0.7964 - dice_coef: 0.8026 - iou_coef: 0.6711 - loss: 0.1974
# Epoch 44: val_dice_coef improved from 0.69840 to 0.70022, saving model to best_unet.keras
#
# Epoch 44: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7813 - dice_coef: 0.7926 - iou_coef: 0.6571 - loss: 0.2074 - val_accuracy: 0.6094 - val_dice_coef: 0.7002 - val_iou_coef: 0.5387 - val_loss: 0.2998 - learning_rate: 1.0000e-04
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - accuracy: 0.7807 - dice_coef: 0.7962 - iou_coef: 0.6617 - loss: 0.2038
# Epoch 45: val_dice_coef improved from 0.70022 to 0.70203, saving model to best_unet.keras
#
# Epoch 45: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7972 - dice_coef: 0.8052 - iou_coef: 0.6742 - loss: 0.1948 - val_accuracy: 0.6120 - val_dice_coef: 0.7020 - val_iou_coef: 0.5409 - val_loss: 0.2980 - learning_rate: 1.0000e-04
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.7729 - dice_coef: 0.7902 - iou_coef: 0.6532 - loss: 0.2098
# Epoch 46: val_dice_coef improved from 0.70203 to 0.70391, saving model to best_unet.keras
#
# Epoch 46: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.7810 - dice_coef: 0.7945 - iou_coef: 0.6592 - loss: 0.2055 - val_accuracy: 0.6138 - val_dice_coef: 0.7039 - val_iou_coef: 0.5431 - val_loss: 0.2961 - learning_rate: 1.0000e-04
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - accuracy: 0.7955 - dice_coef: 0.8056 - iou_coef: 0.6748 - loss: 0.1944
# Epoch 47: val_dice_coef improved from 0.70391 to 0.70625, saving model to best_unet.keras
#
# Epoch 47: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - accuracy: 0.7842 - dice_coef: 0.7996 - iou_coef: 0.6663 - loss: 0.2004 - val_accuracy: 0.6145 - val_dice_coef: 0.7063 - val_iou_coef: 0.5459 - val_loss: 0.2937 - learning_rate: 1.0000e-04
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 627ms/step - accuracy: 0.7935 - dice_coef: 0.8084 - iou_coef: 0.6787 - loss: 0.1916
# Epoch 48: val_dice_coef improved from 0.70625 to 0.70768, saving model to best_unet.keras
#
# Epoch 48: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7845 - dice_coef: 0.7967 - iou_coef: 0.6627 - loss: 0.2033 - val_accuracy: 0.6136 - val_dice_coef: 0.7077 - val_iou_coef: 0.5476 - val_loss: 0.2923 - learning_rate: 1.0000e-04
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 517ms/step - accuracy: 0.8006 - dice_coef: 0.8129 - iou_coef: 0.6850 - loss: 0.1871
# Epoch 49: val_dice_coef improved from 0.70768 to 0.70887, saving model to best_unet.keras
#
# Epoch 49: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7893 - dice_coef: 0.8020 - iou_coef: 0.6699 - loss: 0.1980 - val_accuracy: 0.6148 - val_dice_coef: 0.7089 - val_iou_coef: 0.5490 - val_loss: 0.2911 - learning_rate: 1.0000e-04
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 679ms/step - accuracy: 0.8034 - dice_coef: 0.8097 - iou_coef: 0.6808 - loss: 0.1903
# Epoch 50: val_dice_coef improved from 0.70887 to 0.71019, saving model to best_unet.keras
#
# Epoch 50: finished saving model to best_unet.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.7864 - dice_coef: 0.7993 - iou_coef: 0.6669 - loss: 0.2007 - val_accuracy: 0.6167 - val_dice_coef: 0.7102 - val_iou_coef: 0.5506 - val_loss: 0.2898 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 50.
