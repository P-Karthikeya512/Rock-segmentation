# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Rock-segmentation/blob/main/Skip_Connections_modified2_UNET%2B%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import layers, Model
from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (256, 256)
BATCH_SIZE = 4
EPOCHS = 50
SEED = 42

IMAGE_DIR = "/content/drive/MyDrive/dataset_rock/images"
MASK_DIR  = "/content/drive/MyDrive/dataset_rock/masks"

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

AUTOTUNE = tf.data.AUTOTUNE

print("Images :", len(os.listdir(IMAGE_DIR)))
print("Masks  :", len(os.listdir(MASK_DIR)))
# Out:
# Images : 16
# Masks  : 16

# %%
# =========================
# PAIR IMAGES WITH MASKS
# =========================
def get_pairs(image_dir, mask_dir):
    image_paths = []
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        image_paths.extend(glob.glob(os.path.join(image_dir, f"*.{ext}")))

    image_paths = sorted(image_paths)

    mask_map = {}
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        for p in glob.glob(os.path.join(mask_dir, f"*.{ext}")):
            stem = os.path.splitext(os.path.basename(p))[0]
            mask_map[stem] = p

    pairs = []
    for img_path in image_paths:
        stem = os.path.splitext(os.path.basename(img_path))[0]
        if stem in mask_map:
            pairs.append((img_path, mask_map[stem]))
        else:
            print(f"Warning: no mask found for {img_path}")

    return pairs

pairs = get_pairs(IMAGE_DIR, MASK_DIR)
print("Total paired samples:", len(pairs))

# =========================
# LOAD IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    img = cv2.imread(img_path.decode(), cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    mask = cv2.imread(mask_path.decode(), cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")
    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask

# =========================
# DATASET
# =========================
train_pairs, val_pairs = train_test_split(
    pairs, test_size=0.2, random_state=SEED
)

def duplicate_mask(image, mask):
    return image, (mask, mask, mask, mask)

def make_dataset(pairs, training=True, duplicate=False):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))

    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=AUTOTUNE)

    if duplicate:
        ds = ds.map(duplicate_mask, num_parallel_calls=AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds

train_ds_multi = make_dataset(train_pairs, training=True, duplicate=True)
val_ds_multi   = make_dataset(val_pairs, training=False, duplicate=True)

train_ds_single = make_dataset(train_pairs, training=True, duplicate=False)
val_ds_single   = make_dataset(val_pairs, training=False, duplicate=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))
# Out:
# Total paired samples: 16
# Train samples: 12
# Val samples: 4

# %%
# =========================
# LOSS + METRICS
# =========================
bce_loss_fn = tf.keras.losses.BinaryCrossentropy()

def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def combined_bce_dice_loss(y_true, y_pred):
    bce = bce_loss_fn(y_true, y_pred)
    dloss = dice_loss(y_true, y_pred)
    return 0.5 * bce + dloss

def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# =========================
# BLOCKS
# =========================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.ReLU()(x)
    return x

def fixed_conv_block(x, filters, name):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal", name=f"{name}_conv1")(x)
    x = layers.ReLU(name=f"{name}_relu1")(x)
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal", name=f"{name}_conv2")(x)
    x = layers.ReLU(name=f"{name}_relu2")(x)
    return x

def merge_with_fixed_convs(inputs_list, filters, prefix):
    original_feats = inputs_list
    fixed_feats = []

    for idx, feat in enumerate(original_feats):
        fixed_feat = fixed_conv_block(feat, filters, name=f"{prefix}_fix_{idx}")
        fixed_feats.append(fixed_feat)

    x = layers.Concatenate(name=f"{prefix}_concat")(original_feats + fixed_feats)

    # Optional compression to reduce channel explosion
    x = layers.Conv2D(filters, 1, padding="same", kernel_initializer="he_normal", name=f"{prefix}_compress")(x)
    x = layers.ReLU(name=f"{prefix}_compress_relu")(x)
    return x

# =========================
# BUILD UNET++ WITH YOUR ADVANCEMENT
# =========================
def build_unet_plus_plus_fixed(input_shape=(256, 256, 3)):
    """
    Modified UNet++:
    For every X(i,j), concatenate:
      1) original UNet++ features
      2) fixed-conv version of each original feature
    Then apply the main conv block.
    """
    filters = [32, 64, 128, 256, 512]
    depth = len(filters) - 1

    inputs = layers.Input(shape=input_shape)
    X = {}

    # Encoder backbone: X[i,0]
    x = inputs
    for i in range(depth + 1):
        X[(i, 0)] = conv_block(x, filters[i])
        if i < depth:
            x = layers.MaxPooling2D((2, 2))(X[(i, 0)])

    # Nested decoder / skip pathways
    for j in range(1, depth + 1):
        for i in range(0, depth - j + 1):
            up = layers.Conv2DTranspose(
                filters[i],
                kernel_size=2,
                strides=2,
                padding="same",
                name=f"up_{i}_{j}"
            )(X[(i + 1, j - 1)])

            base_feats = [X[(i, k)] for k in range(j)] + [up]
            merged = merge_with_fixed_convs(base_feats, filters[i], prefix=f"merge_{i}_{j}")
            X[(i, j)] = conv_block(merged, filters[i])

    # Deep supervision heads
    side_outputs = [
        layers.Conv2D(1, 1, activation="sigmoid", name=f"side_{j}")(X[(0, j)])
        for j in range(1, depth + 1)
    ]

    train_model = Model(inputs, side_outputs, name="UNetPlusPlus_FixedConv_Train")
    avg_output = layers.Average(name="avg_output")(side_outputs)
    infer_model = Model(inputs, avg_output, name="UNetPlusPlus_FixedConv_Infer")

    return train_model, infer_model

train_model, infer_model = build_unet_plus_plus_fixed()

train_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=[combined_bce_dice_loss for _ in range(4)],
    loss_weights=[0.25, 0.25, 0.25, 0.25],
    metrics=[
        ["accuracy", dice_coef, iou_coef],
        ["accuracy", dice_coef, iou_coef],
        ["accuracy", dice_coef, iou_coef],
        ["accuracy", dice_coef, iou_coef],
    ]
)

infer_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=combined_bce_dice_loss,
    metrics=["accuracy", dice_coef, iou_coef]
)

train_model.summary()
infer_model.summary()
# Out:
# Model: "UNetPlusPlus_FixedConv_Train"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 256, 256,  │          0 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,248 │ re_lu[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 256, 256,  │          0 │ conv2d_1[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128,  │          0 │ conv2d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,928 │ re_lu_2[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128,  │          0 │ conv2d_3[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ re_lu_3[0][0]     │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 64, 64,    │          0 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,584 │ re_lu_4[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ conv2d_5[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ re_lu_5[0][0]     │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ conv2d_6[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    590,080 │ re_lu_6[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 32, 32,    │          0 │ conv2d_7[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ re_lu_7[0][0]     │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_3[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ conv2d_8[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │  2,359,808 │ re_lu_8[0][0]     │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ conv2d_9[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_3_1              │ (None, 32, 32,    │    524,544 │ re_lu_9[0][0]     │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_2_1              │ (None, 64, 64,    │    131,200 │ re_lu_7[0][0]     │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_fix_0_co… │ (None, 32, 32,    │    590,080 │ re_lu_7[0][0]     │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_fix_1_co… │ (None, 32, 32,    │    590,080 │ up_3_1[0][0]      │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_1_1              │ (None, 128, 128,  │     32,832 │ re_lu_5[0][0]     │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_fix_0_co… │ (None, 64, 64,    │    147,584 │ re_lu_5[0][0]     │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_fix_1_co… │ (None, 64, 64,    │    147,584 │ up_2_1[0][0]      │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_fix_0_re… │ (None, 32, 32,    │          0 │ merge_3_1_fix_0_… │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_fix_1_re… │ (None, 32, 32,    │          0 │ merge_3_1_fix_1_… │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_0_1              │ (None, 256, 256,  │      8,224 │ re_lu_3[0][0]     │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_fix_0_co… │ (None, 128, 128,  │     36,928 │ re_lu_3[0][0]     │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_fix_1_co… │ (None, 128, 128,  │     36,928 │ up_1_1[0][0]      │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_fix_0_re… │ (None, 64, 64,    │          0 │ merge_2_1_fix_0_… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_fix_1_re… │ (None, 64, 64,    │          0 │ merge_2_1_fix_1_… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_fix_0_co… │ (None, 32, 32,    │    590,080 │ merge_3_1_fix_0_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_fix_1_co… │ (None, 32, 32,    │    590,080 │ merge_3_1_fix_1_… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_fix_0_co… │ (None, 256, 256,  │      9,248 │ re_lu_1[0][0]     │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_fix_1_co… │ (None, 256, 256,  │      9,248 │ up_0_1[0][0]      │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_fix_0_re… │ (None, 128, 128,  │          0 │ merge_1_1_fix_0_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_fix_1_re… │ (None, 128, 128,  │          0 │ merge_1_1_fix_1_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_fix_0_co… │ (None, 64, 64,    │    147,584 │ merge_2_1_fix_0_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_fix_1_co… │ (None, 64, 64,    │    147,584 │ merge_2_1_fix_1_… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_fix_0_re… │ (None, 32, 32,    │          0 │ merge_3_1_fix_0_… │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_fix_1_re… │ (None, 32, 32,    │          0 │ merge_3_1_fix_1_… │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_fix_0_re… │ (None, 256, 256,  │          0 │ merge_0_1_fix_0_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_fix_1_re… │ (None, 256, 256,  │          0 │ merge_0_1_fix_1_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_fix_0_co… │ (None, 128, 128,  │     36,928 │ merge_1_1_fix_0_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_fix_1_co… │ (None, 128, 128,  │     36,928 │ merge_1_1_fix_1_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_fix_0_re… │ (None, 64, 64,    │          0 │ merge_2_1_fix_0_… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_fix_1_re… │ (None, 64, 64,    │          0 │ merge_2_1_fix_1_… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_concat    │ (None, 32, 32,    │          0 │ re_lu_7[0][0],    │
# │ (Concatenate)       │ 1024)             │            │ up_3_1[0][0],     │
# │                     │                   │            │ merge_3_1_fix_0_… │
# │                     │                   │            │ merge_3_1_fix_1_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_fix_0_co… │ (None, 256, 256,  │      9,248 │ merge_0_1_fix_0_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_fix_1_co… │ (None, 256, 256,  │      9,248 │ merge_0_1_fix_1_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_fix_0_re… │ (None, 128, 128,  │          0 │ merge_1_1_fix_0_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_fix_1_re… │ (None, 128, 128,  │          0 │ merge_1_1_fix_1_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_concat    │ (None, 64, 64,    │          0 │ re_lu_5[0][0],    │
# │ (Concatenate)       │ 512)              │            │ up_2_1[0][0],     │
# │                     │                   │            │ merge_2_1_fix_0_… │
# │                     │                   │            │ merge_2_1_fix_1_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_compress  │ (None, 32, 32,    │    262,400 │ merge_3_1_concat… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_fix_0_re… │ (None, 256, 256,  │          0 │ merge_0_1_fix_0_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_fix_1_re… │ (None, 256, 256,  │          0 │ merge_0_1_fix_1_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_concat    │ (None, 128, 128,  │          0 │ re_lu_3[0][0],    │
# │ (Concatenate)       │ 256)              │            │ up_1_1[0][0],     │
# │                     │                   │            │ merge_1_1_fix_0_… │
# │                     │                   │            │ merge_1_1_fix_1_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_compress  │ (None, 64, 64,    │     65,664 │ merge_2_1_concat… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_compress… │ (None, 32, 32,    │          0 │ merge_3_1_compre… │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_concat    │ (None, 256, 256,  │          0 │ re_lu_1[0][0],    │
# │ (Concatenate)       │ 128)              │            │ up_0_1[0][0],     │
# │                     │                   │            │ merge_0_1_fix_0_… │
# │                     │                   │            │ merge_0_1_fix_1_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_compress  │ (None, 128, 128,  │     16,448 │ merge_1_1_concat… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2
1_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_fix_2_co… │ (None, 256, 256,  │      9,248 │ merge_0_2_fix_2_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_fix_0_re… │ (None, 128, 128,  │          0 │ merge_1_2_fix_0_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_fix_1_re… │ (None, 128, 128,  │          0 │ merge_1_2_fix_1_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_fix_2_re… │ (None, 128, 128,  │          0 │ merge_1_2_fix_2_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_2_concat    │ (None, 64, 64,    │          0 │ re_lu_5[0][0],    │
# │ (Concatenate)       │ 768)              │            │ re_lu_15[0][0],   │
# │                     │                   │            │ up_2_2[0][0],     │
# │                     │                   │            │ merge_2_2_fix_0_… │
# │                     │                   │            │ merge_2_2_fix_1_… │
# │                     │                   │            │ merge_2_2_fix_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_fix_0_re… │ (None, 256, 256,  │          0 │ merge_0_2_fix_0_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_fix_1_re… │ (None, 256, 256,  │          0 │ merge_0_2_fix_1_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_fix_2_re… │ (None, 256, 256,  │          0 │ merge_0_2_fix_2_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_concat    │ (None, 128, 128,  │          0 │ re_lu_3[0][0],    │
# │ (Concatenate)       │ 384)              │            │ re_lu_13[0][0],   │
# │                     │                   │            │ up_1_2[0][0],     │
# │                     │                   │            │ merge_1_2_fix_0_… │
# │                     │                   │            │ merge_1_2_fix_1_… │
# │                     │                   │            │ merge_1_2_fix_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_2_compress  │ (None, 64, 64,    │     98,432 │ merge_2_2_concat… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_concat    │ (None, 256, 256,  │          0 │ re_lu_1[0][0],    │
# │ (Concatenate)       │ 192)              │            │ re_lu_11[0][0],   │
# │                     │                   │            │ up_0_2[0][0],     │
# │                     │                   │            │ merge_0_2_fix_0_… │
# │                     │                   │            │ merge_0_2_fix_1_… │
# │                     │                   │            │ merge_0_2_fix_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_compress  │ (None, 128, 128,  │     24,640 │ merge_1_2_concat… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_2_compress… │ (None, 64, 64,    │          0 │ merge_2_2_compre… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_compress  │ (None, 256, 256,  │      6,176 │ merge_0_2_concat… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_compress… │ (None, 128, 128,  │          0 │ merge_1_2_compre… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 64, 64,    │    147,584 │ merge_2_2_compre… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_compress… │ (None, 256, 256,  │          0 │ merge_0_2_compre… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 128, 128,  │     36,928 │ merge_1_2_compre… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_22 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_22[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 256, 256,  │      9,248 │ merge_0_2_compre… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_20 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_20[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_22[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_18[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_20[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_23 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_23[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_18[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_21 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_21[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_1_3              │ (None, 128, 128,  │     32,832 │ re_lu_23[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_19 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_19[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_0_3              │ (None, 256, 256,  │      8,224 │ re_lu_21[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_0_co… │ (None, 128, 128,  │     36,928 │ re_lu_3[0][0]     │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_1_co… │ (None, 128, 128,  │     36,928 │ re_lu_13[0][0]    │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_2_co… │ (None, 128, 128,  │     36,928 │ re_lu_21[0][0]    │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_3_co… │ (None, 128, 128,  │     36,928 │ up_1_3[0][0]      │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_0_co… │ (None, 256, 256,  │      9,248 │ re_lu_1[0][0]     │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_1_co… │ (None, 256, 256,  │      9,248 │ re_lu_11[0][0]    │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_2_co… │ (None, 256, 256,  │      9,248 │ re_lu_19[0][0]    │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_3_co… │ (None, 256, 256,  │      9,248 │ up_0_3[0][0]      │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_0_re… │ (None, 128, 128,  │          0 │ merge_1_3_fix_0_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_1_re… │ (None, 128, 128,  │          0 │ merge_1_3_fix_1_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_2_re… │ (None, 128, 128,  │          0 │ merge_1_3_fix_2_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_3_re… │ (None, 128, 128,  │          0 │ merge_1_3_fix_3_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_0_re… │ (None, 256, 256,  │          0 │ merge_0_3_fix_0_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_1_re… │ (None, 256, 256,  │          0 │ merge_0_3_fix_1_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_2_re… │ (None, 256, 256,  │          0 │ merge_0_3_fix_2_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_3_re… │ (None, 256, 256,  │          0 │ merge_0_3_fix_3_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_0_co… │ (None, 128, 128,  │     36,928 │ merge_1_3_fix_0_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_1_co… │ (None, 128, 128,  │     36,928 │ merge_1_3_fix_1_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_2_co… │ (None, 128, 128,  │     36,928 │ merge_1_3_fix_2_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_3_co… │ (None, 128, 128,  │     36,928 │ merge_1_3_fix_3_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_0_co… │ (None, 256, 256,  │      9,248 │ merge_0_3_fix_0_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_1_co… │ (None, 256, 256,  │      9,248 │ merge_0_3_fix_1_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_2_co… │ (None, 256, 256,  │      9,248 │ merge_0_3_fix_2_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_3_co… │ (None, 256, 256,  │      9,248 │ merge_0_3_fix_3_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_0_re… │ (None, 128, 128,  │          0 │ merge_1_3_fix_0_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_1_re… │ (None, 128, 128,  │          0 │ merge_1_3_fix_1_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_2_re… │ (None, 128, 128,  │          0 │ merge_1_3_fix_2_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_3_re… │ (None, 128, 128,  │          0 │ merge_1_3_fix_3_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_0_re… │ (None, 256, 256,  │          0 │ merge_0_3_fix_0_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_1_re… │ (None, 256, 256,  │          0 │ merge_0_3_fix_1_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_2_re… │ (None, 256, 256,  │          0 │ merge_0_3_fix_2_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_3_re… │ (None, 256, 256,  │          0 │ merge_0_3_fix_3_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_concat    │ (None, 128, 128,  │          0 │ re_lu_3[0][0],    │
# │ (Concatenate)       │ 512)              │            │ re_lu_13[0][0],   │
# │                     │                   │            │ re_lu_21[0][0],   │
# │                     │                   │            │ up_1_3[0][0],     │
# │                     │                   │            │ merge_1_3_fix_0_… │
# │                     │                   │            │ merge_1_3_fix_1_… │
# │                     │                   │            │ merge_1_3_fix_2_… │
# │                     │                   │            │ merge_1_3_fix_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_concat    │ (None, 256, 256,  │          0 │ re_lu_1[0][0],    │
# │ (Concatenate)       │ 256)              │            │ re_lu_11[0][0],   │
# │                     │                   │            │ re_lu_19[0][0],   │
# │                     │                   │            │ up_0_3[0][0],     │
# │                     │                   │            │ merge_0_3_fix_0_… │
# │                     │                   │            │ merge_0_3_fix_1_… │
# │                     │                   │            │ merge_0_3_fix_2_… │
# │                     │                   │            │ merge_0_3_fix_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_compress  │ (None, 128, 128,  │     32,832 │ merge_1_3_concat… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_compress  │ (None, 256, 256,  │      8,224 │ merge_0_3_concat… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_compress… │ (None, 128, 128,  │          0 │ merge_1_3_compre… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_compress… │ (None, 256, 256,  │          0 │ merge_0_3_compre… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 128, 128,  │     36,928 │ merge_1_3_compre… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 256, 256,  │      9,248 │ merge_0_3_compre… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_26 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_26[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_24 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_24[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_26[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_24[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_27 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_27[0][0]   │
# │                     │ 64)               │            │                   │
# ...
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_2_co… │ (None, 128, 128,  │     36,928 │ merge_1_3_fix_2_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_3_co… │ (None, 128, 128,  │     36,928 │ merge_1_3_fix_3_… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_0_co… │ (None, 256, 256,  │      9,248 │ merge_0_3_fix_0_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_1_co… │ (None, 256, 256,  │      9,248 │ merge_0_3_fix_1_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_2_co… │ (None, 256, 256,  │      9,248 │ merge_0_3_fix_2_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_3_co… │ (None, 256, 256,  │      9,248 │ merge_0_3_fix_3_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_0_re… │ (None, 128, 128,  │          0 │ merge_1_3_fix_0_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_1_re… │ (None, 128, 128,  │          0 │ merge_1_3_fix_1_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_2_re… │ (None, 128, 128,  │          0 │ merge_1_3_fix_2_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fix_3_re… │ (None, 128, 128,  │          0 │ merge_1_3_fix_3_… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_0_re… │ (None, 256, 256,  │          0 │ merge_0_3_fix_0_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_1_re… │ (None, 256, 256,  │          0 │ merge_0_3_fix_1_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_2_re… │ (None, 256, 256,  │          0 │ merge_0_3_fix_2_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fix_3_re… │ (None, 256, 256,  │          0 │ merge_0_3_fix_3_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_concat    │ (None, 128, 128,  │          0 │ re_lu_3[0][0],    │
# │ (Concatenate)       │ 512)              │            │ re_lu_13[0][0],   │
# │                     │                   │            │ re_lu_21[0][0],   │
# │                     │                   │            │ up_1_3[0][0],     │
# │                     │                   │            │ merge_1_3_fix_0_… │
# │                     │                   │            │ merge_1_3_fix_1_… │
# │                     │                   │            │ merge_1_3_fix_2_… │
# │                     │                   │            │ merge_1_3_fix_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_concat    │ (None, 256, 256,  │          0 │ re_lu_1[0][0],    │
# │ (Concatenate)       │ 256)              │            │ re_lu_11[0][0],   │
# │                     │                   │            │ re_lu_19[0][0],   │
# │                     │                   │            │ up_0_3[0][0],     │
# │                     │                   │            │ merge_0_3_fix_0_… │
# │                     │                   │            │ merge_0_3_fix_1_… │
# │                     │                   │            │ merge_0_3_fix_2_… │
# │                     │                   │            │ merge_0_3_fix_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_compress  │ (None, 128, 128,  │     32,832 │ merge_1_3_concat… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_compress  │ (None, 256, 256,  │      8,224 │ merge_0_3_concat… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_compress… │ (None, 128, 128,  │          0 │ merge_1_3_compre… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_compress… │ (None, 256, 256,  │          0 │ merge_0_3_compre… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 128, 128,  │     36,928 │ merge_1_3_compre… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 256, 256,  │      9,248 │ merge_0_3_compre… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_26 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_26[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_24 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_24[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_26[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_24[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_27 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_27[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_25 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_25[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_0_4              │ (None, 256, 256,  │      8,224 │ re_lu_27[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_0_co… │ (None, 256, 256,  │      9,248 │ re_lu_1[0][0]     │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_1_co… │ (None, 256, 256,  │      9,248 │ re_lu_11[0][0]    │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_2_co… │ (None, 256, 256,  │      9,248 │ re_lu_19[0][0]    │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_3_co… │ (None, 256, 256,  │      9,248 │ re_lu_25[0][0]    │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_4_co… │ (None, 256, 256,  │      9,248 │ up_0_4[0][0]      │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_0_re… │ (None, 256, 256,  │          0 │ merge_0_4_fix_0_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_1_re… │ (None, 256, 256,  │          0 │ merge_0_4_fix_1_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_2_re… │ (None, 256, 256,  │          0 │ merge_0_4_fix_2_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_3_re… │ (None, 256, 256,  │          0 │ merge_0_4_fix_3_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_4_re… │ (None, 256, 256,  │          0 │ merge_0_4_fix_4_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_0_co… │ (None, 256, 256,  │      9,248 │ merge_0_4_fix_0_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_1_co… │ (None, 256, 256,  │      9,248 │ merge_0_4_fix_1_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_2_co… │ (None, 256, 256,  │      9,248 │ merge_0_4_fix_2_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_3_co… │ (None, 256, 256,  │      9,248 │ merge_0_4_fix_3_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_4_co… │ (None, 256, 256,  │      9,248 │ merge_0_4_fix_4_… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_0_re… │ (None, 256, 256,  │          0 │ merge_0_4_fix_0_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_1_re… │ (None, 256, 256,  │          0 │ merge_0_4_fix_1_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_2_re… │ (None, 256, 256,  │          0 │ merge_0_4_fix_2_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_3_re… │ (None, 256, 256,  │          0 │ merge_0_4_fix_3_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fix_4_re… │ (None, 256, 256,  │          0 │ merge_0_4_fix_4_… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_concat    │ (None, 256, 256,  │          0 │ re_lu_1[0][0],    │
# │ (Concatenate)       │ 320)              │            │ re_lu_11[0][0],   │
# │                     │                   │            │ re_lu_19[0][0],   │
# │                     │                   │            │ re_lu_25[0][0],   │
# │                     │                   │            │ up_0_4[0][0],     │
# │                     │                   │            │ merge_0_4_fix_0_… │
# │                     │                   │            │ merge_0_4_fix_1_… │
# │                     │                   │            │ merge_0_4_fix_2_… │
# │                     │                   │            │ merge_0_4_fix_3_… │
# │                     │                   │            │ merge_0_4_fix_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_compress  │ (None, 256, 256,  │     10,272 │ merge_0_4_concat… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_compress… │ (None, 256, 256,  │          0 │ merge_0_4_compre… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 256, 256,  │      9,248 │ merge_0_4_compre… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_28 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_28[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_28[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_29 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_29[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_1 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_11[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_2 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_19[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_3 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_25[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_4 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_29[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_output          │ (None, 256, 256,  │          0 │ side_1[0][0],     │
# │ (Average)           │ 1)                │            │ side_2[0][0],     │
# │                     │                   │            │ side_3[0][0],     │
# │                     │                   │            │ side_4[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 12,985,764 (49.54 MB)
#  Trainable params: 12,985,764 (49.54 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# =========================
# CALLBACK: EVALUATE AVERAGED OUTPUT MODEL
# =========================
class EvaluateAveragedModel(tf.keras.callbacks.Callback):
    def __init__(self, averaged_model, val_ds):
        super().__init__()
        self.averaged_model = averaged_model
        self.val_ds = val_ds

    def on_epoch_end(self, epoch, logs=None):
        logs = logs if logs is not None else {}

        results = self.averaged_model.evaluate(
            self.val_ds,
            verbose=0,
            return_dict=True
        )

        logs["val_avg_loss"] = float(results["loss"])
        logs["val_avg_accuracy"] = float(results["accuracy"])
        logs["val_avg_dice_coef"] = float(results["dice_coef"])
        logs["val_avg_iou_coef"] = float(results["iou_coef"])

        print(
            f"\nval_avg_loss={logs['val_avg_loss']:.4f}  "
            f"val_avg_accuracy={logs['val_avg_accuracy']:.4f}  "
            f"val_avg_dice_coef={logs['val_avg_dice_coef']:.4f}  "
            f"val_avg_iou_coef={logs['val_avg_iou_coef']:.4f}"
        )

paper_eval_cb = EvaluateAveragedModel(infer_model, val_ds_single)

# =========================
# CALLBACKS
# =========================
callbacks = [
    paper_eval_cb,
    tf.keras.callbacks.ModelCheckpoint(
        "best_unetpp_fixedconv.keras",
        monitor="val_avg_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_avg_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_avg_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# =========================
# TRAIN
# =========================
history = train_model.fit(
    train_ds_multi,
    validation_data=val_ds_multi,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)
    plt.figure(figsize=(20, 5))

    plt.subplot(1, 4, 1)
    if "side_4_accuracy" in hist:
        plt.plot(epochs_range, hist["side_4_accuracy"], label="Train Accuracy")
    if "val_avg_accuracy" in hist:
        plt.plot(epochs_range, hist["val_avg_accuracy"], label="Validation Accuracy")
    plt.title("Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 4, 2)
    if "side_4_dice_coef" in hist:
        plt.plot(epochs_range, hist["side_4_dice_coef"], label="Train Dice")
    if "val_avg_dice_coef" in hist:
        plt.plot(epochs_range, hist["val_avg_dice_coef"], label="Validation Dice")
    plt.title("Dice Coefficient")
    plt.xlabel("Epoch")
    plt.ylabel("Dice")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 4, 3)
    if "side_4_iou_coef" in hist:
        plt.plot(epochs_range, hist["side_4_iou_coef"], label="Train IoU")
    if "val_avg_iou_coef" in hist:
        plt.plot(epochs_range, hist["val_avg_iou_coef"], label="Validation IoU")
    plt.title("IoU")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 4, 4)
    plt.plot(epochs_range, hist["loss"], label="Train Loss")
    if "val_avg_loss" in hist:
        plt.plot(epochs_range, hist["val_avg_loss"], label="Validation Loss")
    plt.title("Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_curves(history)

# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

show_prediction(infer_model, val_pairs[0])
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 0.8558 - side_1_accuracy: 0.3858 - side_1_dice_coef: 0.5518 - side_1_iou_coef: 0.3814 - side_1_loss: 0.8061 - side_2_accuracy: 0.3422 - side_2_dice_coef: 0.4680 - side_2_iou_coef: 0.3071 - side_2_loss: 0.9519 - side_3_accuracy: 0.5991 - side_3_dice_coef: 0.5829 - side_3_iou_coef: 0.4117 - side_3_loss: 0.7571 - side_4_accuracy: 0.3488 - side_4_dice_coef: 0.4915 - side_4_iou_coef: 0.3270 - side_4_loss: 0.9080
# val_avg_loss=0.7814  val_avg_accuracy=0.5659  val_avg_dice_coef=0.5567  val_avg_iou_coef=0.3857
#
# Epoch 1: val_avg_dice_coef improved from None to 0.55668, saving model to best_unetpp_fixedconv.keras
#
# Epoch 1: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 103s 10s/step - loss: 0.8260 - side_1_accuracy: 0.4370 - side_1_dice_coef: 0.5578 - side_1_iou_coef: 0.3870 - side_1_loss: 0.7956 - side_2_accuracy: 0.3603 - side_2_dice_coef: 0.4986 - side_2_iou_coef: 0.3336 - side_2_loss: 0.8980 - side_3_accuracy: 0.6258 - side_3_dice_coef: 0.5892 - side_3_iou_coef: 0.4179 - side_3_loss: 0.7474 - side_4_accuracy: 0.3793 - side_4_dice_coef: 0.5180 - side_4_iou_coef: 0.3507 - side_4_loss: 0.8630 - val_loss: 0.7834 - val_side_1_accuracy: 0.5865 - val_side_1_dice_coef: 0.5413 - val_side_1_iou_coef: 0.3711 - val_side_1_loss: 0.8013 - val_side_2_accuracy: 0.5106 - val_side_2_dice_coef: 0.5468 - val_side_2_iou_coef: 0.3762 - val_side_2_loss: 0.7956 - val_side_3_accuracy: 0.5634 - val_side_3_dice_coef: 0.5844 - val_side_3_iou_coef: 0.4128 - val_side_3_loss: 0.7507 - val_side_4_accuracy: 0.5922 - val_side_4_dice_coef: 0.5526 - val_side_4_iou_coef: 0.3818 - val_side_4_loss: 0.7859 - val_avg_loss: 0.7814 - val_avg_accuracy: 0.5659 - val_avg_dice_coef: 0.5567 - val_avg_iou_coef: 0.3857 - learning_rate: 3.0000e-04
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 631ms/step - loss: 0.7196 - side_1_accuracy: 0.6682 - side_1_dice_coef: 0.5870 - side_1_iou_coef: 0.4155 - side_1_loss: 0.7498 - side_2_accuracy: 0.6052 - side_2_dice_coef: 0.6012 - side_2_iou_coef: 0.4301 - side_2_loss: 0.7295 - side_3_accuracy: 0.6584 - side_3_dice_coef: 0.6421 - side_3_iou_coef: 0.4734 - side_3_loss: 0.6766 - side_4_accuracy: 0.6656 - side_4_dice_coef: 0.6061 - side_4_iou_coef: 0.4352 - side_4_loss: 0.7226
# val_avg_loss=0.7104  val_avg_accuracy=0.5626  val_avg_dice_coef=0.6382  val_avg_iou_coef=0.4686
#
# Epoch 2: val_avg_dice_coef improved from 0.55668 to 0.63816, saving model to best_unetpp_fixedconv.keras
#
# Epoch 2: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.7050 - side_1_accuracy: 0.6674 - side_1_dice_coef: 0.5934 - side_1_iou_coef: 0.4219 - side_1_loss: 0.7411 - side_2_accuracy: 0.6316 - side_2_dice_coef: 0.6146 - side_2_iou_coef: 0.4440 - side_2_loss: 0.7125 - side_3_accuracy: 0.6596 - side_3_dice_coef: 0.6588 - side_3_iou_coef: 0.4918 - side_3_loss: 0.6625 - side_4_accuracy: 0.6658 - side_4_dice_coef: 0.6214 - side_4_iou_coef: 0.4512 - side_4_loss: 0.7042 - val_loss: 0.7343 - val_side_1_accuracy: 0.5707 - val_side_1_dice_coef: 0.5786 - val_side_1_iou_coef: 0.4071 - val_side_1_loss: 0.7538 - val_side_2_accuracy: 0.5626 - val_side_2_dice_coef: 0.6256 - val_side_2_iou_coef: 0.4552 - val_side_2_loss: 0.7134 - val_side_3_accuracy: 0.5626 - val_side_3_dice_coef: 0.6842 - val_side_3_iou_coef: 0.5199 - val_side_3_loss: 0.7591 - val_side_4_accuracy: 0.5632 - val_side_4_dice_coef: 0.6526 - val_side_4_iou_coef: 0.4844 - val_side_4_loss: 0.7108 - val_avg_loss: 0.7104 - val_avg_accuracy: 0.5626 - val_avg_dice_coef: 0.6382 - val_avg_iou_coef: 0.4686 - learning_rate: 3.0000e-04
# Epoch 3/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - loss: 0.6566 - side_1_accuracy: 0.6463 - side_1_dice_coef: 0.6200 - side_1_iou_coef: 0.4496 - side_1_loss: 0.7018 - side_2_accuracy: 0.6454 - side_2_dice_coef: 0.6788 - side_2_iou_coef: 0.5147 - side_2_loss: 0.6408 - side_3_accuracy: 0.6454 - side_3_dice_coef: 0.7370 - side_3_iou_coef: 0.5838 - side_3_loss: 0.6532 - side_4_accuracy: 0.6457 - side_4_dice_coef: 0.7077 - side_4_iou_coef: 0.5485 - side_4_loss: 0.6305
# val_avg_loss=0.7079  val_avg_accuracy=0.5625  val_avg_dice_coef=0.6724  val_avg_iou_coef=0.5065
#
# Epoch 3: val_avg_dice_coef improved from 0.63816 to 0.67242, saving model to best_unetpp_fixedconv.keras
#
# Epoch 3: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 609ms/step - loss: 0.6157 - side_1_accuracy: 0.6434 - side_1_dice_coef: 0.6928 - side_1_iou_coef: 0.5303 - side_1_loss: 0.6211 - side_2_accuracy: 0.6434 - side_2_dice_coef: 0.7341 - side_2_iou_coef: 0.5801 - side_2_loss: 0.6183 - side_3_accuracy: 0.6434 - side_3_dice_coef: 0.7131 - side_3_iou_coef: 0.5543 - side_3_loss: 0.6166 - side_4_accuracy: 0.6457 - side_4_dice_coef: 0.7140 - side_4_iou_coef: 0.5554 - side_4_loss: 0.6068
# val_avg_loss=0.6886  val_avg_accuracy=0.5624  val_avg_dice_coef=0.6766  val_avg_iou_coef=0.5112
#
# Epoch 5: val_avg_dice_coef improved from 0.67242 to 0.67656, saving model to best_unetpp_fixedconv.keras
#
# Epoch 5: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.5967 - side_1_accuracy: 0.6600 - side_1_dice_coef: 0.7046 - side_1_iou_coef: 0.5445 - side_1_loss: 0.6011 - side_2_accuracy: 0.6599 - side_2_dice_coef: 0.7385 - side_2_iou_coef: 0.5858 - side_2_loss: 0.5963 - side_3_accuracy: 0.6599 - side_3_dice_coef: 0.7191 - side_3_iou_coef: 0.5618 - side_3_loss: 0.5992 - side_4_accuracy: 0.6631 - side_4_dice_coef: 0.7181 - side_4_iou_coef: 0.5605 - side_4_loss: 0.5902 - val_loss: 0.6901 - val_side_1_accuracy: 0.5624 - val_side_1_dice_coef: 0.6719 - val_side_1_iou_coef: 0.5059 - val_side_1_loss: 0.6870 - val_side_2_accuracy: 0.5624 - val_side_2_dice_coef: 0.6795 - val_side_2_iou_coef: 0.5145 - val_side_2_loss: 0.6961 - val_side_3_accuracy: 0.5624 - val_side_3_dice_coef: 0.6694 - val_side_3_iou_coef: 0.5031 - val_side_3_loss: 0.6940 - val_side_4_accuracy: 0.5659 - val_side_4_dice_coef: 0.6853 - val_side_4_iou_coef: 0.5213 - val_side_4_loss: 0.6833 - val_avg_loss: 0.6886 - val_avg_accuracy: 0.5624 - val_avg_dice_coef: 0.6766 - val_avg_iou_coef: 0.5112 - learning_rate: 3.0000e-04
# Epoch 6/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - loss: 0.6197 - side_1_accuracy: 0.6311 - side_1_dice_coef: 0.7114 - side_1_iou_coef: 0.5530 - side_1_loss: 0.6195 - side_2_accuracy: 0.6311 - side_2_dice_coef: 0.7176 - side_2_iou_coef: 0.5604 - side_2_loss: 0.6223 - side_3_accuracy: 0.6311 - side_3_dice_coef: 0.7075 - side_3_iou_coef: 0.5482 - side_3_loss: 0.6254 - side_4_accuracy: 0.6320 - side_4_dice_coef: 0.7257 - side_4_iou_coef: 0.5705 - side_4_loss: 0.6116
# val_avg_loss=0.6921  val_avg_accuracy=0.5624  val_avg_dice_coef=0.6906  val_avg_iou_coef=0.5274
#
# Epoch 6: val_avg_dice_coef improved from 0.67656 to 0.69063, saving model to best_unetpp_fixedconv.keras
#
# Epoch 6: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.5850 - side_1_accuracy: 0.6466 - side_1_dice_coef: 0.7503 - side_1_iou_coef: 0.6007 - side_1_loss: 0.5953 - side_2_accuracy: 0.6467 - side_2_dice_coef: 0.7451 - side_2_iou_coef: 0.5940 - side_2_loss: 0.5871 - side_3_accuracy: 0.6469 - side_3_dice_coef: 0.7449 - side_3_iou_coef: 0.5937 - side_3_loss: 0.5939 - side_4_accuracy: 0.6657 - side_4_dice_coef: 0.7467 - side_4_iou_coef: 0.5961 - side_4_loss: 0.5638
# val_avg_loss=0.6792  val_avg_accuracy=0.5631  val_avg_dice_coef=0.6990  val_avg_iou_coef=0.5373
#
# Epoch 8: val_avg_dice_coef improved from 0.69647 to 0.69900, saving model to best_unetpp_fixedconv.keras
#
# Epoch 8: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.5722 - side_1_accuracy: 0.6599 - side_1_dice_coef: 0.7523 - side_1_iou_coef: 0.6034 - side_1_loss: 0.5798 - side_2_accuracy: 0.6600 - side_2_dice_coef: 0.7465 - side_2_iou_coef: 0.5959 - side_2_loss: 0.5735 - side_3_accuracy: 0.6601 - side_3_dice_coef: 0.7456 - side_3_iou_coef: 0.5947 - side_3_loss: 0.5802 - side_4_accuracy: 0.6834 - side_4_dice_coef: 0.7409 - side_4_iou_coef: 0.5887 - side_4_loss: 0.5553 - val_loss: 0.6817 - val_side_1_accuracy: 0.5624 - val_side_1_dice_coef: 0.6966 - val_side_1_iou_coef: 0.5345 - val_side_1_loss: 0.6914 - val_side_2_accuracy: 0.5628 - val_side_2_dice_coef: 0.6952 - val_side_2_iou_coef: 0.5328 - val_side_2_loss: 0.6856 - val_side_3_accuracy: 0.5630 - val_side_3_dice_coef: 0.6934 - val_side_3_iou_coef: 0.5307 - val_side_3_loss: 0.6879 - val_side_4_accuracy: 0.6042 - val_side_4_dice_coef: 0.7108 - val_side_4_iou_coef: 0.5514 - val_side_4_loss: 0.6618 - val_avg_loss: 0.6792 - val_avg_accuracy: 0.5631 - val_avg_dice_coef: 0.6990 - val_avg_iou_coef: 0.5373 - learning_rate: 3.0000e-04
# Epoch 9/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - loss: 0.5888 - side_1_accuracy: 0.6421 - side_1_dice_coef: 0.7377 - side_1_iou_coef: 0.5847 - side_1_loss: 0.5979 - side_2_accuracy: 0.6422 - side_2_dice_coef: 0.7373 - side_2_iou_coef: 0.5842 - side_2_loss: 0.5906 - side_3_accuracy: 0.6424 - side_3_dice_coef: 0.7335 - side_3_iou_coef: 0.5794 - side_3_loss: 0.5972 - side_4_accuracy: 0.6564 - side_4_dice_coef: 0.7523 - side_4_iou_coef: 0.6033 - side_4_loss: 0.5695
# val_avg_loss=0.6530  val_avg_accuracy=0.5724  val_avg_dice_coef=0.6893  val_avg_iou_coef=0.5259
#
# Epoch 9: val_avg_dice_coef did not improve from 0.69900
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - loss: 0.5832 - side_1_accuracy: 0.6621 - side_1_dice_coef: 0.7237 - side_1_iou_coef: 0.5682 - side_1_loss: 0.5883 - side_2_accuracy: 0.6472 - side_2_dice_coef: 0.7216 - side_2_iou_coef: 0.5657 - side_2_loss: 0.5879 - side_3_accuracy: 0.6495 - side_3_dice_coef: 0.7223 - side_3_iou_coef: 0.5664 - side_3_loss: 0.5877 - side_4_accuracy: 0.7288 - side_4_dice_coef: 0.7168 - side_4_iou_coef: 0.5598 - side_4_loss: 0.5687
# val_avg_loss=0.6437  val_avg_accuracy=0.6795  val_avg_dice_coef=0.7034  val_avg_iou_coef=0.5425
#
# Epoch 17: val_avg_dice_coef did not improve from 0.70577
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 0.5301 - side_1_accuracy: 0.7044 - side_1_dice_coef: 0.7490 - side_1_iou_coef: 0.6011 - side_1_loss: 0.5316 - side_2_accuracy: 0.6927 - side_2_dice_coef: 0.7467 - side_2_iou_coef: 0.5984 - side_2_loss: 0.5316 - side_3_accuracy: 0.6935 - side_3_dice_coef: 0.7467 - side_3_iou_coef: 0.5981 - side_3_loss: 0.5323 - side_4_accuracy: 0.7526 - side_4_dice_coef: 0.7380 - side_4_iou_coef: 0.5875 - side_4_loss: 0.5251 - val_loss: 0.6465 - val_side_1_accuracy: 0.6503 - val_side_1_dice_coef: 0.7030 - val_side_1_iou_coef: 0.5421 - val_side_1_loss: 0.6444 - val_side_2_accuracy: 0.6263 - val_side_2_dice_coef: 0.7027 - val_side_2_iou_coef: 0.5417 - val_side_2_loss: 0.6554 - val_side_3_accuracy: 0.6494 - val_side_3_dice_coef: 0.7059 - val_side_3_iou_coef: 0.5454 - val_side_3_loss: 0.6477 - val_side_4_accuracy: 0.6874 - val_side_4_dice_coef: 0.7019 - val_side_4_iou_coef: 0.5407 - val_side_4_loss: 0.6387 - val_avg_loss: 0.6437 - val_avg_accuracy: 0.6795 - val_avg_dice_coef: 0.7034 - val_avg_iou_coef: 0.5425 - learning_rate: 1.5000e-04
# Epoch 18/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - loss: 0.5188 - side_1_accuracy: 0.6955 - side_1_dice_coef: 0.7670 - side_1_iou_coef: 0.6221 - side_1_loss: 0.5302 - side_2_accuracy: 0.6868 - side_2_dice_coef: 0.7730 - side_2_iou_coef: 0.6300 - side_2_loss: 0.5236 - side_3_accuracy: 0.6955 - side_3_dice_coef: 0.7728 - side_3_iou_coef: 0.6299 - side_3_loss: 0.5208 - side_4_accuracy: 0.7422 - side_4_dice_coef: 0.7773 - side_4_iou_coef: 0.6359 - side_4_loss: 0.5005
# val_avg_loss=0.6572  val_avg_accuracy=0.6817  val_avg_dice_coef=0.7138  val_avg_iou_coef=0.5550
#
# Epoch 18: val_avg_dice_coef improved from 0.70577 to 0.71384, saving model to best_unetpp_fixedconv.keras
#
# Epoch 18: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 628ms/step - loss: 0.5287 - side_1_accuracy: 0.7183 - side_1_dice_coef: 0.7583 - side_1_iou_coef: 0.6117 - side_1_loss: 0.5288 - side_2_accuracy: 0.7047 - side_2_dice_coef: 0.7628 - side_2_iou_coef: 0.6180 - side_2_loss: 0.5343 - side_3_accuracy: 0.7336 - side_3_dice_coef: 0.7574 - side_3_iou_coef: 0.6115 - side_3_loss: 0.5278 - side_4_accuracy: 0.7403 - side_4_dice_coef: 0.7676 - side_4_iou_coef: 0.6252 - side_4_loss: 0.5238
# val_avg_loss=0.6435  val_avg_accuracy=0.6955  val_avg_dice_coef=0.7002  val_avg_iou_coef=0.5387
#
# Epoch 20: val_avg_dice_coef did not improve from 0.71384
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 0.5285 - side_1_accuracy: 0.7429 - side_1_dice_coef: 0.7507 - side_1_iou_coef: 0.6019 - side_1_loss: 0.5207 - side_2_accuracy: 0.7281 - side_2_dice_coef: 0.7515 - side_2_iou_coef: 0.6032 - side_2_loss: 0.5275 - side_3_accuracy: 0.7467 - side_3_dice_coef: 0.7401 - side_3_iou_coef: 0.5892 - side_3_loss: 0.5324 - side_4_accuracy: 0.7326 - side_4_dice_coef: 0.7473 - side_4_iou_coef: 0.5985 - side_4_loss: 0.5333 - val_loss: 0.6497 - val_side_1_accuracy: 0.6863 - val_side_1_dice_coef: 0.6994 - val_side_1_iou_coef: 0.5377 - val_side_1_loss: 0.6335 - val_side_2_accuracy: 0.6736 - val_side_2_dice_coef: 0.7004 - val_side_2_iou_coef: 0.5389 - val_side_2_loss: 0.6561 - val_side_3_accuracy: 0.6973 - val_side_3_dice_coef: 0.6997 - val_side_3_iou_coef: 0.5381 - val_side_3_loss: 0.6402 - val_side_4_accuracy: 0.6738 - val_side_4_dice_coef: 0.7013 - val_side_4_iou_coef: 0.5400 - val_side_4_loss: 0.6691 - val_avg_loss: 0.6435 - val_avg_accuracy: 0.6955 - val_avg_dice_coef: 0.7002 - val_avg_iou_coef: 0.5387 - learning_rate: 1.5000e-04
# Epoch 21/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - loss: 0.4842 - side_1_accuracy: 0.7667 - side_1_dice_coef: 0.7742 - side_1_iou_coef: 0.6317 - side_1_loss: 0.4861 - side_2_accuracy: 0.7515 - side_2_dice_coef: 0.7812 - side_2_iou_coef: 0.6411 - side_2_loss: 0.4895 - side_3_accuracy: 0.7740 - side_3_dice_coef: 0.7807 - side_3_iou_coef: 0.6404 - side_3_loss: 0.4830 - side_4_accuracy: 0.7693 - side_4_dice_coef: 0.7916 - side_4_iou_coef: 0.6551 - side_4_loss: 0.4784
# val_avg_loss=0.6851  val_avg_accuracy=0.6840  val_avg_dice_coef=0.7272  val_avg_iou_coef=0.5713
#
# Epoch 21: val_avg_dice_coef improved from 0.71384 to 0.72718, saving model to best_unetpp_fixedconv.keras
#
# Epoch 21: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.
# Epoch 23/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 619ms/step - loss: 0.4719 - side_1_accuracy: 0.7604 - side_1_dice_coef: 0.7830 - side_1_iou_coef: 0.6459 - side_1_loss: 0.4757 - side_2_accuracy: 0.7585 - side_2_dice_coef: 0.7871 - side_2_iou_coef: 0.6522 - side_2_loss: 0.4768 - side_3_accuracy: 0.7743 - side_3_dice_coef: 0.7866 - side_3_iou_coef: 0.6518 - side_3_loss: 0.4686 - side_4_accuracy: 0.7730 - side_4_dice_coef: 0.7941 - side_4_iou_coef: 0.6619 - side_4_loss: 0.4666
# val_avg_loss=0.6303  val_avg_accuracy=0.6909  val_avg_dice_coef=0.6921  val_avg_iou_coef=0.5291
#
# Epoch 23: val_avg_dice_coef did not improve from 0.72718
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 0.5047 - side_1_accuracy: 0.7536 - side_1_dice_coef: 0.7567 - side_1_iou_coef: 0.6108 - side_1_loss: 0.5065 - side_2_accuracy: 0.7513 - side_2_dice_coef: 0.7566 - side_2_iou_coef: 0.6113 - side_2_loss: 0.5119 - side_3_accuracy: 0.7675 - side_3_dice_coef: 0.7548 - side_3_iou_coef: 0.6094 - side_3_loss: 0.5036 - side_4_accuracy: 0.7648 - side_4_dice_coef: 0.7637 - side_4_iou_coef: 0.6208 - side_4_loss: 0.4969 - val_loss: 0.6347 - val_side_1_accuracy: 0.6889 - val_side_1_dice_coef: 0.6959 - val_side_1_iou_coef: 0.5336 - val_side_1_loss: 0.6258 - val_side_2_accuracy: 0.6936 - val_side_2_dice_coef: 0.6913 - val_side_2_iou_coef: 0.5282 - val_side_2_loss: 0.6421 - val_side_3_accuracy: 0.6932 - val_side_3_dice_coef: 0.6910 - val_side_3_iou_coef: 0.5279 - val_side_3_loss: 0.6258 - val_side_4_accuracy: 0.6718 - val_side_4_dice_coef: 0.6899 - val_side_4_iou_coef: 0.5266 - val_side_4_loss: 0.6451 - val_avg_loss: 0.6303 - val_avg_accuracy: 0.6909 - val_avg_dice_coef: 0.6921 - val_avg_iou_coef: 0.5291 - learning_rate: 1.5000e-04
# Epoch 24/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - loss: 0.5096 - side_1_accuracy: 0.7349 - side_1_dice_coef: 0.7513 - side_1_iou_coef: 0.6021 - side_1_loss: 0.5172 - side_2_accuracy: 0.7358 - side_2_dice_coef: 0.7518 - side_2_iou_coef: 0.6027 - side_2_loss: 0.5177 - side_3_accuracy: 0.7556 - side_3_dice_coef: 0.7524 - side_3_iou_coef: 0.6033 - side_3_loss: 0.5058 - side_4_accuracy: 0.7579 - side_4_dice_coef: 0.7601 - side_4_iou_coef: 0.6132 - side_4_loss: 0.4977
# val_avg_loss=0.6421  val_avg_accuracy=0.6952  val_avg_dice_coef=0.7145  val_avg_iou_coef=0.5558
#
# Epoch 24: val_avg_dice_coef did not improve from 0.72718
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 0.
# Epoch 26/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - loss: 0.5229 - side_1_accuracy: 0.7233 - side_1_dice_coef: 0.7662 - side_1_iou_coef: 0.6212 - side_1_loss: 0.5253 - side_2_accuracy: 0.7211 - side_2_dice_coef: 0.7724 - side_2_iou_coef: 0.6294 - side_2_loss: 0.5306 - side_3_accuracy: 0.7352 - side_3_dice_coef: 0.7816 - side_3_iou_coef: 0.6417 - side_3_loss: 0.5213 - side_4_accuracy: 0.7399 - side_4_dice_coef: 0.7817 - side_4_iou_coef: 0.6419 - side_4_loss: 0.5144
# val_avg_loss=0.6388  val_avg_accuracy=0.6954  val_avg_dice_coef=0.7147  val_avg_iou_coef=0.5561
#
# Epoch 26: val_avg_dice_coef did not improve from 0.72718
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.4925 - side_1_accuracy: 0.7470 - side_1_dice_coef: 0.7750 - side_1_iou_coef: 0.6329 - side_1_loss: 0.4971 - side_2_accuracy: 0.7447 - side_2_dice_coef: 0.7804 - side_2_iou_coef: 0.6400 - side_2_loss: 0.5016 - side_3_accuracy: 0.7576 - side_3_dice_coef: 0.7904 - side_3_iou_coef: 0.6537 - side_3_loss: 0.4889 - side_4_accuracy: 0.7602 - side_4_dice_coef: 0.7912 - side_4_iou_coef: 0.6548 - side_4_loss: 0.4824 - val_loss: 0.6424 - val_side_1_accuracy: 0.6878 - val_side_1_dice_coef: 0.7104 - val_side_1_iou_coef: 0.5508 - val_side_1_loss: 0.6302 - val_side_2_accuracy: 0.6941 - val_side_2_dice_coef: 0.7101 - val_side_2_iou_coef: 0.5505 - val_side_2_loss: 0.6556 - val_side_3_accuracy: 0.6961 - val_side_3_dice_coef: 0.7194 - val_side_3_iou_coef: 0.5617 - val_side_3_loss: 0.6435 - val_side_4_accuracy: 0.6900 - val_side_4_dice_coef: 0.7193 - val_side_4_iou_coef: 0.5616 - val_side_4_loss: 0.6401 - val_avg_loss: 0.6388 - val_avg_accuracy: 0.6954 - val_avg_dice_coef: 0.7147 - val_avg_iou_coef: 0.5561 - learning_rate: 7.5000e-05
# Epoch 27/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - loss: 0.4349 - side_1_accuracy: 0.7884 - side_1_dice_coef: 0.7944 - side_1_iou_coef: 0.6602 - side_1_loss: 0.4431 - side_2_accuracy: 0.7903 - side_2_dice_coef: 0.7996 - side_2_iou_coef: 0.6676 - side_2_loss: 0.4409 - side_3_accuracy: 0.7950 - side_3_dice_coef: 0.8071 - side_3_iou_coef: 0.6778 - side_3_loss: 0.4284 - side_4_accuracy: 0.7945 - side_4_dice_coef: 0.8081 - side_4_iou_coef: 0.6792 - side_4_loss: 0.4272
# val_avg_loss=0.6340  val_avg_accuracy=0.6943  val_avg_dice_coef=0.7099  val_avg_iou_coef=0.5502
#
# Epoch 27: val_avg_dice_coef did not improve from 0.72718
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 0.
# Epoch 29/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - loss: 0.4506 - side_1_accuracy: 0.7850 - side_1_dice_coef: 0.7865 - side_1_iou_coef: 0.6499 - side_1_loss: 0.4552 - side_2_accuracy: 0.7880 - side_2_dice_coef: 0.7869 - side_2_iou_coef: 0.6507 - side_2_loss: 0.4587 - side_3_accuracy: 0.7912 - side_3_dice_coef: 0.7919 - side_3_iou_coef: 0.6573 - side_3_loss: 0.4459 - side_4_accuracy: 0.7890 - side_4_dice_coef: 0.7986 - side_4_iou_coef: 0.6665 - side_4_loss: 0.4426
# val_avg_loss=0.6319  val_avg_accuracy=0.6909  val_avg_dice_coef=0.7072  val_avg_iou_coef=0.5470
#
# Epoch 29: val_avg_dice_coef did not improve from 0.72718
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 0.4878 - side_1_accuracy: 0.7644 - side_1_dice_coef: 0.7624 - side_1_iou_coef: 0.6177 - side_1_loss: 0.4916 - side_2_accuracy: 0.7674 - side_2_dice_coef: 0.7616 - side_2_iou_coef: 0.6169 - side_2_loss: 0.4965 - side_3_accuracy: 0.7710 - side_3_dice_coef: 0.7667 - side_3_iou_coef: 0.6234 - side_3_loss: 0.4833 - side_4_accuracy: 0.7701 - side_4_dice_coef: 0.7736 - side_4_iou_coef: 0.6326 - side_4_loss: 0.4796 - val_loss: 0.6363 - val_side_1_accuracy: 0.6889 - val_side_1_dice_coef: 0.7051 - val_side_1_iou_coef: 0.5445 - val_side_1_loss: 0.6242 - val_side_2_accuracy: 0.6955 - val_side_2_dice_coef: 0.7029 - val_side_2_iou_coef: 0.5419 - val_side_2_loss: 0.6443 - val_side_3_accuracy: 0.6896 - val_side_3_dice_coef: 0.7096 - val_side_3_iou_coef: 0.5499 - val_side_3_loss: 0.6340 - val_side_4_accuracy: 0.6828 - val_side_4_dice_coef: 0.7113 - val_side_4_iou_coef: 0.5520 - val_side_4_loss: 0.6428 - val_avg_loss: 0.6319 - val_avg_accuracy: 0.6909 - val_avg_dice_coef: 0.7072 - val_avg_iou_coef: 0.5470 - learning_rate: 7.5000e-05
# Epoch 30/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 890ms/step - loss: 0.5287 - side_1_accuracy: 0.7446 - side_1_dice_coef: 0.7373 - side_1_iou_coef: 0.5853 - side_1_loss: 0.5349 - side_2_accuracy: 0.7481 - side_2_dice_coef: 0.7360 - side_2_iou_coef: 0.5838 - side_2_loss: 0.5431 - side_3_accuracy: 0.7595 - side_3_dice_coef: 0.7474 - side_3_iou_coef: 0.5981 - side_3_loss: 0.5203 - side_4_accuracy: 0.7578 - side_4_dice_coef: 0.7535 - side_4_iou_coef: 0.6058 - side_4_loss: 0.5166
# val_avg_loss=0.6348  val_avg_accuracy=0.6937  val_avg_dice_coef=0.7134  val_avg_iou_coef=0.5544
#
# Epoch 30: val_avg_dice_coef did not improve from 0.72718
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 0.4860 - side_1_accuracy: 0.7633 - side_1_dice_coef: 0.7642 - side_1_iou_coef: 0.6214 - side_1_loss: 0.4914 - side_2_accuracy: 0.7667 - side_2_dice_coef: 0.7650 - side_2_iou_coef: 0.6229 - side_2_loss: 0.4954 - side_3_accuracy: 0.7722 - side_3_dice_coef: 0.7734 - side_3_iou_coef: 0.6338 - side_3_loss: 0.4798 - side_4_accuracy: 0.7716 - side_4_dice_coef: 0.7786 - side_4_iou_coef: 0.6406 - side_4_loss: 0.4773 - val_loss: 0.6392 - val_side_1_accuracy: 0.6895 - val_side_1_dice_coef: 0.7092 - val_side_1_iou_coef: 0.5494 - val_side_1_loss: 0.6256 - val_side_2_accuracy: 0.6969 - val_side_2_dice_coef: 0.7082 - val_side_2_iou_coef: 0.5483 - val_side_2_loss: 0.6484 - val_side_3_accuracy: 0.6931 - val_side_3_dice_coef: 0.7173 - val_side_3_iou_coef: 0.5593 - val_side_3_loss: 0.6394 - val_side_4_accuracy: 0.6874 - val_side_4_dice_coef: 0.7189 - val_side_4_iou_coef: 0.5611 - val_side_4_loss: 0.6434 - val_avg_loss: 0.6348 - val_avg_accuracy: 0.6937 - val_avg_dice_coef: 0.7134 - val_avg_iou_coef: 0.5544 - learning_rate: 3.7500e-05
# Epoch 31/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - loss: 0.4832 - side_1_accuracy: 0.7606 - side_1_dice_coef: 0.7717 - side_1_iou_coef: 0.6283 - side_1_loss: 0.4901 - side_2_accuracy: 0.7640 - side_2_dice_coef: 0.7748 - side_2_iou_coef: 0.6324 - side_2_loss: 0.4929 - side_3_accuracy: 0.7701 - side_3_dice_coef: 0.7856 - side_3_iou_coef: 0.6469 - side_3_loss: 0.4757 - side_4_accuracy: 0.7691 - side_4_dice_coef: 0.7890 - side_4_iou_coef: 0.6516 - side_4_loss: 0.4741
# val_avg_loss=0.6391  val_avg_accuracy=0.6956  val_avg_dice_coef=0.7190  val_avg_iou_coef=0.5612
#
# Epoch 31: val_avg_dice_coef did not improve from 0.72718
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 0.4797 - side_1_accuracy: 0.7598 - side_1_dice_coef: 0.7738 - side_1_iou_coef: 0.6311 - side_1_loss: 0.4859 - side_2_accuracy: 0.7625 - side_2_dice_coef: 0.7769 - side_2_iou_coef: 0.6353 - side_2_loss: 0.4889 - side_3_accuracy: 0.7700 - side_3_dice_coef: 0.7875 - side_3_iou_coef: 0.6495 - side_3_loss: 0.4730 - side_4_accuracy: 0.7691 - side_4_dice_coef: 0.7911 - side_4_iou_coef: 0.6545 - side_4_loss: 0.4709 - val_loss: 0.6436 - val_side_1_accuracy: 0.6894 - val_side_1_dice_coef: 0.7132 - val_side_1_iou_coef: 0.5542 - val_side_1_loss: 0.6279 - val_side_2_accuracy: 0.6971 - val_side_2_dice_coef: 0.7133 - val_side_2_iou_coef: 0.5544 - val_side_2_loss: 0.6538 - val_side_3_accuracy: 0.6955 - val_side_3_dice_coef: 0.7241 - val_side_3_iou_coef: 0.5675 - val_side_3_loss: 0.6466 - val_side_4_accuracy: 0.6908 - val_side_4_dice_coef: 0.7254 - val_side_4_iou_coef: 0.5691 - val_side_4_loss: 0.6461 - val_avg_loss: 0.6391 - val_avg_accuracy: 0.6956 - val_avg_dice_coef: 0.7190 - val_avg_iou_coef: 0.5612 - learning_rate: 3.7500e-05
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.
