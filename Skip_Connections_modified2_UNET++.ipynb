# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Rock-segmentation/blob/main/Skip_Connections_modified2_UNET%2B%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import layers, Model
from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (256, 256)
BATCH_SIZE = 4
EPOCHS = 50
SEED = 42

IMAGE_DIR = "/content/drive/MyDrive/dataset_rock/images"
MASK_DIR  = "/content/drive/MyDrive/dataset_rock/masks"

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

AUTOTUNE = tf.data.AUTOTUNE

print("Images :", len(os.listdir(IMAGE_DIR)))
print("Masks  :", len(os.listdir(MASK_DIR)))
# Out:
# Images : 16
# Masks  : 16

# %%
# =========================
# PAIR IMAGES WITH MASKS
# =========================
def get_pairs(image_dir, mask_dir):
    image_paths = []
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        image_paths.extend(glob.glob(os.path.join(image_dir, f"*.{ext}")))

    image_paths = sorted(image_paths)

    mask_map = {}
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        for p in glob.glob(os.path.join(mask_dir, f"*.{ext}")):
            stem = os.path.splitext(os.path.basename(p))[0]
            mask_map[stem] = p

    pairs = []
    for img_path in image_paths:
        stem = os.path.splitext(os.path.basename(img_path))[0]
        if stem in mask_map:
            pairs.append((img_path, mask_map[stem]))
        else:
            print(f"Warning: no mask found for {img_path}")

    return pairs

pairs = get_pairs(IMAGE_DIR, MASK_DIR)
print("Total paired samples:", len(pairs))

# =========================
# LOAD IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    img = cv2.imread(img_path.decode(), cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    mask = cv2.imread(mask_path.decode(), cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")
    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask

# =========================
# DATASET
# =========================
train_pairs, val_pairs = train_test_split(
    pairs, test_size=0.2, random_state=SEED
)

def duplicate_mask(image, mask):
    return image, (mask, mask, mask, mask)

def make_dataset(pairs, training=True, duplicate=False):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))

    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=AUTOTUNE)

    if duplicate:
        ds = ds.map(duplicate_mask, num_parallel_calls=AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds

train_ds_multi = make_dataset(train_pairs, training=True, duplicate=True)
val_ds_multi   = make_dataset(val_pairs, training=False, duplicate=True)

train_ds_single = make_dataset(train_pairs, training=True, duplicate=False)
val_ds_single   = make_dataset(val_pairs, training=False, duplicate=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))
# Out:
# Total paired samples: 16
# Train samples: 12
# Val samples: 4

# %%
# =========================
# LOSS + METRICS
# =========================
bce_loss_fn = tf.keras.losses.BinaryCrossentropy()

def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def combined_bce_dice_loss(y_true, y_pred):
    bce = bce_loss_fn(y_true, y_pred)
    dloss = dice_loss(y_true, y_pred)
    return 0.5 * bce + dloss

def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.ReLU()(x)
    return x

class FixedKernelLayer(layers.Layer):
    """
    Fixed non-trainable kernel bank:
    - Sobel X
    - Sobel Y
    - Laplacian

    Input:  [B, H, W, C]
    Output: [B, H, W, 3C]  (concat of the three fixed responses)
    """
    def __init__(self, **kwargs):
        super().__init__(trainable=False, **kwargs)

    def build(self, input_shape):
        c = int(input_shape[-1])

        sobel_x = np.array([
            [-1, 0, 1],
            [-2, 0, 2],
            [-1, 0, 1]
        ], dtype=np.float32)

        sobel_y = np.array([
            [-1, -2, -1],
            [ 0,  0,  0],
            [ 1,  2,  1]
        ], dtype=np.float32)

        laplacian = np.array([
            [ 0,  1,  0],
            [ 1, -4,  1],
            [ 0,  1,  0]
        ], dtype=np.float32)

        def make_depthwise_kernel(base_kernel):
            k = np.zeros((3, 3, c, 1), dtype=np.float32)
            for ch in range(c):
                k[:, :, ch, 0] = base_kernel
            return tf.constant(k)

        self.k_sobel_x = make_depthwise_kernel(sobel_x)
        self.k_sobel_y = make_depthwise_kernel(sobel_y)
        self.k_lap = make_depthwise_kernel(laplacian)

    def call(self, x):
        sx = tf.nn.depthwise_conv2d(
            x, self.k_sobel_x, strides=[1, 1, 1, 1], padding="SAME"
        )
        sy = tf.nn.depthwise_conv2d(
            x, self.k_sobel_y, strides=[1, 1, 1, 1], padding="SAME"
        )
        lp = tf.nn.depthwise_conv2d(
            x, self.k_lap, strides=[1, 1, 1, 1], padding="SAME"
        )

        # Optional nonlinearity; keeps edge maps non-negative if you prefer:
        # sx = tf.abs(sx); sy = tf.abs(sy); lp = tf.abs(lp)

        return tf.concat([sx, sy, lp], axis=-1)

def merge_with_fixed_kernels(inputs_list, filters, prefix):
    """
    For each incoming tensor:
      original feature
      + fixed-kernel response of that feature
    Then concatenate all and compress with 1x1 conv.
    """
    original_feats = inputs_list
    fixed_feats = []

    for idx, feat in enumerate(original_feats):
        fk = FixedKernelLayer(name=f"{prefix}_fixed_{idx}")(feat)
        fixed_feats.append(fk)

    x = layers.Concatenate(name=f"{prefix}_concat")(original_feats + fixed_feats)

    # channel compression to control memory
    x = layers.Conv2D(filters, 1, padding="same", kernel_initializer="he_normal",
                      name=f"{prefix}_compress")(x)
    x = layers.ReLU(name=f"{prefix}_compress_relu")(x)
    return x

# =========================
# BUILD UNET++ WITH FIXED-KERNEL IMPROVEMENT
# =========================
def build_unet_plus_plus_fixed(input_shape=(256, 256, 3)):
    """
    Modified UNet++:
    For each X(i,j), use:
      - normal UNet++ inputs
      - fixed-kernel responses of each input
    Then apply the main conv block.
    """
    filters = [32, 64, 128, 256, 512]
    depth = len(filters) - 1

    inputs = layers.Input(shape=input_shape)
    X = {}

    # Encoder backbone: X[i,0]
    x = inputs
    for i in range(depth + 1):
        X[(i, 0)] = conv_block(x, filters[i])
        if i < depth:
            x = layers.MaxPooling2D((2, 2))(X[(i, 0)])

    # Nested decoder / skip pathways
    for j in range(1, depth + 1):
        for i in range(0, depth - j + 1):
            up = layers.Conv2DTranspose(
                filters[i],
                kernel_size=2,
                strides=2,
                padding="same",
                name=f"up_{i}_{j}"
            )(X[(i + 1, j - 1)])

            base_feats = [X[(i, k)] for k in range(j)] + [up]
            merged = merge_with_fixed_kernels(
                base_feats,
                filters[i],
                prefix=f"merge_{i}_{j}"
            )
            X[(i, j)] = conv_block(merged, filters[i])

    # Deep supervision heads
    side_outputs = [
        layers.Conv2D(1, 1, activation="sigmoid", name=f"side_{j}")(X[(0, j)])
        for j in range(1, depth + 1)
    ]

    train_model = Model(inputs, side_outputs, name="UNetPlusPlus_FixedKernel_Train")
    avg_output = layers.Average(name="avg_output")(side_outputs)
    infer_model = Model(inputs, avg_output, name="UNetPlusPlus_FixedKernel_Infer")

    return train_model, infer_model

train_model, infer_model = build_unet_plus_plus_fixed()

train_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=[combined_bce_dice_loss for _ in range(4)],
    loss_weights=[0.25, 0.25, 0.25, 0.25],
    metrics=[
        ["accuracy", dice_coef, iou_coef],
        ["accuracy", dice_coef, iou_coef],
        ["accuracy", dice_coef, iou_coef],
        ["accuracy", dice_coef, iou_coef],
    ]
)

infer_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=combined_bce_dice_loss,
    metrics=["accuracy", dice_coef, iou_coef]
)

train_model.summary()
infer_model.summary()
# Out:
# Model: "UNetPlusPlus_FixedKernel_Train"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 256, 256,  │        896 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_30 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_30[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_30[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_31 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_31[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 128, 128,  │          0 │ re_lu_31[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │     18,496 │ max_pooling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_32 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_32[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_32[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_33 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_33[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 64, 64,    │          0 │ re_lu_33[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 64, 64,    │     73,856 │ max_pooling2d_5[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_34 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_34[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_34[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_35 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_35[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 32, 32,    │          0 │ re_lu_35[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 32, 32,    │    295,168 │ max_pooling2d_6[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_36 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_36[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_36[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_37 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_37[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 16, 16,    │          0 │ re_lu_37[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_7[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_38 (ReLU)     │ (None, 16, 16,    │          0 │ conv2d_38[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ re_lu_38[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_39 (ReLU)     │ (None, 16, 16,    │          0 │ conv2d_39[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_3_1              │ (None, 32, 32,    │    524,544 │ re_lu_39[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_2_1              │ (None, 64, 64,    │    131,200 │ re_lu_37[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_fixed_0   │ (None, 32, 32,    │          0 │ re_lu_37[0][0]    │
# │ (FixedKernelLayer)  │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_fixed_1   │ (None, 32, 32,    │          0 │ up_3_1[0][0]      │
# │ (FixedKernelLayer)  │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_1_1              │ (None, 128, 128,  │     32,832 │ re_lu_35[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_fixed_0   │ (None, 64, 64,    │          0 │ re_lu_35[0][0]    │
# │ (FixedKernelLayer)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_fixed_1   │ (None, 64, 64,    │          0 │ up_2_1[0][0]      │
# │ (FixedKernelLayer)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_concat    │ (None, 32, 32,    │          0 │ re_lu_37[0][0],   │
# │ (Concatenate)       │ 2048)             │            │ up_3_1[0][0],     │
# │                     │                   │            │ merge_3_1_fixed_… │
# │                     │                   │            │ merge_3_1_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_0_1              │ (None, 256, 256,  │      8,224 │ re_lu_33[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_fixed_0   │ (None, 128, 128,  │          0 │ re_lu_33[0][0]    │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_fixed_1   │ (None, 128, 128,  │          0 │ up_1_1[0][0]      │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_concat    │ (None, 64, 64,    │          0 │ re_lu_35[0][0],   │
# │ (Concatenate)       │ 1024)             │            │ up_2_1[0][0],     │
# │                     │                   │            │ merge_2_1_fixed_… │
# │                     │                   │            │ merge_2_1_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_compress  │ (None, 32, 32,    │    524,544 │ merge_3_1_concat… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_fixed_0   │ (None, 256, 256,  │          0 │ re_lu_31[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_fixed_1   │ (None, 256, 256,  │          0 │ up_0_1[0][0]      │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_concat    │ (None, 128, 128,  │          0 │ re_lu_33[0][0],   │
# │ (Concatenate)       │ 512)              │            │ up_1_1[0][0],     │
# │                     │                   │            │ merge_1_1_fixed_… │
# │                     │                   │            │ merge_1_1_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_compress  │ (None, 64, 64,    │    131,200 │ merge_2_1_concat… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_compress… │ (None, 32, 32,    │          0 │ merge_3_1_compre… │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_concat    │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 256)              │            │ up_0_1[0][0],     │
# │                     │                   │            │ merge_0_1_fixed_… │
# │                     │                   │            │ merge_0_1_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_compress  │ (None, 128, 128,  │     32,832 │ merge_1_1_concat… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_compress… │ (None, 64, 64,    │          0 │ merge_2_1_compre… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 32, 32,    │    590,080 │ merge_3_1_compre… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_compress  │ (None, 256, 256,  │      8,224 │ merge_0_1_concat… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_compress… │ (None, 128, 128,  │          0 │ merge_1_1_compre… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 64, 64,    │    147,584 │ merge_2_1_compre… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_46 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_46[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_compress… │ (None, 256, 256,  │          0 │ merge_0_1_compre… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 128, 128,  │     36,928 │ merge_1_1_compre… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_44 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_44[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_46[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 256, 256,  │      9,248 │ merge_0_1_compre… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_42 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_42[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_44[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_47 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_47[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_40 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_40[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_42[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_45 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_45[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_2_2              │ (None, 64, 64,    │    131,200 │ re_lu_47[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_40[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_43 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_43[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_1_2              │ (None, 128, 128,  │     32,832 │ re_lu_45[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_2_fixed_0   │ (None, 64, 64,    │          0 │ re_lu_35[0][0]    │
# │ (FixedKernelLayer)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_2_fixed_1   │ (None, 64, 64,    │          0 │ re_lu_45[0][0]    │
# │ (FixedKernelLayer)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_2_fixed_2   │ (None, 64, 64,    │          0 │ up_2_2[0][0]      │
# │ (FixedKernelLayer)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_41 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_41[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_0_2              │ (None, 256, 256,  │      8,224 │ re_lu_43[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_fixed_0   │ (None, 128, 128,  │          0 │ re_lu_33[0][0]    │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_fixed_1   │ (None, 128, 128,  │          0 │ re_lu_43[0][0]    │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_fixed_2   │ (None, 128, 128,  │          0 │ up_1_2[0][0]      │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_2_concat    │ (None, 64, 64,    │          0 │ re_lu_35[0][0],   │
# │ (Concatenate)       │ 1536)             │            │ re_lu_45[0][0],   │
# │                     │                   │            │ up_2_2[0][0],     │
# │                     │                   │            │ merge_2_2_fixed_… │
# │                     │                   │            │ merge_2_2_fixed_… │
# │                     │                   │            │ merge_2_2_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_fixed_0   │ (None, 256, 256,  │          0 │ re_lu_31[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_fixed_1   │ (None, 256, 256,  │          0 │ re_lu_41[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_fixed_2   │ (None, 256, 256,  │          0 │ up_0_2[0][0]      │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_concat    │ (None, 128, 128,  │          0 │ re_lu_33[0][0],   │
# │ (Concatenate)       │ 768)              │            │ re_lu_43[0][0],   │
# │                     │                   │            │ up_1_2[0][0],     │
# │                     │                   │            │ merge_1_2_fixed_… │
# │                     │                   │            │ merge_1_2_fixed_… │
# │                     │                   │            │ merge_1_2_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_2_compress  │ (None, 64, 64,    │    196,736 │ merge_2_2_concat… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_concat    │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 384)              │            │ re_lu_41[0][0],   │
# │                     │                   │            │ up_0_2[0][0],     │
# │                     │                   │            │ merge_0_2_fixed_… │
# │                     │                   │            │ merge_0_2_fixed_… │
# │                     │                   │            │ merge_0_2_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_compress  │ (None, 128, 128,  │     49,216 │ merge_1_2_concat… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_2_compress… │ (None, 64, 64,    │          0 │ merge_2_2_compre… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_compress  │ (None, 256, 256,  │     12,320 │ merge_0_2_concat… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_compress… │ (None, 128, 128,  │          0 │ merge_1_2_compre… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 64, 64,    │    147,584 │ merge_2_2_compre… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_compress… │ (None, 256, 256,  │          0 │ merge_0_2_compre… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 128, 128,  │     36,928 │ merge_1_2_compre… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_52 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_52[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 256, 256,  │      9,248 │ merge_0_2_compre… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_50 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_50[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_52[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_48 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_48[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_50[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_53 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_53[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_48[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_51 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_51[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_1_3              │ (None, 128, 128,  │     32,832 │ re_lu_53[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_49 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_49[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_0_3              │ (None, 256, 256,  │      8,224 │ re_lu_51[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fixed_0   │ (None, 128, 128,  │          0 │ re_lu_33[0][0]    │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fixed_1   │ (None, 128, 128,  │          0 │ re_lu_43[0][0]    │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fixed_2   │ (None, 128, 128,  │          0 │ re_lu_51[0][0]    │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fixed_3   │ (None, 128, 128,  │          0 │ up_1_3[0][0]      │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fixed_0   │ (None, 256, 256,  │          0 │ re_lu_31[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fixed_1   │ (None, 256, 256,  │          0 │ re_lu_41[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fixed_2   │ (None, 256, 256,  │          0 │ re_lu_49[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fixed_3   │ (None, 256, 256,  │          0 │ up_0_3[0][0]      │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_concat    │ (None, 128, 128,  │          0 │ re_lu_33[0][0],   │
# │ (Concatenate)       │ 1024)             │            │ re_lu_43[0][0],   │
# │                     │                   │            │ re_lu_51[0][0],   │
# │                     │                   │            │ up_1_3[0][0],     │
# │                     │                   │            │ merge_1_3_fixed_… │
# │                     │                   │            │ merge_1_3_fixed_… │
# │                     │                   │            │ merge_1_3_fixed_… │
# │                     │                   │            │ merge_1_3_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_concat    │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 512)              │            │ re_lu_41[0][0],   │
# │                     │                   │            │ re_lu_49[0][0],   │
# │                     │                   │            │ up_0_3[0][0],     │
# │                     │                   │            │ merge_0_3_fixed_… │
# │                     │                   │            │ merge_0_3_fixed_… │
# │                     │                   │            │ merge_0_3_fixed_… │
# │                     │                   │            │ merge_0_3_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_compress  │ (None, 128, 128,  │     65,600 │ merge_1_3_concat… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_compress  │ (None, 256, 256,  │     16,416 │ merge_0_3_concat… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_compress… │ (None, 128, 128,  │          0 │ merge_1_3_compre… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_compress… │ (None, 256, 256,  │          0 │ merge_0_3_compre… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 128, 128,  │     36,928 │ merge_1_3_compre… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 256, 256,  │      9,248 │ merge_0_3_compre… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_56 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_56[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_54 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_54[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_56[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_54[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_57 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_57[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_55 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_55[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_0_4              │ (None, 256, 256,  │      8,224 │ re_lu_57[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fixed_0   │ (None, 256, 256,  │          0 │ re_lu_31[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fixed_1   │ (None, 256, 256,  │          0 │ re_lu_41[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fixed_2   │ (None, 256, 256,  │          0 │ re_lu_49[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fixed_3   │ (None, 256, 256,  │          0 │ re_lu_55[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fixed_4   │ (None, 256, 256,  │          0 │ up_0_4[0][0]      │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_concat    │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 640)              │            │ re_lu_41[0][0],   │
# │                     │                   │            │ re_lu_49[0][0],   │
# │                     │                   │            │ re_lu_55[0][0],   │
# │                     │                   │            │ up_0_4[0][0],     │
# │                     │                   │            │ merge_0_4_fixed_… │
# │                     │                   │            │ merge_0_4_fixed_… │
# │                     │                   │            │ merge_0_4_fixed_… │
# │                     │                   │            │ merge_0_4_fixed_… │
# │                     │                   │            │ merge_0_4_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_compress  │ (None, 256, 256,  │     20,512 │ merge_0_4_concat… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_compress… │ (None, 256, 256,  │          0 │ merge_0_4_compre… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 256, 256,  │      9,248 │ merge_0_4_compre… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_58 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_58[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_58[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_59 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_59[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_1 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_41[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_2 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_49[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_3 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_55[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_4 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_59[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,754,340 (33.40 MB)
#  Trainable params: 8,754,340 (33.40 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "UNetPlusPlus_FixedKernel_Infer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 256, 256,  │        896 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_30 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_30[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_30[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_31 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_31[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 128, 128,  │          0 │ re_lu_31[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │     18,496 │ max_pooling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_32 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_32[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_32[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_33 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_33[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 64, 64,    │          0 │ re_lu_33[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 64, 64,    │     73,856 │ max_pooling2d_5[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_34 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_34[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_34[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_35 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_35[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 32, 32,    │          0 │ re_lu_35[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 32, 32,    │    295,168 │ max_pooling2d_6[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_36 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_36[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_36[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_37 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_37[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 16, 16,    │          0 │ re_lu_37[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_7[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_38 (ReLU)     │ (None, 16, 16,    │          0 │ conv2d_38[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ re_lu_38[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_39 (ReLU)     │ (None, 16, 16,    │          0 │ conv2d_39[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_3_1              │ (None, 32, 32,    │    524,544 │ re_lu_39[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_2_1              │ (None, 64, 64,    │    131,200 │ re_lu_37[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_fixed_0   │ (None, 32, 32,    │          0 │ re_lu_37[0][0]    │
# │ (FixedKernelLayer)  │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_fixed_1   │ (None, 32, 32,    │          0 │ up_3_1[0][0]      │
# │ (FixedKernelLayer)  │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_1_1              │ (None, 128, 128,  │     32,832 │ re_lu_35[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_fixed_0   │ (None, 64, 64,    │          0 │ re_lu_35[0][0]    │
# │ (FixedKernelLayer)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_fixed_1   │ (None, 64, 64,    │          0 │ up_2_1[0][0]      │
# │ (FixedKernelLayer)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_concat    │ (None, 32, 32,    │          0 │ re_lu_37[0][0],   │
# │ (Concatenate)       │ 2048)             │            │ up_3_1[0][0],     │
# │                     │                   │            │ merge_3_1_fixed_… │
# │                     │                   │            │ merge_3_1_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_0_1              │ (None, 256, 256,  │      8,224 │ re_lu_33[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_fixed_0   │ (None, 128, 128,  │          0 │ re_lu_33[0][0]    │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_fixed_1   │ (None, 128, 128,  │          0 │ up_1_1[0][0]      │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_concat    │ (None, 64, 64,    │          0 │ re_lu_35[0][0],   │
# │ (Concatenate)       │ 1024)             │            │ up_2_1[0][0],     │
# │                     │                   │            │ merge_2_1_fixed_… │
# │                     │                   │            │ merge_2_1_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_compress  │ (None, 32, 32,    │    524,544 │ merge_3_1_concat… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_fixed_0   │ (None, 256, 256,  │          0 │ re_lu_31[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_fixed_1   │ (None, 256, 256,  │          0 │ up_0_1[0][0]      │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_concat    │ (None, 128, 128,  │          0 │ re_lu_33[0][0],   │
# │ (Concatenate)       │ 512)              │            │ up_1_1[0][0],     │
# │                     │                   │            │ merge_1_1_fixed_… │
# │                     │                   │            │ merge_1_1_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_compress  │ (None, 64, 64,    │    131,200 │ merge_2_1_concat… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_3_1_compress… │ (None, 32, 32,    │          0 │ merge_3_1_compre… │
# │ (ReLU)              │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_concat    │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 256)              │            │ up_0_1[0][0],     │
# │                     │                   │            │ merge_0_1_fixed_… │
# │                     │                   │            │ merge_0_1_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_compress  │ (None, 128, 128,  │     32,832 │ merge_1_1_concat… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_1_compress… │ (None, 64, 64,    │          0 │ merge_2_1_compre… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 32, 32,    │    590,080 │ merge_3_1_compre… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_1_compress  │ (None, 256, 256,  │      8,224 │ merge_0_1_concat… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_1_compress… │ (None, 128, 128,  │          0 │ merge_1_1_compre… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 64, 64,    │    147,584 │ merge_2_1_compre… │
# │                     │ 128)              │            │                   │
# ...
# │ merge_0_2_concat    │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 384)              │            │ re_lu_41[0][0],   │
# │                     │                   │            │ up_0_2[0][0],     │
# │                     │                   │            │ merge_0_2_fixed_… │
# │                     │                   │            │ merge_0_2_fixed_… │
# │                     │                   │            │ merge_0_2_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_compress  │ (None, 128, 128,  │     49,216 │ merge_1_2_concat… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_2_2_compress… │ (None, 64, 64,    │          0 │ merge_2_2_compre… │
# │ (ReLU)              │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_compress  │ (None, 256, 256,  │     12,320 │ merge_0_2_concat… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_2_compress… │ (None, 128, 128,  │          0 │ merge_1_2_compre… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 64, 64,    │    147,584 │ merge_2_2_compre… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_2_compress… │ (None, 256, 256,  │          0 │ merge_0_2_compre… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 128, 128,  │     36,928 │ merge_1_2_compre… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_52 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_52[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 256, 256,  │      9,248 │ merge_0_2_compre… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_50 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_50[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_52[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_48 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_48[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_50[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_53 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_53[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_48[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_51 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_51[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_1_3              │ (None, 128, 128,  │     32,832 │ re_lu_53[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_49 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_49[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_0_3              │ (None, 256, 256,  │      8,224 │ re_lu_51[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fixed_0   │ (None, 128, 128,  │          0 │ re_lu_33[0][0]    │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fixed_1   │ (None, 128, 128,  │          0 │ re_lu_43[0][0]    │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fixed_2   │ (None, 128, 128,  │          0 │ re_lu_51[0][0]    │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_fixed_3   │ (None, 128, 128,  │          0 │ up_1_3[0][0]      │
# │ (FixedKernelLayer)  │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fixed_0   │ (None, 256, 256,  │          0 │ re_lu_31[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fixed_1   │ (None, 256, 256,  │          0 │ re_lu_41[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fixed_2   │ (None, 256, 256,  │          0 │ re_lu_49[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_fixed_3   │ (None, 256, 256,  │          0 │ up_0_3[0][0]      │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_concat    │ (None, 128, 128,  │          0 │ re_lu_33[0][0],   │
# │ (Concatenate)       │ 1024)             │            │ re_lu_43[0][0],   │
# │                     │                   │            │ re_lu_51[0][0],   │
# │                     │                   │            │ up_1_3[0][0],     │
# │                     │                   │            │ merge_1_3_fixed_… │
# │                     │                   │            │ merge_1_3_fixed_… │
# │                     │                   │            │ merge_1_3_fixed_… │
# │                     │                   │            │ merge_1_3_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_concat    │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 512)              │            │ re_lu_41[0][0],   │
# │                     │                   │            │ re_lu_49[0][0],   │
# │                     │                   │            │ up_0_3[0][0],     │
# │                     │                   │            │ merge_0_3_fixed_… │
# │                     │                   │            │ merge_0_3_fixed_… │
# │                     │                   │            │ merge_0_3_fixed_… │
# │                     │                   │            │ merge_0_3_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_compress  │ (None, 128, 128,  │     65,600 │ merge_1_3_concat… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_compress  │ (None, 256, 256,  │     16,416 │ merge_0_3_concat… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_1_3_compress… │ (None, 128, 128,  │          0 │ merge_1_3_compre… │
# │ (ReLU)              │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_3_compress… │ (None, 256, 256,  │          0 │ merge_0_3_compre… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 128, 128,  │     36,928 │ merge_1_3_compre… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 256, 256,  │      9,248 │ merge_0_3_compre… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_56 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_56[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_54 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_54[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_56[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_54[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_57 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_57[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_55 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_55[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_0_4              │ (None, 256, 256,  │      8,224 │ re_lu_57[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fixed_0   │ (None, 256, 256,  │          0 │ re_lu_31[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fixed_1   │ (None, 256, 256,  │          0 │ re_lu_41[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fixed_2   │ (None, 256, 256,  │          0 │ re_lu_49[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fixed_3   │ (None, 256, 256,  │          0 │ re_lu_55[0][0]    │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_fixed_4   │ (None, 256, 256,  │          0 │ up_0_4[0][0]      │
# │ (FixedKernelLayer)  │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_concat    │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 640)              │            │ re_lu_41[0][0],   │
# │                     │                   │            │ re_lu_49[0][0],   │
# │                     │                   │            │ re_lu_55[0][0],   │
# │                     │                   │            │ up_0_4[0][0],     │
# │                     │                   │            │ merge_0_4_fixed_… │
# │                     │                   │            │ merge_0_4_fixed_… │
# │                     │                   │            │ merge_0_4_fixed_… │
# │                     │                   │            │ merge_0_4_fixed_… │
# │                     │                   │            │ merge_0_4_fixed_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_compress  │ (None, 256, 256,  │     20,512 │ merge_0_4_concat… │
# │ (Conv2D)            │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ merge_0_4_compress… │ (None, 256, 256,  │          0 │ merge_0_4_compre… │
# │ (ReLU)              │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 256, 256,  │      9,248 │ merge_0_4_compre… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_58 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_58[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_58[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_59 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_59[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_1 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_41[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_2 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_49[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_3 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_55[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_4 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_59[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_output          │ (None, 256, 256,  │          0 │ side_1[0][0],     │
# │ (Average)           │ 1)                │            │ side_2[0][0],     │
# │                     │                   │            │ side_3[0][0],     │
# │                     │                   │            │ side_4[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,754,340 (33.40 MB)
#  Trainable params: 8,754,340 (33.40 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# =========================
# CALLBACK: EVALUATE AVERAGED OUTPUT MODEL
# =========================
class EvaluateAveragedModel(tf.keras.callbacks.Callback):
    def __init__(self, averaged_model, val_ds):
        super().__init__()
        self.averaged_model = averaged_model
        self.val_ds = val_ds

    def on_epoch_end(self, epoch, logs=None):
        logs = logs if logs is not None else {}

        results = self.averaged_model.evaluate(
            self.val_ds,
            verbose=0,
            return_dict=True
        )

        logs["val_avg_loss"] = float(results["loss"])
        logs["val_avg_accuracy"] = float(results["accuracy"])
        logs["val_avg_dice_coef"] = float(results["dice_coef"])
        logs["val_avg_iou_coef"] = float(results["iou_coef"])

        print(
            f"\nval_avg_loss={logs['val_avg_loss']:.4f}  "
            f"val_avg_accuracy={logs['val_avg_accuracy']:.4f}  "
            f"val_avg_dice_coef={logs['val_avg_dice_coef']:.4f}  "
            f"val_avg_iou_coef={logs['val_avg_iou_coef']:.4f}"
        )

paper_eval_cb = EvaluateAveragedModel(infer_model, val_ds_single)

# =========================
# CALLBACKS
# =========================
callbacks = [
    paper_eval_cb,
    tf.keras.callbacks.ModelCheckpoint(
        "best_unetpp_fixedconv.keras",
        monitor="val_avg_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor="val_avg_dice_coef",
        mode="max",
        patience=10,
        restore_best_weights=True,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_avg_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )
]

# =========================
# TRAIN
# =========================
history = train_model.fit(
    train_ds_multi,
    validation_data=val_ds_multi,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)
    plt.figure(figsize=(20, 5))

    plt.subplot(1, 4, 1)
    if "side_4_accuracy" in hist:
        plt.plot(epochs_range, hist["side_4_accuracy"], label="Train Accuracy")
    if "val_avg_accuracy" in hist:
        plt.plot(epochs_range, hist["val_avg_accuracy"], label="Validation Accuracy")
    plt.title("Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 4, 2)
    if "side_4_dice_coef" in hist:
        plt.plot(epochs_range, hist["side_4_dice_coef"], label="Train Dice")
    if "val_avg_dice_coef" in hist:
        plt.plot(epochs_range, hist["val_avg_dice_coef"], label="Validation Dice")
    plt.title("Dice Coefficient")
    plt.xlabel("Epoch")
    plt.ylabel("Dice")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 4, 3)
    if "side_4_iou_coef" in hist:
        plt.plot(epochs_range, hist["side_4_iou_coef"], label="Train IoU")
    if "val_avg_iou_coef" in hist:
        plt.plot(epochs_range, hist["val_avg_iou_coef"], label="Validation IoU")
    plt.title("IoU")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    plt.subplot(1, 4, 4)
    plt.plot(epochs_range, hist["loss"], label="Train Loss")
    if "val_avg_loss" in hist:
        plt.plot(epochs_range, hist["val_avg_loss"], label="Validation Loss")
    plt.title("Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

plot_training_curves(history)

# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

show_prediction(infer_model, val_pairs[0])
# Out:
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - loss:
# Epoch 4/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - loss: 0.5679 - side_1_accuracy: 0.6678 - side_1_dice_coef: 0.7433 - side_1_iou_coef: 0.5917 - side_1_loss: 0.5813 - side_2_accuracy: 0.6683 - side_2_dice_coef: 0.7615 - side_2_iou_coef: 0.6150 - side_2_loss: 0.5748 - side_3_accuracy: 0.6797 - side_3_dice_coef: 0.7599 - side_3_iou_coef: 0.6131 - side_3_loss: 0.5616 - side_4_accuracy: 0.6942 - side_4_dice_coef: 0.7713 - side_4_iou_coef: 0.6282 - side_4_loss: 0.5538
# val_avg_loss=0.6809  val_avg_accuracy=0.5736  val_avg_dice_coef=0.6992  val_avg_iou_coef=0.5375
#
# Epoch 4: val_avg_dice_coef improved from 0.69375 to 0.69916, saving model to best_unetpp_fixedconv.keras
#
# Epoch 4: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0.5786 - side_1_accuracy: 0.6602 - side_1_dice_coef: 0.7428 - side_1_iou_coef: 0.5911 - side_1_loss: 0.5921 - side_2_accuracy: 0.6606 - side_2_dice_coef: 0.7594 - side_2_iou_coef: 0.6125 - side_2_loss: 0.5878 - side_3_accuracy: 0.6742 - side_3_dice_coef: 0.7575 - side_3_iou_coef: 0.6100 - side_3_loss: 0.5707 - side_4_accuracy: 0.6898 - side_4_dice_coef: 0.7705 - side_4_iou_coef: 0.6272 - side_4_loss: 0.5640 - val_loss: 0.6996 - val_side_1_accuracy: 0.5630 - val_side_1_dice_coef: 0.6937 - val_side_1_iou_coef: 0.5311 - val_side_1_loss: 0.7130 - val_side_2_accuracy: 0.5656 - val_side_2_dice_coef: 0.7021 - val_side_2_iou_coef: 0.5410 - val_side_2_loss: 0.7035 - val_side_3_accuracy: 0.6036 - val_side_3_dice_coef: 0.6968 - val_side_3_iou_coef: 0.5347 - val_side_3_loss: 0.6807 - val_side_4_accuracy: 0.6252 - val_side_4_dice_coef: 0.7041 - val_side_4_iou_coef: 0.5433 - val_side_4_loss: 0.7012 - val_avg_loss: 0.6809 - val_avg_accuracy: 0.5736 - val_avg_dice_coef: 0.6992 - val_avg_iou_coef: 0.5375 - learning_rate: 3.0000e-04
# Epoch 5/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - loss: 0.5900 - side_1_accuracy: 0.6437 - side_1_dice_coef: 0.7409 - side_1_iou_coef: 0.5887 - side_1_loss: 0.6104 - side_2_accuracy: 0.6451 - side_2_dice_coef: 0.7453 - side_2_iou_coef: 0.5941 - side_2_loss: 0.5969 - side_3_accuracy: 0.6759 - side_3_dice_coef: 0.7356 - side_3_iou_coef: 0.5819 - side_3_loss: 0.5787 - side_4_accuracy: 0.6904 - side_4_dice_coef: 0.7435 - side_4_iou_coef: 0.5921 - side_4_loss: 0.5740
# val_avg_loss=0.6584  val_avg_accuracy=0.5925  val_avg_dice_coef=0.6863  val_avg_iou_coef=0.5224
#
# Epoch 5: val_avg_dice_coef did not improve from 0.69916
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0
# Epoch 7/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - loss: 0.5816 - side_1_accuracy: 0.6469 - side_1_dice_coef: 0.7476 - side_1_iou_coef: 0.5975 - side_1_loss: 0.6069 - side_2_accuracy: 0.6507 - side_2_dice_coef: 0.7531 - side_2_iou_coef: 0.6046 - side_2_loss: 0.5842 - side_3_accuracy: 0.6891 - side_3_dice_coef: 0.7692 - side_3_iou_coef: 0.6255 - side_3_loss: 0.5624 - side_4_accuracy: 0.7045 - side_4_dice_coef: 0.7788 - side_4_iou_coef: 0.6384 - side_4_loss: 0.5731
# val_avg_loss=0.6604  val_avg_accuracy=0.6281  val_avg_dice_coef=0.7103  val_avg_iou_coef=0.5507
#
# Epoch 7: val_avg_dice_coef did not improve from 0.71134
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.5440 - side_1_accuracy: 0.6610 - side_1_dice_coef: 0.7547 - side_1_iou_coef: 0.6066 - side_1_loss: 0.5743 - side_2_accuracy: 0.6669 - side_2_dice_coef: 0.7604 - side_2_iou_coef: 0.6140 - side_2_loss: 0.5512 - side_3_accuracy: 0.7112 - side_3_dice_coef: 0.7776 - side_3_iou_coef: 0.6366 - side_3_loss: 0.5236 - side_4_accuracy: 0.7265 - side_4_dice_coef: 0.7870 - side_4_iou_coef: 0.6493 - side_4_loss: 0.5271 - val_loss: 0.6811 - val_side_1_accuracy: 0.5665 - val_side_1_dice_coef: 0.6956 - val_side_1_iou_coef: 0.5333 - val_side_1_loss: 0.6894 - val_side_2_accuracy: 0.5840 - val_side_2_dice_coef: 0.7043 - val_side_2_iou_coef: 0.5436 - val_side_2_loss: 0.6661 - val_side_3_accuracy: 0.6512 - val_side_3_dice_coef: 0.7202 - val_side_3_iou_coef: 0.5627 - val_side_3_loss: 0.6718 - val_side_4_accuracy: 0.6613 - val_side_4_dice_coef: 0.7215 - val_side_4_iou_coef: 0.5644 - val_side_4_loss: 0.6969 - val_avg_loss: 0.6604 - val_avg_accuracy: 0.6281 - val_avg_dice_coef: 0.7103 - val_avg_iou_coef: 0.5507 - learning_rate: 3.0000e-04
# Epoch 8/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 827ms/step - loss: 0.5511 - side_1_accuracy: 0.6488 - side_1_dice_coef: 0.7469 - side_1_iou_coef: 0.5964 - side_1_loss: 0.5803 - side_2_accuracy: 0.6595 - side_2_dice_coef: 0.7545 - side_2_iou_coef: 0.6063 - side_2_loss: 0.5555 - side_3_accuracy: 0.7150 - side_3_dice_coef: 0.7721 - side_3_iou_coef: 0.6296 - side_3_loss: 0.5321 - side_4_accuracy: 0.7281 - side_4_dice_coef: 0.7748 - side_4_iou_coef: 0.6335 - side_4_loss: 0.5363
# val_avg_loss=0.6403  val_avg_accuracy=0.6571  val_avg_dice_coef=0.7021  val_avg_iou_coef=0.5409
#
# Epoch 8: val_avg_dice_coef did not improve from 0.71134
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 0
# Epoch 10/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - loss: 0.5338 - side_1_accuracy: 0.6648 - side_1_dice_coef: 0.7508 - side_1_iou_coef: 0.6016 - side_1_loss: 0.5624 - side_2_accuracy: 0.6815 - side_2_dice_coef: 0.7665 - side_2_iou_coef: 0.6219 - side_2_loss: 0.5377 - side_3_accuracy: 0.7359 - side_3_dice_coef: 0.7832 - side_3_iou_coef: 0.6440 - side_3_loss: 0.5143 - side_4_accuracy: 0.7413 - side_4_dice_coef: 0.7872 - side_4_iou_coef: 0.6494 - side_4_loss: 0.5207
# val_avg_loss=0.6344  val_avg_accuracy=0.6824  val_avg_dice_coef=0.7133  val_avg_iou_coef=0.5544
#
# Epoch 10: val_avg_dice_coef improved from 0.71285 to 0.71331, saving model to best_unetpp_fixedconv.keras
#
# Epoch 10: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.5232 - side_1_accuracy: 0.6704 - side_1_dice_coef: 0.7440 - side_1_iou_coef: 0.5934 - side_1_loss: 0.5555 - side_2_accuracy: 0.6924 - side_2_dice_coef: 0.7591 - side_2_iou_coef: 0.6127 - side_2_loss: 0.5280 - side_3_accuracy: 0.7490 - side_3_dice_coef: 0.7737 - side_3_iou_coef: 0.6316 - side_3_loss: 0.5019 - side_4_accuracy: 0.7502 - side_4_dice_coef: 0.7771 - side_4_iou_coef: 0.6361 - side_4_loss: 0.5073 - val_loss: 0.6562 - val_side_1_accuracy: 0.5869 - val_side_1_dice_coef: 0.6934 - val_side_1_iou_coef: 0.5306 - val_side_1_loss: 0.6635 - val_side_2_accuracy: 0.6218 - val_side_2_dice_coef: 0.7100 - val_side_2_iou_coef: 0.5504 - val_side_2_loss: 0.6475 - val_side_3_accuracy: 0.6861 - val_side_3_dice_coef: 0.7246 - val_side_3_iou_coef: 0.5681 - val_side_3_loss: 0.6467 - val_side_4_accuracy: 0.6832 - val_side_4_dice_coef: 0.7263 - val_side_4_iou_coef: 0.5702 - val_side_4_loss: 0.6672 - val_avg_loss: 0.6344 - val_avg_accuracy: 0.6824 - val_avg_dice_coef: 0.7133 - val_avg_iou_coef: 0.5544 - learning_rate: 3.0000e-04
# Epoch 11/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - loss: 0.5081 - side_1_accuracy: 0.6824 - side_1_dice_coef: 0.7586 - side_1_iou_coef: 0.6113 - side_1_loss: 0.5415 - side_2_accuracy: 0.7027 - side_2_dice_coef: 0.7768 - side_2_iou_coef: 0.6353 - side_2_loss: 0.5142 - side_3_accuracy: 0.7537 - side_3_dice_coef: 0.7944 - side_3_iou_coef: 0.6593 - side_3_loss: 0.4866 - side_4_accuracy: 0.7577 - side_4_dice_coef: 0.7995 - side_4_iou_coef: 0.6663 - side_4_loss: 0.4900
# val_avg_loss=0.6360  val_avg_accuracy=0.6877  val_avg_dice_coef=0.7203  val_avg_iou_coef=0.5629
#
# Epoch 11: val_avg_dice_coef improved from 0.71331 to 0.72033, saving model to best_unetpp_fixedconv.keras
#
# Epoch 11: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0
# Epoch 16/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step - loss: 0.5096 - side_1_accuracy: 0.6928 - side_1_dice_coef: 0.7499 - side_1_iou_coef: 0.6002 - side_1_loss: 0.5452 - side_2_accuracy: 0.7424 - side_2_dice_coef: 0.7597 - side_2_iou_coef: 0.6128 - side_2_loss: 0.5140 - side_3_accuracy: 0.7665 - side_3_dice_coef: 0.7772 - side_3_iou_coef: 0.6359 - side_3_loss: 0.4909 - side_4_accuracy: 0.7697 - side_4_dice_coef: 0.7832 - side_4_iou_coef: 0.6439 - side_4_loss: 0.4883
# val_avg_loss=0.6000  val_avg_accuracy=0.7087  val_avg_dice_coef=0.7257  val_avg_iou_coef=0.5694
#
# Epoch 16: val_avg_dice_coef improved from 0.72534 to 0.72566, saving model to best_unetpp_fixedconv.keras
#
# Epoch 16: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.4811 - side_1_accuracy: 0.7082 - side_1_dice_coef: 0.7615 - side_1_iou_coef: 0.6156 - side_1_loss: 0.5174 - side_2_accuracy: 0.7548 - side_2_dice_coef: 0.7726 - side_2_iou_coef: 0.6303 - side_2_loss: 0.4837 - side_3_accuracy: 0.7763 - side_3_dice_coef: 0.7900 - side_3_iou_coef: 0.6536 - side_3_loss: 0.4617 - side_4_accuracy: 0.7785 - side_4_dice_coef: 0.7947 - side_4_iou_coef: 0.6600 - side_4_loss: 0.4618 - val_loss: 0.6167 - val_side_1_accuracy: 0.6456 - val_side_1_dice_coef: 0.7069 - val_side_1_iou_coef: 0.5467 - val_side_1_loss: 0.6369 - val_side_2_accuracy: 0.6904 - val_side_2_dice_coef: 0.7192 - val_side_2_iou_coef: 0.5616 - val_side_2_loss: 0.6122 - val_side_3_accuracy: 0.7069 - val_side_3_dice_coef: 0.7367 - val_side_3_iou_coef: 0.5832 - val_side_3_loss: 0.6041 - val_side_4_accuracy: 0.7074 - val_side_4_dice_coef: 0.7412 - val_side_4_iou_coef: 0.5888 - val_side_4_loss: 0.6135 - val_avg_loss: 0.6000 - val_avg_accuracy: 0.7087 - val_avg_dice_coef: 0.7257 - val_avg_iou_coef: 0.5694 - learning_rate: 3.0000e-04
# Epoch 17/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 769ms/step - loss: 0.5225 - side_1_accuracy: 0.6807 - side_1_dice_coef: 0.7346 - side_1_iou_coef: 0.5816 - side_1_loss: 0.5699 - side_2_accuracy: 0.7399 - side_2_dice_coef: 0.7516 - side_2_iou_coef: 0.6030 - side_2_loss: 0.5268 - side_3_accuracy: 0.7651 - side_3_dice_coef: 0.7740 - side_3_iou_coef: 0.6321 - side_3_loss: 0.4980 - side_4_accuracy: 0.7696 - side_4_dice_coef: 0.7816 - side_4_iou_coef: 0.6422 - side_4_loss: 0.4951
# val_avg_loss=0.6143  val_avg_accuracy=0.7063  val_avg_dice_coef=0.7373  val_avg_iou_coef=0.5839
#
# Epoch 17: val_avg_dice_coef improved from 0.72566 to 0.73726, saving model to best_unetpp_fixedconv.keras
#
# Epoch 17: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0
# Epoch 19/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - loss: 0.4976 - side_1_accuracy: 0.7222 - side_1_dice_coef: 0.7501 - side_1_iou_coef: 0.6007 - side_1_loss: 0.5321 - side_2_accuracy: 0.7605 - side_2_dice_coef: 0.7703 - side_2_iou_coef: 0.6271 - side_2_loss: 0.4974 - side_3_accuracy: 0.7710 - side_3_dice_coef: 0.7869 - side_3_iou_coef: 0.6492 - side_3_loss: 0.4812 - side_4_accuracy: 0.7737 - side_4_dice_coef: 0.7891 - side_4_iou_coef: 0.6522 - side_4_loss: 0.4797
# val_avg_loss=0.5799  val_avg_accuracy=0.7160  val_avg_dice_coef=0.7300  val_avg_iou_coef=0.5748
#
# Epoch 19: val_avg_dice_coef did not improve from 0.73726
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.4655 - side_1_accuracy: 0.7303 - side_1_dice_coef: 0.7672 - side_1_iou_coef: 0.6232 - side_1_loss: 0.5022 - side_2_accuracy: 0.7725 - side_2_dice_coef: 0.7887 - side_2_iou_coef: 0.6521 - side_2_loss: 0.4636 - side_3_accuracy: 0.7829 - side_3_dice_coef: 0.8035 - side_3_iou_coef: 0.6724 - side_3_loss: 0.4487 - side_4_accuracy: 0.7864 - side_4_dice_coef: 0.8047 - side_4_iou_coef: 0.6740 - side_4_loss: 0.4473 - val_loss: 0.5949 - val_side_1_accuracy: 0.6684 - val_side_1_dice_coef: 0.7112 - val_side_1_iou_coef: 0.5518 - val_side_1_loss: 0.6233 - val_side_2_accuracy: 0.7054 - val_side_2_dice_coef: 0.7283 - val_side_2_iou_coef: 0.5727 - val_side_2_loss: 0.5954 - val_side_3_accuracy: 0.7143 - val_side_3_dice_coef: 0.7411 - val_side_3_iou_coef: 0.5887 - val_side_3_loss: 0.5822 - val_side_4_accuracy: 0.7169 - val_side_4_dice_coef: 0.7408 - val_side_4_iou_coef: 0.5883 - val_side_4_loss: 0.5785 - val_avg_loss: 0.5799 - val_avg_accuracy: 0.7160 - val_avg_dice_coef: 0.7300 - val_avg_iou_coef: 0.5748 - learning_rate: 3.0000e-04
# Epoch 20/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - loss: 0.4739 - side_1_accuracy: 0.7194 - side_1_dice_coef: 0.7672 - side_1_iou_coef: 0.6232 - side_1_loss: 0.5123 - side_2_accuracy: 0.7678 - side_2_dice_coef: 0.7858 - side_2_iou_coef: 0.6481 - side_2_loss: 0.4704 - side_3_accuracy: 0.7783 - side_3_dice_coef: 0.7961 - side_3_iou_coef: 0.6623 - side_3_loss: 0.4580 - side_4_accuracy: 0.7824 - side_4_dice_coef: 0.7965 - side_4_iou_coef: 0.6630 - side_4_loss: 0.4550
# val_avg_loss=0.6004  val_avg_accuracy=0.7133  val_avg_dice_coef=0.7424  val_avg_iou_coef=0.5903
#
# Epoch 20: val_avg_dice_coef improved from 0.73726 to 0.74240, saving model to best_unetpp_fixedconv.keras
#
# Epoch 20: finished saving model to best_unetpp_fixedconv.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - loss: 0
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - loss: 0.3832 - side_1_accuracy: 0.7865 - side_1_dice_coef: 0.8083 - side_1_iou_coef: 0.6787 - side_1_loss: 0.4256 - side_2_accuracy: 0.8125 - side_2_dice_coef: 0.8311 - side_2_iou_coef: 0.7114 - side_2_loss: 0.3800 - side_3_accuracy: 0.8184 - side_3_dice_coef: 0.8377 - side_3_iou_coef: 0.7211 - side_3_loss: 0.3692 - side_4_accuracy: 0.8249 - side_4_dice_coef: 0.8414 - side_4_iou_coef: 0.7265 - side_4_loss: 0.3578
# val_avg_loss=0.5489  val_avg_accuracy=0.7386  val_avg_dice_coef=0.7551  val_avg_iou_coef=0.6065
#
# Epoch 48: val_avg_dice_coef did not improve from 0.76202
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.4114 - side_1_accuracy: 0.7737 - side_1_dice_coef: 0.7932 - side_1_iou_coef: 0.6580 - side_1_loss: 0.4601 - side_2_accuracy: 0.8065 - side_2_dice_coef: 0.8185 - side_2_iou_coef: 0.6934 - side_2_loss: 0.4071 - side_3_accuracy: 0.8127 - side_3_dice_coef: 0.8252 - side_3_iou_coef: 0.7031 - side_3_loss: 0.3955 - side_4_accuracy: 0.8200 - side_4_dice_coef: 0.8299 - side_4_iou_coef: 0.7098 - side_4_loss: 0.3828 - val_loss: 0.5667 - val_side_1_accuracy: 0.7001 - val_side_1_dice_coef: 0.7334 - val_side_1_iou_coef: 0.5790 - val_side_1_loss: 0.6032 - val_side_2_accuracy: 0.7347 - val_side_2_dice_coef: 0.7586 - val_side_2_iou_coef: 0.6111 - val_side_2_loss: 0.5530 - val_side_3_accuracy: 0.7390 - val_side_3_dice_coef: 0.7632 - val_side_3_iou_coef: 0.6171 - val_side_3_loss: 0.5557 - val_side_4_accuracy: 0.7435 - val_side_4_dice_coef: 0.7657 - val_side_4_iou_coef: 0.6204 - val_side_4_loss: 0.5550 - val_avg_loss: 0.5489 - val_avg_accuracy: 0.7386 - val_avg_dice_coef: 0.7551 - val_avg_iou_coef: 0.6065 - learning_rate: 7.5000e-05
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - loss: 0.3763 - side_1_accuracy: 0.7852 - side_1_dice_coef: 0.8079 - side_1_iou_coef: 0.6783 - side_1_loss: 0.4293 - side_2_accuracy: 0.8217 - side_2_dice_coef: 0.8339 - side_2_iou_coef: 0.7154 - side_2_loss: 0.3712 - side_3_accuracy: 0.8284 - side_3_dice_coef: 0.8408 - side_3_iou_coef: 0.7257 - side_3_loss: 0.3590 - side_4_accuracy: 0.8355 - side_4_dice_coef: 0.8465 - side_4_iou_coef: 0.7341 - side_4_loss: 0.3457
# val_avg_loss=0.5476  val_avg_accuracy=0.7384  val_avg_dice_coef=0.7538  val_avg_iou_coef=0.6049
#
# Epoch 49: val_avg_dice_coef did not improve from 0.76202
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 0.4074 - side_1_accuracy: 0.7740 - side_1_dice_coef: 0.7956 - side_1_iou_coef: 0.6611 - side_1_loss: 0.4578 - side_2_accuracy: 0.8069 - side_2_dice_coef: 0.8223 - side_2_iou_coef: 0.6987 - side_2_loss: 0.4039 - side_3_accuracy: 0.8136 - side_3_dice_coef: 0.8296 - side_3_iou_coef: 0.7092 - side_3_loss: 0.3916 - side_4_accuracy: 0.8217 - side_4_dice_coef: 0.8357 - side_4_iou_coef: 0.7182 - side_4_loss: 0.3761 - val_loss: 0.5667 - val_side_1_accuracy: 0.7004 - val_side_1_dice_coef: 0.7327 - val_side_1_iou_coef: 0.5782 - val_side_1_loss: 0.6026 - val_side_2_accuracy: 0.7342 - val_side_2_dice_coef: 0.7578 - val_side_2_iou_coef: 0.6100 - val_side_2_loss: 0.5542 - val_side_3_accuracy: 0.7386 - val_side_3_dice_coef: 0.7619 - val_side_3_iou_coef: 0.6154 - val_side_3_loss: 0.5564 - val_side_4_accuracy: 0.7435 - val_side_4_dice_coef: 0.7638 - val_side_4_iou_coef: 0.6179 - val_side_4_loss: 0.5535 - val_avg_loss: 0.5476 - val_avg_accuracy: 0.7384 - val_avg_dice_coef: 0.7538 - val_avg_iou_coef: 0.6049 - learning_rate: 7.5000e-05
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - loss: 0.3859 - side_1_accuracy: 0.7900 - side_1_dice_coef: 0.7878 - side_1_iou_coef: 0.6513 - side_1_loss: 0.4456 - side_2_accuracy: 0.8258 - side_2_dice_coef: 0.8243 - side_2_iou_coef: 0.7019 - side_2_loss: 0.3793 - side_3_accuracy: 0.8318 - side_3_dice_coef: 0.8328 - side_3_iou_coef: 0.7143 - side_3_loss: 0.3662 - side_4_accuracy: 0.8393 - side_4_dice_coef: 0.8382 - side_4_iou_coef: 0.7222 - side_4_loss: 0.3525
# val_avg_loss=0.5465  val_avg_accuracy=0.7380  val_avg_dice_coef=0.7532  val_avg_iou_coef=0.6041
#
# Epoch 50: val_avg_dice_coef did not improve from 0.76202
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - loss: 0.4067 - side_1_accuracy: 0.7745 - side_1_dice_coef: 0.7939 - side_1_iou_coef: 0.6598 - side_1_loss: 0.4590 - side_2_accuracy: 0.8076 - side_2_dice_coef: 0.8219 - side_2_iou_coef: 0.6988 - side_2_loss: 0.4034 - side_3_accuracy: 0.8150 - side_3_dice_coef: 0.8290 - side_3_iou_coef: 0.7092 - side_3_loss: 0.3904 - side_4_accuracy: 0.8238 - side_4_dice_coef: 0.8344 - side_4_iou_coef: 0.7170 - side_4_loss: 0.3739 - val_loss: 0.5662 - val_side_1_accuracy: 0.7004 - val_side_1_dice_coef: 0.7327 - val_side_1_iou_coef: 0.5781 - val_side_1_loss: 0.6027 - val_side_2_accuracy: 0.7339 - val_side_2_dice_coef: 0.7574 - val_side_2_iou_coef: 0.6095 - val_side_2_loss: 0.5542 - val_side_3_accuracy: 0.7385 - val_side_3_dice_coef: 0.7611 - val_side_3_iou_coef: 0.6144 - val_side_3_loss: 0.5560 - val_side_4_accuracy: 0.7436 - val_side_4_dice_coef: 0.7625 - val_side_4_iou_coef: 0.6161 - val_side_4_loss: 0.5519 - val_avg_loss: 0.5465 - val_avg_accuracy: 0.7380 - val_avg_dice_coef: 0.7532 - val_avg_iou_coef: 0.6041 - learning_rate: 3.7500e-05
# Restoring model weights from the end of the best epoch: 41.
