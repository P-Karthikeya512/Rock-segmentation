# %% [markdown]
# <a href="https://colab.research.google.com/github/P-Karthikeya512/Rock-segmentation/blob/main/Skip_connections_modified1_UNET%2B%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import glob
import random
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import layers, Model
from sklearn.model_selection import train_test_split

# =========================
# CONFIG
# =========================
IMG_SIZE = (256, 256)
BATCH_SIZE = 4
EPOCHS = 50
SEED = 42

IMAGE_DIR = "/content/drive/MyDrive/dataset_rock/images"
MASK_DIR  = "/content/drive/MyDrive/dataset_rock/masks"

tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

AUTOTUNE = tf.data.AUTOTUNE

print("Images :", len(os.listdir(IMAGE_DIR)))
print("Masks  :", len(os.listdir(MASK_DIR)))

# =========================
# PAIR IMAGES WITH MASKS
# =========================
def get_pairs(image_dir, mask_dir):
    image_paths = []
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        image_paths.extend(glob.glob(os.path.join(image_dir, f"*.{ext}")))

    image_paths = sorted(image_paths)

    mask_map = {}
    for ext in ["jpg", "jpeg", "png", "bmp", "tif", "tiff"]:
        for p in glob.glob(os.path.join(mask_dir, f"*.{ext}")):
            stem = os.path.splitext(os.path.basename(p))[0]
            mask_map[stem] = p

    pairs = []
    for img_path in image_paths:
        stem = os.path.splitext(os.path.basename(img_path))[0]
        if stem in mask_map:
            pairs.append((img_path, mask_map[stem]))
        else:
            print(f"Warning: no mask found for {img_path}")

    return pairs

pairs = get_pairs(IMAGE_DIR, MASK_DIR)
print("Total paired samples:", len(pairs))
# Out:
# Images : 16
# Masks  : 16
# Total paired samples: 16

# %%
# =========================
# LOAD IMAGE + MASK
# =========================
def load_image_mask(img_path, mask_path):
    img = cv2.imread(img_path.decode(), cv2.IMREAD_COLOR)
    if img is None:
        raise ValueError(f"Could not read image: {img_path}")
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, IMG_SIZE, interpolation=cv2.INTER_AREA)
    img = img.astype(np.float32) / 255.0

    mask = cv2.imread(mask_path.decode(), cv2.IMREAD_GRAYSCALE)
    if mask is None:
        raise ValueError(f"Could not read mask: {mask_path}")
    mask = cv2.resize(mask, IMG_SIZE, interpolation=cv2.INTER_NEAREST)

    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.numpy_function(
        func=load_image_mask,
        inp=[img_path, mask_path],
        Tout=[tf.float32, tf.float32]
    )
    img.set_shape([IMG_SIZE[0], IMG_SIZE[1], 3])
    mask.set_shape([IMG_SIZE[0], IMG_SIZE[1], 1])
    return img, mask

# =========================
# DATASET
# =========================
train_pairs, val_pairs = train_test_split(
    pairs,
    test_size=0.2,
    random_state=SEED
)

def duplicate_mask(image, mask):
    return image, (mask, mask, mask, mask)

def make_dataset(pairs, training=True, duplicate=False):
    img_paths = [p[0] for p in pairs]
    mask_paths = [p[1] for p in pairs]

    ds = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))
    if training:
        ds = ds.shuffle(buffer_size=len(pairs), seed=SEED, reshuffle_each_iteration=True)

    ds = ds.map(tf_load_image_mask, num_parallel_calls=AUTOTUNE)

    if duplicate:
        ds = ds.map(duplicate_mask, num_parallel_calls=AUTOTUNE)

    ds = ds.batch(BATCH_SIZE).prefetch(AUTOTUNE)
    return ds

train_ds_multi = make_dataset(train_pairs, training=True, duplicate=True)
val_ds_multi   = make_dataset(val_pairs, training=False, duplicate=True)

train_ds_single = make_dataset(train_pairs, training=True, duplicate=False)
val_ds_single   = make_dataset(val_pairs, training=False, duplicate=False)

print("Train samples:", len(train_pairs))
print("Val samples:", len(val_pairs))
# Out:
# Train samples: 12
# Val samples: 4

# %%
# =========================
# LOSS + METRICS
# =========================
bce_loss_fn = tf.keras.losses.BinaryCrossentropy()

def dice_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (
        tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
    )

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

def combined_bce_dice_loss(y_true, y_pred):
    bce = bce_loss_fn(y_true, y_pred)
    dloss = dice_loss(y_true, y_pred)
    return 0.5 * bce + dloss

def iou_coef(y_true, y_pred, smooth=1e-7):
    y_true_f = tf.keras.backend.flatten(tf.cast(y_true, tf.float32))
    y_pred_f = tf.keras.backend.flatten(tf.cast(y_pred, tf.float32))
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# =========================
# UNET++ BLOCKS
# =========================
def conv_block(x, filters):
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.ReLU()(x)
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.ReLU()(x)
    return x

# =========================
# BUILD UNET++ WITH YOUR EXTRA DIRECT SKIPS
# =========================
def build_unet_plus_plus(input_shape=(256, 256, 3)):
    filters = [32, 64, 128, 256, 512]
    depth = len(filters) - 1

    inputs = layers.Input(shape=input_shape)
    X = {}

    # Encoder backbone
    x = inputs
    for i in range(depth + 1):
        X[(i, 0)] = conv_block(x, filters[i])
        if i < depth:
            x = layers.MaxPooling2D((2, 2))(X[(i, 0)])

    # Nested decoder / skip pathways
    for j in range(1, depth + 1):
        for i in range(0, depth - j + 1):
            up = layers.Conv2DTranspose(
                filters[i],
                kernel_size=2,
                strides=2,
                padding="same"
            )(X[(i + 1, j - 1)])

            concat_inputs = [X[(i, k)] for k in range(j)] + [up]

            # Your extra direct skips:
            # X(1,0) -> X(0,4)
            # X(2,0) -> X(1,3)
            # X(3,0) -> X(2,2)
            direct_skip_map = {
                (0, 4): (1, 0),
                (1, 3): (2, 0),
                (2, 2): (3, 0),
            }

            if (i, j) in direct_skip_map:
                si, sj = direct_skip_map[(i, j)]
                direct_up = layers.Conv2DTranspose(
                    filters[i],
                    kernel_size=2,
                    strides=2,
                    padding="same"
                )(X[(si, sj)])
                concat_inputs.append(direct_up)

            x = layers.Concatenate()(concat_inputs)
            X[(i, j)] = conv_block(x, filters[i])

    # Deep supervision outputs
    side_outputs = [
        layers.Conv2D(1, 1, activation="sigmoid", name=f"side_{j}")(X[(0, j)])
        for j in range(1, depth + 1)
    ]

    # Training model returns all 4 side outputs
    train_model = Model(inputs, side_outputs, name="UNetPlusPlus_Train")

    # Accurate inference mode: average the 4 outputs
    avg_output = layers.Average(name="avg_output")(side_outputs)
    infer_model = Model(inputs, avg_output, name="UNetPlusPlus_Infer")

    return train_model, infer_model

train_model, infer_model = build_unet_plus_plus()

train_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=[combined_bce_dice_loss for _ in range(4)],
    loss_weights=[0.25, 0.25, 0.25, 0.25],
    metrics=[
        ["accuracy", dice_coef, iou_coef],
        ["accuracy", dice_coef, iou_coef],
        ["accuracy", dice_coef, iou_coef],
        ["accuracy", dice_coef, iou_coef],
    ]
)

infer_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss=combined_bce_dice_loss,
    metrics=[
        "accuracy",
        dice_coef,
        iou_coef
    ]
)

train_model.summary()
infer_model.summary()

# =========================
# CALLBACK TO EVALUATE AVERAGED OUTPUT
# =========================
class EvaluateAveragedModel(tf.keras.callbacks.Callback):

    def __init__(self, averaged_model, val_ds):
        super().__init__()
        self.averaged_model = averaged_model
        self.val_ds = val_ds

    def on_epoch_end(self, epoch, logs=None):

        logs = logs if logs is not None else {}

        results = self.averaged_model.evaluate(
            self.val_ds,
            verbose=0,
            return_dict=True
        )

        logs["val_avg_loss"] = float(results["loss"])
        logs["val_avg_accuracy"] = float(results["accuracy"])
        logs["val_avg_dice_coef"] = float(results["dice_coef"])
        logs["val_avg_iou_coef"] = float(results["iou_coef"])

        print(
            f"\n"
            f"val_avg_loss={logs['val_avg_loss']:.4f}  "
            f"val_avg_accuracy={logs['val_avg_accuracy']:.4f}  "
            f"val_avg_dice_coef={logs['val_avg_dice_coef']:.4f}  "
            f"val_avg_iou_coef={logs['val_avg_iou_coef']:.4f}"
        )

paper_eval_cb = EvaluateAveragedModel(infer_model, val_ds_single)

callbacks = [

    paper_eval_cb,

    tf.keras.callbacks.ModelCheckpoint(
        "best_unetpp_paper.keras",
        monitor="val_avg_dice_coef",
        mode="max",
        save_best_only=True,
        verbose=1
    ),

    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_avg_dice_coef",
        mode="max",
        factor=0.5,
        patience=4,
        verbose=1
    )

]

# =========================
# TRAIN
# =========================
history = train_model.fit(
    train_ds_multi,
    validation_data=val_ds_multi,
    epochs=EPOCHS,
    callbacks=callbacks
)

# =========================
# PLOTS
# =========================
def plot_training_curves(history):
    hist = history.history
    epochs_range = range(1, len(hist["loss"]) + 1)
    plt.figure(figsize=(20,5))

    # ---------------- Accuracy ----------------

    plt.subplot(1,4,1)
    if "side_4_accuracy" in hist:
        plt.plot(
            epochs_range,
            hist["side_4_accuracy"],
            label="Train Accuracy"
        )
    if "val_avg_accuracy" in hist:
        plt.plot(
            epochs_range,
            hist["val_avg_accuracy"],
            label="Validation Accuracy"
        )
    plt.title("Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.grid(True)

    # ---------------- Dice ----------------

    plt.subplot(1,4,2)
    if "side_4_dice_coef" in hist:
        plt.plot(
            epochs_range,
            hist["side_4_dice_coef"],
            label="Train Dice"
        )
    if "val_avg_dice_coef" in hist:
        plt.plot(
            epochs_range,
            hist["val_avg_dice_coef"],
            label="Validation Dice"
        )
    plt.title("Dice Coefficient")
    plt.xlabel("Epoch")
    plt.ylabel("Dice")
    plt.legend()
    plt.grid(True)

    # ---------------- IoU ----------------
    plt.subplot(1,4,3)
    if "side_4_iou_coef" in hist:
        plt.plot(
            epochs_range,
            hist["side_4_iou_coef"],
            label="Train IoU"
        )
    if "val_avg_iou_coef" in hist:
        plt.plot(
            epochs_range,
            hist["val_avg_iou_coef"],
            label="Validation IoU"
        )
    plt.title("IoU")
    plt.xlabel("Epoch")
    plt.ylabel("IoU")
    plt.legend()
    plt.grid(True)

    # ---------------- Loss ----------------
    plt.subplot(1,4,4)
    plt.plot(
        epochs_range,
        hist["loss"],
        label="Train Loss"
    )
    if "val_avg_loss" in hist:
        plt.plot(
            epochs_range,
            hist["val_avg_loss"],
            label="Validation Loss"
        )
    plt.title("Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()


# =========================
# PREDICTION + VISUALIZATION
# =========================
def show_prediction(model, pair):
    img_path, mask_path = pair
    img, mask = load_image_mask(img_path.encode(), mask_path.encode())

    pred = model.predict(np.expand_dims(img, axis=0), verbose=0)[0]
    pred_mask = (pred > 0.5).astype(np.uint8)

    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    plt.imshow(img)
    plt.title("Input Image")
    plt.axis("off")

    plt.subplot(1, 3, 2)
    plt.imshow(mask.squeeze(), cmap="gray")
    plt.title("True Mask")
    plt.axis("off")

    plt.subplot(1, 3, 3)
    plt.imshow(pred_mask.squeeze(), cmap="gray")
    plt.title("Predicted Mask")
    plt.axis("off")

    plt.show()

show_prediction(infer_model, val_pairs[0])
# Out:
# Model: "UNetPlusPlus_Train"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 256, 256,  │        896 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_30 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_30[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_30[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_31 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_31[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 128, 128,  │          0 │ re_lu_31[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │     18,496 │ max_pooling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_32 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_32[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_32[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_33 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_33[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 64, 64,    │          0 │ re_lu_33[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 64, 64,    │     73,856 │ max_pooling2d_5[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_34 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_34[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_34[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_35 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_35[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 32, 32,    │          0 │ re_lu_35[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 32, 32,    │    295,168 │ max_pooling2d_6[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_36 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_36[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_36[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_37 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_37[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 16, 16,    │          0 │ re_lu_37[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_7[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_38 (ReLU)     │ (None, 16, 16,    │          0 │ conv2d_38[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ re_lu_38[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_39 (ReLU)     │ (None, 16, 16,    │          0 │ conv2d_39[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_16 │ (None, 32, 32,    │    524,544 │ re_lu_39[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_15 │ (None, 64, 64,    │    131,200 │ re_lu_37[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 32, 32,    │          0 │ re_lu_37[0][0],   │
# │ (Concatenate)       │ 512)              │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_14 │ (None, 128, 128,  │     32,832 │ re_lu_35[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 64, 64,    │          0 │ re_lu_35[0][0],   │
# │ (Concatenate)       │ 256)              │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate_13[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_13 │ (None, 256, 256,  │      8,224 │ re_lu_33[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 128, 128,  │          0 │ re_lu_33[0][0],   │
# │ (Concatenate)       │ 128)              │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 64, 64,    │    295,040 │ concatenate_12[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_46 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_46[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 64)               │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 128, 128,  │     73,792 │ concatenate_11[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_44 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_44[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_46[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 256, 256,  │     18,464 │ concatenate_10[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_42 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_42[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_44[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_47 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_47[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_40 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_40[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_42[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_45 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_45[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_19 │ (None, 64, 64,    │    131,200 │ re_lu_47[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_20 │ (None, 64, 64,    │    131,200 │ re_lu_37[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_40[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_43 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_43[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_18 │ (None, 128, 128,  │     32,832 │ re_lu_45[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 64, 64,    │          0 │ re_lu_35[0][0],   │
# │ (Concatenate)       │ 512)              │            │ re_lu_45[0][0],   │
# │                     │                   │            │ conv2d_transpose… │
# │                     │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_41 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_41[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_17 │ (None, 256, 256,  │      8,224 │ re_lu_43[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 128, 128,  │          0 │ re_lu_33[0][0],   │
# │ (Concatenate)       │ 192)              │            │ re_lu_43[0][0],   │
# │                     │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 64, 64,    │    589,952 │ concatenate_16[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 96)               │            │ re_lu_41[0][0],   │
# │                     │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 128, 128,  │    110,656 │ concatenate_15[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_52 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_52[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 256, 256,  │     27,680 │ concatenate_14[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_50 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_50[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_52[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_48 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_48[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_50[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_53 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_53[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_48[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_51 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_51[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_22 │ (None, 128, 128,  │     32,832 │ re_lu_53[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_23 │ (None, 128, 128,  │     32,832 │ re_lu_35[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_49 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_49[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_21 │ (None, 256, 256,  │      8,224 │ re_lu_51[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 128, 128,  │          0 │ re_lu_33[0][0],   │
# │ (Concatenate)       │ 320)              │            │ re_lu_43[0][0],   │
# │                     │                   │            │ re_lu_51[0][0],   │
# │                     │                   │            │ conv2d_transpose… │
# │                     │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 128)              │            │ re_lu_41[0][0],   │
# │                     │                   │            │ re_lu_49[0][0],   │
# │                     │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 128, 128,  │    184,384 │ concatenate_18[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 256, 256,  │     36,896 │ concatenate_17[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_56 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_56[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_54 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_54[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_56[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_54[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_57 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_57[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_55 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_55[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_24 │ (None, 256, 256,  │      8,224 │ re_lu_57[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_25 │ (None, 256, 256,  │      8,224 │ re_lu_33[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 192)              │            │ re_lu_41[0][0],   │
# │                     │                   │            │ re_lu_49[0][0],   │
# │                     │                   │            │ re_lu_55[0][0],   │
# │                     │                   │            │ conv2d_transpose… │
# │                     │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 256, 256,  │     55,328 │ concatenate_19[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_58 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_58[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_58[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_59 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_59[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_1 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_41[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_2 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_49[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_3 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_55[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_4 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_59[0][0]    │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,408,068 (35.89 MB)
#  Trainable params: 9,408,068 (35.89 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "UNetPlusPlus_Infer"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 256, 256,  │        896 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_30 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_30[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_30[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_31 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_31[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 128, 128,  │          0 │ re_lu_31[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │     18,496 │ max_pooling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_32 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_32[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_32[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_33 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_33[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 64, 64,    │          0 │ re_lu_33[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 64, 64,    │     73,856 │ max_pooling2d_5[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_34 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_34[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_34[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_35 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_35[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 32, 32,    │          0 │ re_lu_35[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 32, 32,    │    295,168 │ max_pooling2d_6[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_36 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_36[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_36[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_37 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_37[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 16, 16,    │          0 │ re_lu_37[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 16, 16,    │  1,180,160 │ max_pooling2d_7[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_38 (ReLU)     │ (None, 16, 16,    │          0 │ conv2d_38[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 16, 16,    │  2,359,808 │ re_lu_38[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_39 (ReLU)     │ (None, 16, 16,    │          0 │ conv2d_39[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_16 │ (None, 32, 32,    │    524,544 │ re_lu_39[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_15 │ (None, 64, 64,    │    131,200 │ re_lu_37[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 32, 32,    │          0 │ re_lu_37[0][0],   │
# │ (Concatenate)       │ 512)              │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_14 │ (None, 128, 128,  │     32,832 │ re_lu_35[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 64, 64,    │          0 │ re_lu_35[0][0],   │
# │ (Concatenate)       │ 256)              │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_46 (Conv2D)  │ (None, 32, 32,    │  1,179,904 │ concatenate_13[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_13 │ (None, 256, 256,  │      8,224 │ re_lu_33[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 128, 128,  │          0 │ re_lu_33[0][0],   │
# │ (Concatenate)       │ 128)              │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_44 (Conv2D)  │ (None, 64, 64,    │    295,040 │ concatenate_12[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_46 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_46[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 64)               │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_42 (Conv2D)  │ (None, 128, 128,  │     73,792 │ concatenate_11[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_44 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_44[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_47 (Conv2D)  │ (None, 32, 32,    │    590,080 │ re_lu_46[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_40 (Conv2D)  │ (None, 256, 256,  │     18,464 │ concatenate_10[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_42 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_42[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_45 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_44[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_47 (ReLU)     │ (None, 32, 32,    │          0 │ conv2d_47[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_40 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_40[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_43 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_42[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_45 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_45[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_19 │ (None, 64, 64,    │    131,200 │ re_lu_47[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_20 │ (None, 64, 64,    │    131,200 │ re_lu_37[0][0]    │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_41 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_40[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_43 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_43[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_18 │ (None, 128, 128,  │     32,832 │ re_lu_45[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 64, 64,    │          0 │ re_lu_35[0][0],   │
# │ (Concatenate)       │ 512)              │            │ re_lu_45[0][0],   │
# │                     │                   │            │ conv2d_transpose… │
# │                     │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_41 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_41[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_17 │ (None, 256, 256,  │      8,224 │ re_lu_43[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 128, 128,  │          0 │ re_lu_33[0][0],   │
# │ (Concatenate)       │ 192)              │            │ re_lu_43[0][0],   │
# │                     │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 64, 64,    │    589,952 │ concatenate_16[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 96)               │            │ re_lu_41[0][0],   │
# │                     │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 128, 128,  │    110,656 │ concatenate_15[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_52 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_52[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 256, 256,  │     27,680 │ concatenate_14[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_50 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_50[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 64, 64,    │    147,584 │ re_lu_52[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_48 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_48[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_50[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_53 (ReLU)     │ (None, 64, 64,    │          0 │ conv2d_53[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_48[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_51 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_51[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_22 │ (None, 128, 128,  │     32,832 │ re_lu_53[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_23 │ (None, 128, 128,  │     32,832 │ re_lu_35[0][0]    │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_49 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_49[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_21 │ (None, 256, 256,  │      8,224 │ re_lu_51[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 128, 128,  │          0 │ re_lu_33[0][0],   │
# │ (Concatenate)       │ 320)              │            │ re_lu_43[0][0],   │
# │                     │                   │            │ re_lu_51[0][0],   │
# │                     │                   │            │ conv2d_transpose… │
# │                     │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 128)              │            │ re_lu_41[0][0],   │
# │                     │                   │            │ re_lu_49[0][0],   │
# │                     │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 128, 128,  │    184,384 │ concatenate_18[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 256, 256,  │     36,896 │ concatenate_17[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_56 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_56[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_54 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_54[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 128, 128,  │     36,928 │ re_lu_56[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_54[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_57 (ReLU)     │ (None, 128, 128,  │          0 │ conv2d_57[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_55 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_55[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_24 │ (None, 256, 256,  │      8,224 │ re_lu_57[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_25 │ (None, 256, 256,  │      8,224 │ re_lu_33[0][0]    │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 256, 256,  │          0 │ re_lu_31[0][0],   │
# │ (Concatenate)       │ 192)              │            │ re_lu_41[0][0],   │
# │                     │                   │            │ re_lu_49[0][0],   │
# │                     │                   │            │ re_lu_55[0][0],   │
# │                     │                   │            │ conv2d_transpose… │
# │                     │                   │            │ conv2d_transpose… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 256, 256,  │     55,328 │ concatenate_19[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_58 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_58[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 256, 256,  │      9,248 │ re_lu_58[0][0]    │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_59 (ReLU)     │ (None, 256, 256,  │          0 │ conv2d_59[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_1 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_41[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_2 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_49[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_3 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_55[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ side_4 (Conv2D)     │ (None, 256, 256,  │         33 │ re_lu_59[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_output          │ (None, 256, 256,  │          0 │ side_1[0][0],     │
# │ (Average)           │ 1)                │            │ side_2[0][0],     │
# │                     │                   │            │ side_3[0][0],     │
# │                     │                   │            │ side_4[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,408,068 (35.89 MB)
#  Trainable params: 9,408,068 (35.89 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - loss: 0.8059 - side_1_accuracy: 0.3380 - side_1_dice_coef: 0.4802 - side_1_iou_coef: 0.3168 - side_1_loss: 0.9299 - side_2_accuracy: 0.5420 - side_2_dice_coef: 0.5895 - side_2_iou_coef: 0.4192 - side_2_loss: 0.7473 - side_3_accuracy: 0.4501 - side_3_dice_coef: 0.5580 - side_3_iou_coef: 0.3877 - side_3_loss: 0.7964 - side_4_accuracy: 0.5469 - side_4_dice_coef: 0.5894 - side_4_iou_coef: 0.4189 - side_4_loss: 0.7499
# val_avg_loss=0.7211  val_avg_accuracy=0.5622  val_avg_dice_coef=0.6121  val_avg_iou_coef=0.4410
#
# Epoch 1: val_avg_dice_coef improved from None to 0.61210, saving model to best_unetpp_paper.keras
#
# Epoch 1: finished saving model to best_unetpp_paper.keras
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 38s 5s/step - loss: 0.7762 - side_1_accuracy: 0.3472 - side_1_dice_coef: 0.5003 - side_1_iou_coef: 0.3343 - side_1_loss: 0.8947 - side_2_accuracy: 0.5974 - side_2_dice_coef: 0.6124 - side_2_iou_coef: 0.4426 - side_2_loss: 0.7151 - side_3_accuracy: 0.5216 - side_3_dice_coef: 0.5731 - side_3_iou_coef: 0.4023 - side_3_loss: 0.7731 - side_4_accuracy: 0.5955 - side_4_dice_coef: 0.6099 - side_4_iou_coef: 0.4397 - side_4_loss: 0.7219 - val_loss: 0.7344 - val_side_1_accuracy: 0.5108 - val_side_1_dice_coef: 0.5363 - val_side_1_iou_coef: 0.3664 - val_side_1_loss: 0.8114 - val_side_2_accuracy: 0.5644 - val_side_2_dice_coef: 0.6459 - val_side_2_iou_coef: 0.4770 - val_side_2_loss: 0.6931 - val_side_3_accuracy: 0.5690 - val_side_3_dice_coef: 0.5967 - val_side_3_iou_coef: 0.4252 - val_side_3_loss: 0.7359 - val_side_4_accuracy: 0.5626 - val_side_4_dice_coef: 0.6558 - val_side_4_iou_coef: 0.4879 - val_side_4_loss: 0.6972 - val_avg_loss: 0.7211 - val_avg_accuracy: 0.5622 - val_avg_dice_coef: 0.6121 - val_avg_iou_coef: 0.4410 - learning_rate: 3.0000e-04
# Epoch 2/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - loss: 0.6524 - side_1_accuracy: 0.5678 - side_1_dice_coef: 0.5921 - side_1_iou_coef: 0.4210 - side_1_loss: 0.7460 - side_2_accuracy: 0.6593 - side_2_dice_coef: 0.7042 - side_2_iou_coef: 0.5438 - side_2_loss: 0.6049 - side_3_accuracy: 0.6611 - side_3_dice_coef: 0.6562 - side_3_iou_coef: 0.4888 - side_3_loss: 0.6567 - side_4_accuracy: 0.6590 - side_4_dice_coef: 0.7267 - side_4_iou_coef: 0.5715 - side_4_loss: 0.6019
# val_avg_loss=0.6967  val_avg_accuracy=0.5624  val_avg_dice_coef=0.6737  val_avg_iou_coef=0.5080
#
# ...
# Epoch 42/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - loss: 0.4823 - side_1_accuracy: 0.7560 - side_1_dice_coef: 0.7647 - side_1_iou_coef: 0.6198 - side_1_loss: 0.4978 - side_2_accuracy: 0.7660 - side_2_dice_coef: 0.7794 - side_2_iou_coef: 0.6391 - side_2_loss: 0.4809 - side_3_accuracy: 0.7683 - side_3_dice_coef: 0.7823 - side_3_iou_coef: 0.6430 - side_3_loss: 0.4752 - side_4_accuracy: 0.7668 - side_4_dice_coef: 0.7829 - side_4_iou_coef: 0.6437 - side_4_loss: 0.4753
# val_avg_loss=0.6110  val_avg_accuracy=0.6984  val_avg_dice_coef=0.7317  val_avg_iou_coef=0.5769
#
# Epoch 42: val_avg_dice_coef did not improve from 0.74116
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.4665 - side_1_accuracy: 0.7651 - side_1_dice_coef: 0.7800 - side_1_iou_coef: 0.6400 - side_1_loss: 0.4774 - side_2_accuracy: 0.7724 - side_2_dice_coef: 0.7925 - side_2_iou_coef: 0.6569 - side_2_loss: 0.4651 - side_3_accuracy: 0.7739 - side_3_dice_coef: 0.7944 - side_3_iou_coef: 0.6594 - side_3_loss: 0.4616 - side_4_accuracy: 0.7732 - side_4_dice_coef: 0.7947 - side_4_iou_coef: 0.6598 - side_4_loss: 0.4621 - val_loss: 0.6137 - val_side_1_accuracy: 0.6921 - val_side_1_dice_coef: 0.7212 - val_side_1_iou_coef: 0.5640 - val_side_1_loss: 0.6245 - val_side_2_accuracy: 0.6962 - val_side_2_dice_coef: 0.7323 - val_side_2_iou_coef: 0.5777 - val_side_2_loss: 0.6178 - val_side_3_accuracy: 0.6998 - val_side_3_dice_coef: 0.7357 - val_side_3_iou_coef: 0.5819 - val_side_3_loss: 0.6087 - val_side_4_accuracy: 0.6999 - val_side_4_dice_coef: 0.7375 - val_side_4_iou_coef: 0.5841 - val_side_4_loss: 0.6039 - val_avg_loss: 0.6110 - val_avg_accuracy: 0.6984 - val_avg_dice_coef: 0.7317 - val_avg_iou_coef: 0.5769 - learning_rate: 9.3750e-06
# Epoch 43/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - loss: 0.4417 - side_1_accuracy: 0.7784 - side_1_dice_coef: 0.7957 - side_1_iou_coef: 0.6615 - side_1_loss: 0.4537 - side_2_accuracy: 0.7847 - side_2_dice_coef: 0.8075 - side_2_iou_coef: 0.6779 - side_2_loss: 0.4410 - side_3_accuracy: 0.7869 - side_3_dice_coef: 0.8095 - side_3_iou_coef: 0.6808 - side_3_loss: 0.4364 - side_4_accuracy: 0.7866 - side_4_dice_coef: 0.8104 - side_4_iou_coef: 0.6821 - side_4_loss: 0.4356
# val_avg_loss=0.6107  val_avg_accuracy=0.6983  val_avg_dice_coef=0.7315  val_avg_iou_coef=0.5766
#
# Epoch 43: val_avg_dice_coef did not improve from 0.74116
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 2s/step - loss: 0.4652 - side_1_accuracy: 0.7653 - side_1_dice_coef: 0.7811 - side_1_iou_coef: 0.6416 - side_1_loss: 0.4760 - side_2_accuracy: 0.7726 - side_2_dice_coef: 0.7935 - side_2_iou_coef: 0.6583 - side_2_loss: 0.4637 - side_3_accuracy: 0.7744 - side_3_dice_coef: 0.7952 - side_3_iou_coef: 0.6607 - side_3_loss: 0.4603 - side_4_accuracy: 0.7736 - side_4_dice_coef: 0.7954 - side_4_iou_coef: 0.6610 - side_4_loss: 0.4610 - val_loss: 0.6134 - val_side_1_accuracy: 0.6922 - val_side_1_dice_coef: 0.7211 - val_side_1_iou_coef: 0.5639 - val_side_1_loss: 0.6243 - val_side_2_accuracy: 0.6962 - val_side_2_dice_coef: 0.7321 - val_side_2_iou_coef: 0.5774 - val_side_2_loss: 0.6175 - val_side_3_accuracy: 0.6997 - val_side_3_dice_coef: 0.7354 - val_side_3_iou_coef: 0.5816 - val_side_3_loss: 0.6084 - val_side_4_accuracy: 0.7000 - val_side_4_dice_coef: 0.7372 - val_side_4_iou_coef: 0.5838 - val_side_4_loss: 0.6035 - val_avg_loss: 0.6107 - val_avg_accuracy: 0.6983 - val_avg_dice_coef: 0.7315 - val_avg_iou_coef: 0.5766 - learning_rate: 9.3750e-06
# Epoch 44/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - loss: 0.4567 - side_1_accuracy: 0.7770 - side_1_dice_coef: 0.7752 - side_1_iou_coef: 0.6335 - side_1_loss: 0.4700 - side_2_accuracy: 0.7839 - side_2_dice_coef: 0.7894 - side_2_iou_coef: 0.6526 - side_2_loss: 0.4541 - side_3_accuracy: 0.7863 - side_3_dice_coef: 0.7917 - side_3_iou_coef: 0.6558 - side_3_loss: 0.4503 - side_4_accuracy: 0.7848 - side_4_dice_coef: 0.7909 - side_4_iou_coef: 0.6547 - side_4_loss: 0.4523
# val_avg_loss=0.6107  val_avg_accuracy=0.6984  val_avg_dice_coef=0.7317  val_avg_iou_coef=0.5769
#
# Epoch 44: val_avg_dice_coef did not improve from 0.74116
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 0.4663 - side_1_accuracy: 0.7653 - side_1_dice_coef: 0.7799 - side_1_iou_coef: 0.6402 - side_1_loss: 0.4773 - side_2_accuracy: 0.7727 - side_2_dice_coef: 0.7923 - side_2_iou_coef: 0.6569 - side_2_loss: 0.4648 - side_3_accuracy: 0.7745 - side_3_dice_coef: 0.7941 - side_3_iou_coef: 0.6593 - side_3_loss: 0.4613 - side_4_accuracy: 0.7737 - side_4_dice_coef: 0.7943 - side_4_iou_coef: 0.6596 - side_4_loss: 0.4619 - val_loss: 0.6135 - val_side_1_accuracy: 0.6922 - val_side_1_dice_coef: 0.7214 - val_side_1_iou_coef: 0.5642 - val_side_1_loss: 0.6245 - val_side_2_accuracy: 0.6963 - val_side_2_dice_coef: 0.7323 - val_side_2_iou_coef: 0.5776 - val_side_2_loss: 0.6175 - val_side_3_accuracy: 0.6998 - val_side_3_dice_coef: 0.7356 - val_side_3_iou_coef: 0.5818 - val_side_3_loss: 0.6083 - val_side_4_accuracy: 0.7001 - val_side_4_dice_coef: 0.7374 - val_side_4_iou_coef: 0.5841 - val_side_4_loss: 0.6035 - val_avg_loss: 0.6107 - val_avg_accuracy: 0.6984 - val_avg_dice_coef: 0.7317 - val_avg_iou_coef: 0.5769 - learning_rate: 9.3750e-06
# Epoch 45/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 603ms/step - loss: 0.4792 - side_1_accuracy: 0.7531 - side_1_dice_coef: 0.7785 - side_1_iou_coef: 0.6374 - side_1_loss: 0.4876 - side_2_accuracy: 0.7580 - side_2_dice_coef: 0.7898 - side_2_iou_coef: 0.6527 - side_2_loss: 0.4779 - side_3_accuracy: 0.7598 - side_3_dice_coef: 0.7909 - side_3_iou_coef: 0.6542 - side_3_loss: 0.4755 - side_4_accuracy: 0.7595 - side_4_dice_coef: 0.7907 - side_4_iou_coef: 0.6540 - side_4_loss: 0.4757
# val_avg_loss=0.6105  val_avg_accuracy=0.6984  val_avg_dice_coef=0.7316  val_avg_iou_coef=0.5768
#
# Epoch 45: val_avg_dice_coef did not improve from 0.74116
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 4.687500222644303e-06.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.4639 - side_1_accuracy: 0.7654 - side_1_dice_coef: 0.7823 - side_1_iou_coef: 0.6425 - side_1_loss: 0.4748 - side_2_accuracy: 0.7728 - side_2_dice_coef: 0.7946 - side_2_iou_coef: 0.6592 - side_2_loss: 0.4625 - side_3_accuracy: 0.7746 - side_3_dice_coef: 0.7963 - side_3_iou_coef: 0.6617 - side_3_loss: 0.4589 - side_4_accuracy: 0.7739 - side_4_dice_coef: 0.7966 - side_4_iou_coef: 0.6620 - side_4_loss: 0.4595 - val_loss: 0.6133 - val_side_1_accuracy: 0.6922 - val_side_1_dice_coef: 0.7214 - val_side_1_iou_coef: 0.5642 - val_side_1_loss: 0.6244 - val_side_2_accuracy: 0.6963 - val_side_2_dice_coef: 0.7322 - val_side_2_iou_coef: 0.5775 - val_side_2_loss: 0.6173 - val_side_3_accuracy: 0.6998 - val_side_3_dice_coef: 0.7356 - val_side_3_iou_coef: 0.5817 - val_side_3_loss: 0.6081 - val_side_4_accuracy: 0.7002 - val_side_4_dice_coef: 0.7373 - val_side_4_iou_coef: 0.5839 - val_side_4_loss: 0.6032 - val_avg_loss: 0.6105 - val_avg_accuracy: 0.6984 - val_avg_dice_coef: 0.7316 - val_avg_iou_coef: 0.5768 - learning_rate: 9.3750e-06
# Epoch 46/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - loss: 0.4880 - side_1_accuracy: 0.7584 - side_1_dice_coef: 0.7700 - side_1_iou_coef: 0.6264 - side_1_loss: 0.4995 - side_2_accuracy: 0.7657 - side_2_dice_coef: 0.7830 - side_2_iou_coef: 0.6437 - side_2_loss: 0.4859 - side_3_accuracy: 0.7674 - side_3_dice_coef: 0.7847 - side_3_iou_coef: 0.6460 - side_3_loss: 0.4824 - side_4_accuracy: 0.7669 - side_4_dice_coef: 0.7842 - side_4_iou_coef: 0.6453 - side_4_loss: 0.4841
# val_avg_loss=0.6104  val_avg_accuracy=0.6984  val_avg_dice_coef=0.7315  val_avg_iou_coef=0.5767
#
# Epoch 46: val_avg_dice_coef did not improve from 0.74116
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.4642 - side_1_accuracy: 0.7654 - side_1_dice_coef: 0.7821 - side_1_iou_coef: 0.6426 - side_1_loss: 0.4750 - side_2_accuracy: 0.7728 - side_2_dice_coef: 0.7942 - side_2_iou_coef: 0.6591 - side_2_loss: 0.4627 - side_3_accuracy: 0.7747 - side_3_dice_coef: 0.7960 - side_3_iou_coef: 0.6615 - side_3_loss: 0.4591 - side_4_accuracy: 0.7740 - side_4_dice_coef: 0.7961 - side_4_iou_coef: 0.6617 - side_4_loss: 0.4598 - val_loss: 0.6132 - val_side_1_accuracy: 0.6922 - val_side_1_dice_coef: 0.7213 - val_side_1_iou_coef: 0.5641 - val_side_1_loss: 0.6244 - val_side_2_accuracy: 0.6963 - val_side_2_dice_coef: 0.7321 - val_side_2_iou_coef: 0.5775 - val_side_2_loss: 0.6172 - val_side_3_accuracy: 0.6998 - val_side_3_dice_coef: 0.7355 - val_side_3_iou_coef: 0.5816 - val_side_3_loss: 0.6079 - val_side_4_accuracy: 0.7001 - val_side_4_dice_coef: 0.7373 - val_side_4_iou_coef: 0.5839 - val_side_4_loss: 0.6031 - val_avg_loss: 0.6104 - val_avg_accuracy: 0.6984 - val_avg_dice_coef: 0.7315 - val_avg_iou_coef: 0.5767 - learning_rate: 4.6875e-06
# Epoch 47/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - loss: 0.4513 - side_1_accuracy: 0.7719 - side_1_dice_coef: 0.7871 - side_1_iou_coef: 0.6491 - side_1_loss: 0.4632 - side_2_accuracy: 0.7814 - side_2_dice_coef: 0.7997 - side_2_iou_coef: 0.6663 - side_2_loss: 0.4500 - side_3_accuracy: 0.7834 - side_3_dice_coef: 0.8018 - side_3_iou_coef: 0.6693 - side_3_loss: 0.4458 - side_4_accuracy: 0.7825 - side_4_dice_coef: 0.8026 - side_4_iou_coef: 0.6705 - side_4_loss: 0.4461
# val_avg_loss=0.6102  val_avg_accuracy=0.6984  val_avg_dice_coef=0.7313  val_avg_iou_coef=0.5764
#
# Epoch 47: val_avg_dice_coef did not improve from 0.74116
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - loss: 0.4643 - side_1_accuracy: 0.7655 - side_1_dice_coef: 0.7817 - side_1_iou_coef: 0.6420 - side_1_loss: 0.4753 - side_2_accuracy: 0.7729 - side_2_dice_coef: 0.7939 - side_2_iou_coef: 0.6585 - side_2_loss: 0.4628 - side_3_accuracy: 0.7748 - side_3_dice_coef: 0.7957 - side_3_iou_coef: 0.6609 - side_3_loss: 0.4592 - side_4_accuracy: 0.7740 - side_4_dice_coef: 0.7958 - side_4_iou_coef: 0.6612 - side_4_loss: 0.4598 - val_loss: 0.6130 - val_side_1_accuracy: 0.6922 - val_side_1_dice_coef: 0.7212 - val_side_1_iou_coef: 0.5639 - val_side_1_loss: 0.6243 - val_side_2_accuracy: 0.6962 - val_side_2_dice_coef: 0.7319 - val_side_2_iou_coef: 0.5772 - val_side_2_loss: 0.6171 - val_side_3_accuracy: 0.6997 - val_side_3_dice_coef: 0.7353 - val_side_3_iou_coef: 0.5814 - val_side_3_loss: 0.6078 - val_side_4_accuracy: 0.7002 - val_side_4_dice_coef: 0.7370 - val_side_4_iou_coef: 0.5836 - val_side_4_loss: 0.6028 - val_avg_loss: 0.6102 - val_avg_accuracy: 0.6984 - val_avg_dice_coef: 0.7313 - val_avg_iou_coef: 0.5764 - learning_rate: 4.6875e-06
# Epoch 48/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - loss: 0.4307 - side_1_accuracy: 0.7821 - side_1_dice_coef: 0.7972 - side_1_iou_coef: 0.6634 - side_1_loss: 0.4385 - side_2_accuracy: 0.7860 - side_2_dice_coef: 0.8078 - side_2_iou_coef: 0.6781 - side_2_loss: 0.4288 - side_3_accuracy: 0.7879 - side_3_dice_coef: 0.8086 - side_3_iou_coef: 0.6792 - side_3_loss: 0.4275 - side_4_accuracy: 0.7874 - side_4_dice_coef: 0.8084 - side_4_iou_coef: 0.6788 - side_4_loss: 0.4279
# val_avg_loss=0.6102  val_avg_accuracy=0.6984  val_avg_dice_coef=0.7314  val_avg_iou_coef=0.5766
#
# Epoch 48: val_avg_dice_coef did not improve from 0.74116
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - loss: 0.4662 - side_1_accuracy: 0.7655 - side_1_dice_coef: 0.7797 - side_1_iou_coef: 0.6399 - side_1_loss: 0.4772 - side_2_accuracy: 0.7729 - side_2_dice_coef: 0.7918 - side_2_iou_coef: 0.6562 - side_2_loss: 0.4648 - side_3_accuracy: 0.7749 - side_3_dice_coef: 0.7937 - side_3_iou_coef: 0.6587 - side_3_loss: 0.4611 - side_4_accuracy: 0.7741 - side_4_dice_coef: 0.7940 - side_4_iou_coef: 0.6590 - side_4_loss: 0.4616 - val_loss: 0.6130 - val_side_1_accuracy: 0.6922 - val_side_1_dice_coef: 0.7213 - val_side_1_iou_coef: 0.5641 - val_side_1_loss: 0.6243 - val_side_2_accuracy: 0.6962 - val_side_2_dice_coef: 0.7320 - val_side_2_iou_coef: 0.5773 - val_side_2_loss: 0.6171 - val_side_3_accuracy: 0.6998 - val_side_3_dice_coef: 0.7354 - val_side_3_iou_coef: 0.5815 - val_side_3_loss: 0.6078 - val_side_4_accuracy: 0.7003 - val_side_4_dice_coef: 0.7371 - val_side_4_iou_coef: 0.5837 - val_side_4_loss: 0.6029 - val_avg_loss: 0.6102 - val_avg_accuracy: 0.6984 - val_avg_dice_coef: 0.7314 - val_avg_iou_coef: 0.5766 - learning_rate: 4.6875e-06
# Epoch 49/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - loss: 0.4382 - side_1_accuracy: 0.7774 - side_1_dice_coef: 0.7951 - side_1_iou_coef: 0.6607 - side_1_loss: 0.4505 - side_2_accuracy: 0.7855 - side_2_dice_coef: 0.8065 - side_2_iou_coef: 0.6764 - side_2_loss: 0.4364 - side_3_accuracy: 0.7877 - side_3_dice_coef: 0.8078 - side_3_iou_coef: 0.6782 - side_3_loss: 0.4331 - side_4_accuracy: 0.7865 - side_4_dice_coef: 0.8080 - side_4_iou_coef: 0.6786 - side_4_loss: 0.4328
# val_avg_loss=0.6101  val_avg_accuracy=0.6985  val_avg_dice_coef=0.7313  val_avg_iou_coef=0.5765
#
# Epoch 49: val_avg_dice_coef did not improve from 0.74116
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 2.3437501113221515e-06.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.4653 - side_1_accuracy: 0.7656 - side_1_dice_coef: 0.7806 - side_1_iou_coef: 0.6409 - side_1_loss: 0.4763 - side_2_accuracy: 0.7730 - side_2_dice_coef: 0.7927 - side_2_iou_coef: 0.6572 - side_2_loss: 0.4639 - side_3_accuracy: 0.7750 - side_3_dice_coef: 0.7945 - side_3_iou_coef: 0.6596 - side_3_loss: 0.4602 - side_4_accuracy: 0.7742 - side_4_dice_coef: 0.7946 - side_4_iou_coef: 0.6599 - side_4_loss: 0.4608 - val_loss: 0.6129 - val_side_1_accuracy: 0.6922 - val_side_1_dice_coef: 0.7212 - val_side_1_iou_coef: 0.5640 - val_side_1_loss: 0.6242 - val_side_2_accuracy: 0.6962 - val_side_2_dice_coef: 0.7319 - val_side_2_iou_coef: 0.5772 - val_side_2_loss: 0.6170 - val_side_3_accuracy: 0.6997 - val_side_3_dice_coef: 0.7353 - val_side_3_iou_coef: 0.5814 - val_side_3_loss: 0.6077 - val_side_4_accuracy: 0.7002 - val_side_4_dice_coef: 0.7370 - val_side_4_iou_coef: 0.5836 - val_side_4_loss: 0.6027 - val_avg_loss: 0.6101 - val_avg_accuracy: 0.6985 - val_avg_dice_coef: 0.7313 - val_avg_iou_coef: 0.5765 - learning_rate: 4.6875e-06
# Epoch 50/50
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.4536 - side_1_accuracy: 0.7849 - side_1_dice_coef: 0.7692 - side_1_iou_coef: 0.6271 - side_1_loss: 0.4707 - side_2_accuracy: 0.7916 - side_2_dice_coef: 0.7849 - side_2_iou_coef: 0.6477 - side_2_loss: 0.4511 - side_3_accuracy: 0.7951 - side_3_dice_coef: 0.7884 - side_3_iou_coef: 0.6522 - side_3_loss: 0.4451 - side_4_accuracy: 0.7934 - side_4_dice_coef: 0.7877 - side_4_iou_coef: 0.6513 - side_4_loss: 0.4473
# val_avg_loss=0.6101  val_avg_accuracy=0.6985  val_avg_dice_coef=0.7314  val_avg_iou_coef=0.5766
#
# Epoch 50: val_avg_dice_coef did not improve from 0.74116
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - loss: 0.4671 - side_1_accuracy: 0.7656 - side_1_dice_coef: 0.7785 - side_1_iou_coef: 0.6394 - side_1_loss: 0.4784 - side_2_accuracy: 0.7730 - side_2_dice_coef: 0.7909 - side_2_iou_coef: 0.6560 - side_2_loss: 0.4656 - side_3_accuracy: 0.7751 - side_3_dice_coef: 0.7929 - side_3_iou_coef: 0.6586 - side_3_loss: 0.4618 - side_4_accuracy: 0.7742 - side_4_dice_coef: 0.7929 - side_4_iou_coef: 0.6587 - side_4_loss: 0.4625 - val_loss: 0.6129 - val_side_1_accuracy: 0.6922 - val_side_1_dice_coef: 0.7213 - val_side_1_iou_coef: 0.5641 - val_side_1_loss: 0.6243 - val_side_2_accuracy: 0.6962 - val_side_2_dice_coef: 0.7320 - val_side_2_iou_coef: 0.5773 - val_side_2_loss: 0.6170 - val_side_3_accuracy: 0.6998 - val_side_3_dice_coef: 0.7354 - val_side_3_iou_coef: 0.5815 - val_side_3_loss: 0.6077 - val_side_4_accuracy: 0.7003 - val_side_4_dice_coef: 0.7371 - val_side_4_iou_coef: 0.5837 - val_side_4_loss: 0.6027 - val_avg_loss: 0.6101 - val_avg_accuracy: 0.6985 - val_avg_dice_coef: 0.7314 - val_avg_iou_coef: 0.5766 - learning_rate: 2.3438e-06

# %%
plot_training_curves(history)
